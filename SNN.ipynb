# %% [markdown]
# <a href="https://colab.research.google.com/github/jlab-sensing/MFC_Modeling/blob/main/SNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  SNN Models
# ###  In order to run the code in this notebook, you must download the `ucscMFCDataset` directory and `stanfordMFCDataset.zip`, which expands into the directory `rocket4`, from [Hugging Face](https://huggingface.co/datasets/adunlop621/Soil_MFC/tree/main), and store them in the same directory as this notebook. You can also find several pretrained models in the at this link, with the naming conventions described in the [README](https://github.com/jlab-sensing/MFC_Modeling#:~:text=Repository%20files%20navigation-,README,-MFC_Modeling)

# %%
# %pip install --upgrade hepml
# %pip install arrow
# %pip install keras_lr_finder
# %pip install pandas
# %pip install snntorch --quiet
# Out:
# Requirement already satisfied: hepml in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (0.0.12)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from hepml) (1.3.2)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from hepml) (2.2.2)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from hepml) (1.26.4)
# Requirement already satisfied: seaborn in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from hepml) (0.13.2)
# Requirement already satisfied: black in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from hepml) (24.10.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from hepml) (4.66.4)
# Requirement already satisfied: wget in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from hepml) (3.2)
# Requirement already satisfied: nbdev in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from hepml) (2.3.31)
# Requirement already satisfied: sklearn-pandas in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from hepml) (2.2.0)
# Requirement already satisfied: graphviz in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from hepml) (0.20.3)
# Requirement already satisfied: gdown in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from hepml) (5.2.0)
# Requirement already satisfied: pyarrow in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from hepml) (17.0.0)
# Requirement already satisfied: numba in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from hepml) (0.60.0)
# Requirement already satisfied: Cython in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from hepml) (3.0.11)
# Requirement already satisfied: fastprogress in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from hepml) (1.0.3)
# Requirement already satisfied: giotto-tda in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from hepml) (0.6.2)
# Requirement already satisfied: pillow in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from hepml) (10.3.0)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from black->hepml) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from black->hepml) (1.0.0)
# Requirement already satisfied: packaging>=22.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from black->hepml) (24.1)
# Requirement already satisfied: pathspec>=0.9.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from black->hepml) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from black->hepml) (4.2.2)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from gdown->hepml) (4.12.3)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from gdown->hepml) (3.16.1)
# Requirement already satisfied: requests[socks] in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from gdown->hepml) (2.32.3)
# Requirement already satisfied: scipy>=1.5.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from giotto-tda->hepml) (1.13.1)
# Requirement already satisfied: joblib>=0.16.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from giotto-tda->hepml) (1.4.2)
# Requirement already satisfied: giotto-ph>=0.2.1 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from giotto-tda->hepml) (0.2.4)
# Requirement already satisfied: pyflagser>=0.4.3 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from giotto-tda->hepml) (0.4.7)
# Requirement already satisfied: igraph>=0.9.8 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from giotto-tda->hepml) (0.11.6)
# Requirement already satisfied: plotly>=4.8.2 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from giotto-tda->hepml) (5.24.1)
# Requirement already satisfied: ipywidgets>=7.5.1 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from giotto-tda->hepml) (8.1.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from scikit-learn->hepml) (3.5.0)
# Requirement already satisfied: fastcore>=1.5.27 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from nbdev->hepml) (1.7.19)
# Requirement already satisfied: execnb>=0.1.4 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from nbdev->hepml) (0.1.6)
# Requirement already satisfied: astunparse in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from nbdev->hepml) (1.6.3)
# Requirement already satisfied: ghapi>=1.0.3 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from nbdev->hepml) (1.0.6)
# Requirement already satisfied: watchdog in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from nbdev->hepml) (5.0.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from nbdev->hepml) (2.4.1)
# Requirement already satisfied: PyYAML in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from nbdev->hepml) (6.0.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from numba->hepml) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from pandas->hepml) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from pandas->hepml) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from pandas->hepml) (2024.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from seaborn->hepml) (3.9.0)
# Requirement already satisfied: ipython in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from execnb>=0.1.4->nbdev->hepml) (8.29.0)
# Requirement already satisfied: texttable>=1.6.2 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from igraph>=0.9.8->giotto-tda->hepml) (1.7.0)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from ipywidgets>=7.5.1->giotto-tda->hepml) (0.2.2)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from ipywidgets>=7.5.1->giotto-tda->hepml) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from ipywidgets>=7.5.1->giotto-tda->hepml) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from ipywidgets>=7.5.1->giotto-tda->hepml) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->hepml) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->hepml) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->hepml) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->hepml) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->hepml) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from plotly>=4.8.2->giotto-tda->hepml) (9.0.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->hepml) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from astunparse->nbdev->hepml) (0.43.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from beautifulsoup4->gdown->hepml) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from requests[socks]->gdown->hepml) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from requests[socks]->gdown->hepml) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from requests[socks]->gdown->hepml) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from requests[socks]->gdown->hepml) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from requests[socks]->gdown->hepml) (1.7.1)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from ipython->execnb>=0.1.4->nbdev->hepml) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from ipython->execnb>=0.1.4->nbdev->hepml) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from ipython->execnb>=0.1.4->nbdev->hepml) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from ipython->execnb>=0.1.4->nbdev->hepml) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from ipython->execnb>=0.1.4->nbdev->hepml) (2.18.0)
# Requirement already satisfied: stack-data in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from ipython->execnb>=0.1.4->nbdev->hepml) (0.6.2)
# Requirement already satisfied: typing-extensions>=4.6 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from ipython->execnb>=0.1.4->nbdev->hepml) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from ipython->execnb>=0.1.4->nbdev->hepml) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from jedi>=0.16->ipython->execnb>=0.1.4->nbdev->hepml) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from pexpect>4.3->ipython->execnb>=0.1.4->nbdev->hepml) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->execnb>=0.1.4->nbdev->hepml) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from stack-data->ipython->execnb>=0.1.4->nbdev->hepml) (2.1.0)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from stack-data->ipython->execnb>=0.1.4->nbdev->hepml) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: arrow in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from arrow) (2.9.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from arrow) (2.9.0.20241003)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from python-dateutil>=2.7.0->arrow) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: keras_lr_finder in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (0.1)
# Requirement already satisfied: keras>=2.0.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from keras_lr_finder) (3.3.3)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from keras_lr_finder) (3.9.0)
# Requirement already satisfied: absl-py in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from keras>=2.0.0->keras_lr_finder) (2.1.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from keras>=2.0.0->keras_lr_finder) (1.26.4)
# Requirement already satisfied: rich in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from keras>=2.0.0->keras_lr_finder) (13.7.1)
# Requirement already satisfied: namex in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from keras>=2.0.0->keras_lr_finder) (0.0.8)
# Requirement already satisfied: h5py in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from keras>=2.0.0->keras_lr_finder) (3.11.0)
# Requirement already satisfied: optree in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from keras>=2.0.0->keras_lr_finder) (0.11.0)
# Requirement already satisfied: ml-dtypes in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from keras>=2.0.0->keras_lr_finder) (0.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib->keras_lr_finder) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib->keras_lr_finder) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib->keras_lr_finder) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib->keras_lr_finder) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib->keras_lr_finder) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib->keras_lr_finder) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib->keras_lr_finder) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib->keras_lr_finder) (2.9.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->keras_lr_finder) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from optree->keras>=2.0.0->keras_lr_finder) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from rich->keras>=2.0.0->keras_lr_finder) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from rich->keras>=2.0.0->keras_lr_finder) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=2.0.0->keras_lr_finder) (0.1.2)
# ^C
# ERROR: Operation cancelled by user
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
# reload modules before executing user code
#%load_ext autoreload
# reload all modules every time before executing Python code
#%autoreload 2
# render plots in notebook

# Misc imports
# %matplotlib inline
import datetime
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
import seaborn as sns
from hepml.core import plot_regression_tree
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
import random
import statistics

# sklearn imports
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_percentage_error as MAPE
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit

# torch imports
import torch
import torch.nn as nn

# snnTorch imports
import snntorch as snn
from snntorch import functional as SF
import snntorch.spikeplot as splt

# # keras imports
# from keras.models import Sequential
# from keras.layers import Dense
# from keras.layers import LSTM
# from keras import backend as K

# %% [markdown]
# ##  Load and Format Dataset 1
#
# ### Remember to download `stanfordMFCDataset.zip`, which expands into the directory `rocket4`, from [Hugging Face](https://huggingface.co/datasets/adunlop621/Soil_MFC/tree/main), and store it in the same directory as this notebook before executing the following code.

# %%
#Load teros data
import glob
teros_files = glob.glob("rocket4/TEROSoutput*.csv")
X = pd.DataFrame()
for f in teros_files:
  try:
    csv = pd.read_csv(f, index_col=False).dropna()
    X = pd.concat([X, csv])
  except:
    continue

# %%
#Load power data
power_files = glob.glob("rocket4/soil*.csv")
y = pd.DataFrame()
for f in sorted(power_files, key=lambda x: int(x.split('.')[0].split('_')[-1])):
#in power_files:
  try:
    csv = pd.read_csv(f, on_bad_lines='skip', skiprows=10).dropna(how='all')
    csv = csv.rename({'Unnamed: 0': 'timestamp'}, axis='columns')
    y = pd.concat([y,csv])
  except:
    continue
y["timestamp"] = y["timestamp"].round(decimals = 1)

# %%
#Convert current to amps, voltage to volts
y["I1L [10pA]"] = np.abs(y["I1L [10pA]"] * 1E-11)
y["V1 [10nV]"] = np.abs(y["V1 [10nV]"] * 1E-8)
y["I1H [nA]"] = np.abs(y["I1H [nA]"] * 1E-9)

# %%
#Sort data by timestamp, convert to datetime
X = X.sort_values(['timestamp'])
y = y.sort_values(['timestamp'])
X['timestamp'] = pd.to_datetime(X['timestamp'], unit='s')
y['timestamp'] = pd.to_datetime(y['timestamp'], unit='s')

#Merge data by timestamp
uncut_df = pd.merge_asof(left=X,right=y,direction='nearest',tolerance=pd.Timedelta('1 sec'), on = 'timestamp').dropna(how='all')

#Isolate data from cell0
df = uncut_df.loc[uncut_df['sensorID'] == 0]

#Localize timestamp
df.timestamp = df.timestamp.dt.tz_localize('UTC').dt.tz_convert('US/Pacific')
# Out:
# /var/folders/1g/jt7x_x9n6j1f3317_dwv3k9m0000gn/T/ipykernel_36727/3455547848.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.timestamp = df.timestamp.dt.tz_localize('UTC').dt.tz_convert('US/Pacific')

# %%
#Use only data from after deployment date
#df = df.loc[(df['timestamp'] > '2021-09-24') & (df['timestamp'] < '2021-10-15')] #Future of Clean Computing Graph
#df = df.loc[(df['timestamp'] > '2021-06-24') & (df['timestamp'] < '2021-07-02')]
#df = df.loc[(df['timestamp'] > '2021-06-18')] #Two weeks after deployment
df = df.loc[(df['timestamp'] > '2021-06-04')] #Deployment date
#df = df.loc[(df['timestamp'] > '2021-06-25') & (df['timestamp'] < '2021-06-26')] #Small training set

#Power drop
#df = df.loc[(df['timestamp'] > '2021-11-01') & (df['timestamp'] < '2021-11-22')]

#Drop data outages
df = df.drop(df[(df.timestamp > '2021-11-11') & (df.timestamp < '2021-11-22 01:00:00')].index)
df = df.drop(df[(df.timestamp > '2022-01-27')].index)
#df = df.set_index('timestamp')
df = df[:-1]

# %%
df = df.set_index('timestamp')

# %%
#Get time since deployement
df['tsd'] = (df.index - df.index[0]).days
df['hour'] = (df.index).hour

# %%
#Calculate power
df["power"] = np.abs(np.multiply(df.iloc[:, 7], df.iloc[:, 8]))
#df["power"] = np.abs(np.multiply(df["I1L [10pA]"], df["V1 [10nV]"]))

#Convert to nW
df['power'] = df['power']*1E9

# %%
#Convert to 10 nanoamps, 10 microvolts
df["I1L [10pA]"] = np.abs(df["I1L [10pA]"] * 1E8)
df["V1 [10nV]"] = np.abs(df["V1 [10nV]"] * 1E5)
df["I1H [nA]"] = np.abs(df["I1H [nA]"] * 1E8)

# %%
df = df.reset_index()

# %%
#Add power time series
df['power - 1h'] = df['power'].shift(1).dropna()
df['power - 2h'] = df['power'].shift(2).dropna()
df['power - 3h'] = df['power'].shift(3).dropna()
#df['power - 2h'] = df['power'].shift(2).dropna()
#df['previous_power - 3'] = df['power'].shift(3).dropna()
#df['previous_power - 4'] = df['power'].shift(4).dropna()

#Add teros time series
df['EC - 1h'] = df['EC'].shift(1).dropna()
df['EC - 2h'] = df['EC'].shift(2).dropna()
df['EC - 3h'] = df['EC'].shift(3).dropna()

df['temp - 1h'] = df['temp'].shift(1).dropna()
df['temp - 2h'] = df['temp'].shift(2).dropna()
df['temp - 3h'] = df['temp'].shift(3).dropna()

df['raw_VWC - 1h'] = df['raw_VWC'].shift(1).dropna()
df['raw_VWC - 2h'] = df['raw_VWC'].shift(2).dropna()
df['raw_VWC - 3h'] = df['raw_VWC'].shift(3).dropna()

#Add voltage and current time series
df['V1 - 1h'] = df['V1 [10nV]'].shift(1).dropna()
df['V1 - 2h'] = df['V1 [10nV]'].shift(2).dropna()
df['V1 - 3h'] = df['V1 [10nV]'].shift(3).dropna()

df['I1L - 1h'] = df['I1L [10pA]'].shift(1).dropna()
df['I1L - 2h'] = df['I1L [10pA]'].shift(2).dropna()
df['I1L - 3h'] = df['I1L [10pA]'].shift(3).dropna()

df['I1H - 1h'] = df['I1H [nA]'].shift(1).dropna()
df['I1H - 2h'] = df['I1H [nA]'].shift(2).dropna()
df['I1H - 3h'] = df['I1H [nA]'].shift(3).dropna()
df = df.dropna()

# %%
#df = df.rename(columns={'power': 'power [μW]'})
df = df.rename(columns={'I1L [10pA]': 'Current (uA)', 'V1 [10nV]' : 'Voltage (mV)', 'power' : 'Power (uW)'})
df = df.set_index('timestamp')

# %%
#New runtime calculation
import math
from dateutil import parser
from matplotlib import pyplot as plt
from datetime import datetime, timedelta

def internal_R_v3(R=2000): #return internal resistance of v3 cells in ohms
    #https://www.jstage.jst.go.jp/article/jwet/20/1/20_21-087/_pdf
    v0_oc = 48.5e-3 #48.5 mV
    v0_cc = 4.8e-3
    v0_r = R*((v0_oc/v0_cc)-1)

    v1_oc = 43.8e-3
    v1_cc = 20.9e-3
    v1_r = R*((v1_oc/v1_cc)-1)

    v2_oc = 45.2e-3
    v2_cc = 23.5e-3
    v2_r = R*((v2_oc/v2_cc)-1)

    return (v0_r+v1_r+v2_r)/3

def internal_R_v0(R=2000): #return internal resistance of v0 cells in ohms
    v3_oc = 41.7e-3 #41.7mV
    v3_cc = 5.1e-3
    v3_r = R*((v3_oc/v3_cc)-1)

    v4_oc = 48.7e-3
    v4_cc = 16.8e-3
    v4_r = R*((v4_oc/v4_cc)-1)

    v5_oc = 39.1e-3
    v5_cc = 16.9e-3
    v5_r = R*((v5_oc/v5_cc)-1)

    return (v3_r+v4_r+v5_r)/3

def SMFC_current(v, R):
    return v/R

#MODEL
def cap_leakage(E_cap_tn, timestep):
    #Spec for KEMET T491
    return 0.01e-6 * E_cap_tn * timestep

def Matrix_Power(V, R):
    #efficiency interpolated from https://www.analog.com/media/en/technical-documentation/data-sheets/ADP5091-5092.pdf
    #given I_in = 100 uA and SYS = 3V
    #V is the voltage (V) of the SMFC we captured
    #R is the resistance (ohms) of the load we used to get that voltage trace
    #Eta = -292.25665*V**4 + 784.30311*V**3 - 770.71691*V**2 + 342.00502*V + 15.83307
    #Eta = Eta/100
    Eta = 0.60
    Pmax = (V**2)/R
    Pout = Eta*Pmax
    #assert((Eta > 0) & (Eta < 1))
    #assert(Pout < 12000e-6)
    return Pout

def update_capEnergy(e0, V_applied, R, C, dt):
    # e0: initial energy stored
    # V_applied: voltage from SMFC
    # R: internal resistance of SMFC
    # C: capacitance of capacitor
    # dt: time step since last data point
    e_cap = e0 + Matrix_Power(V_applied, R)*dt - cap_leakage(e0, dt)
    v_cap = math.sqrt(2*e_cap/C)
    if e_cap < 0: #Not charging if leakage is greater than energy
        e_cap = 0

    return e_cap, v_cap #output final e and v

def Advanced_energy():
    #Now representing "Advanced"
    #startup time of 2500 ms
    t = 2500e-3
    e = 2.4 * 128e-3 * t
    e_startup = 2.4 * 128e-3 * 5e-3
    return e+e_startup

def Minimal_energy():
    #Now representing "Minimal"
    t = 0.888e-3 #tentative time
    e = 0.9 * 4.8e-3 * t #this uses average current
    e_startup = 0#assume negligible, no known startup time given
    return  e + e_startup

def Analog_energy():
    #Now representing Analog
    t = 1e-3 #estimated operating time
    e = 0.11 * 2.15e-6 * t
    e_startup = 0 #analog device, no startup needed :)
    return e + e_startup

#STEP 3:
# For each day:
#   on_Minimal, on_Advanced, on_Analog = 0
#   For each time step (like every 60 s given our logging freq):
#       - Update the energy in our capacitor (put fcn in models.py) given (1) input voltage, (2) time step, (3) capacitance (prob 10 uF), this will be an integral
#       - Check if energy is enough to turn on (1) 1 uJ load, (2) 10 uJ load, and (3) 20 uJ load (will tweak later to reflect real energy cost of each system)
#       - If so, add to on_Minimal, on_Advanced, and on_Analog and reset capacitor energy to 0 J (might tweak this value)
#   Append on_Minimal, on_Advanced, on_Analog to on_Minimal_list, on_Advanced_list, on_Analog_list. This will be a list of how many sensor readings we are able to take with each of these systems every day given the energy we got
#STEP 4: Visualize the daily # of readings with 3 bar graphs, y axis is # of readings and x axis is days.
#   - Given 3 lists of integer values, plot them on bar graphs

def group_util(test_date1, test_date2, N):
    diff = (test_date2 - test_date1) / N
    return [test_date1 + diff * idx for idx in range(N)] + [test_date2]

def oracle_simulate(v_list, C_h):
    #Calculate maximum energy
    total_E = 0
    for i in range(len(v_list) - 1):
        t = (v_list.index[i+1] - v_list.index[i]).total_seconds()
        if t > 180:
          print("Discontinuity")
          print(v_list.index[i+1], v_list.index[i])
          print(v_list['Voltage (mV)'][i+1], v_list['Voltage (mV)'][i])
          #total_E, ignore = update_capEnergy(total_E, V_applied=(v_list['V1 [mV]'][i+1] + v_list['V1 [mV]'][i])/2, R=internal_R_v0(), C=C_h[0], dt = t)
        else:
          total_E, ignore = update_capEnergy(total_E, V_applied=max(v_list['Voltage (mV)'][i], v_list['Voltage (mV)'][i+1]), R=internal_R_v0(), C=C_h[0], dt = t)
    print("Oracle activations:", math.floor(total_E/Minimal_energy()))
    return(math.floor(total_E/Minimal_energy()))

def naive_simulate(t_list, v_list, v_list_naive, v_list_fine, C_h):
    # t_list: list of decimal time stamps in unit of days (e.g. 71.85893518518519 day), same length as v_list
    # v_list: list of voltage values from SFMC
    # C_h: capacitance of the capacitor being filled up by harvester

    #assume capacitor is completely discharged at start
    e_minimal_stored = 0
    e_minimal_stored_theo = 0

    #Initialize evaluation metrics
    false_act = 0
    max_act = 0
    pred_act = 0
    succ_act = 0

    total_E = 0
    total_E_naive = 0

    #Calculate maximum energy
    #for i in range(len(v_list_fine) - 1):
    #    t = (v_list_fine.index[i+1] - v_list_fine.index[i]).total_seconds()
    #    total_E, ignore = update_capEnergy(total_E, V_applied=v_list_fine['V1 [10nV]'][i], R=internal_R_v0(), C=C_h[0], dt = t)
    #print(total_E/Minimal_energy())
    v = v_list_naive.mean()
    #for each voltage data point
    for jj in range(len(v_list) - 1): #last data point was at 71.85893518518519 day
        t = (v_list.index[jj+1] - v_list.index[jj]).total_seconds()
        if t <= time_frame_seconds:
          #Total predicted vs. actual energy stored
          #Predict energy stored during scheduled sub-interval
          total_E, ignore = update_capEnergy(total_E, V_applied=v_list[jj], R=internal_R_v0(), C=C_h[0], dt = t)
          total_E_naive, ignore = update_capEnergy(total_E_naive, V_applied=v, R=internal_R_v0(), C=C_h[0], dt = t)

          E_Minimal_pred, v_minimal_pred = update_capEnergy(e_minimal_stored, V_applied=v, R=internal_R_v0(), C=C_h[0], dt = t) #set dt as length of prediction interval, in seconds
          pred_act += math.floor(E_Minimal_pred/Minimal_energy()) #Update number of activations predicted
          itn = 0
          if math.floor(E_Minimal_pred/Minimal_energy()) > 0:
              minimal_intervals = [date for date in group_util(v_list.index[jj], v_list.index[jj] + timedelta(seconds=t), math.floor(E_Minimal_pred/Minimal_energy()))]
              #Calculate desired interval
              int_len = time_frame_seconds /  math.floor(E_Minimal_pred/Minimal_energy())
              for i in range(len(minimal_intervals) - 1):
                  #Determine actual energy stored during scheduled sub-interval
                  start = v_list_fine.index.searchsorted(minimal_intervals[i])
                  end =  v_list_fine.index.searchsorted(minimal_intervals[i+1])

                  E_Minimal, ignore = update_capEnergy(e_minimal_stored, V_applied=v_list_fine.iloc[start:end]['Voltage (mV)'].mean(), R=internal_R_v0(), C=C_h[0], dt = int_len)
                  if not math.isnan(v_list_fine.iloc[start:end]['Voltage (mV)'].mean()):
                    if E_Minimal < Minimal_energy():
                        false_act += 1
                        e_minimal_stored = max(0, E_Minimal - Minimal_energy())
                        itn += 1

                    elif E_Minimal >= Minimal_energy():
                        succ_act += 1
                        e_minimal_stored = max(0, E_Minimal - Minimal_energy())
                        itn+= 1

                    else:
                      print('Error')
                      print(e_minimal_stored, v)

                  #Unit test
                  #else:
                  #  print("?")
                  #  print(v_list_fine.index[start])
                  #  print(v_list_fine.index[end])
                  #  print(minimal_intervals[i], minimal_intervals[i+1])

              #Unit test
              #if itn != math.floor(E_Minimal_pred/Minimal_energy()):
              #    print("itn not matching")
              #    print(itn, math.floor(E_Minimal_pred/Minimal_energy()))
              #    continue

          else:
              e_minimal_stored, ignore = update_capEnergy(e_minimal_stored, V_applied=v_list[jj], R=internal_R_v0(), C=C_h[0], dt = t)
              #Added this
              #start = v_list_fine.index.searchsorted(v_list.index[jj])
              #end =  v_list_fine.index.searchsorted(v_list.index[jj+1])
              #for h in range(start, end):
              #    v = v_list_fine.iloc[h]['V1 [mV]']
              #    interval_length = ((v_list_fine.index[h+1]) - (v_list_fine.index[h])).total_seconds()
              #    E_Minimal, ignore = update_capEnergy(e_minimal_stored, V_applied=v, R=internal_R_v0(), C=C_h[0], dt = interval_length)
              #    e_minimal_stored = E_Minimal


        else:
          print("It's over 9000!", v_list.index[jj], v_list.index[jj+1])

    print("Naive total_E activations:", total_E/Minimal_energy())
    print("Naive total_E_pred activations:", total_E_naive/Minimal_energy())
    return pred_act, false_act, succ_act, total_E_naive

def getMax(c_list, input_list):
    max_value = max(input_list)
    i = [index for index, item in enumerate(input_list) if item == max_value][0]
    return i, max_value, c_list[i]


#SMFC
import csv
from collections import defaultdict
from scipy.signal import butter, lfilter
import matplotlib.pyplot as plt
from datetime import datetime

def butter_lowpass(cutoff, fs, order=5):
        return butter(order, cutoff, fs=fs, btype='low', analog=False)

def butter_lowpass_filter(data, cutoff, fs, order=5):
    b, a = butter_lowpass(cutoff, fs, order=order)
    y = lfilter(b, a, data)
    return y

def getMFC_data(y_test, test_pred):
    unix_time = y_test.index
    d0 = unix_time[0]
    days = []
    for d in unix_time:
        day = d
        day_from_start = day-d0
        decimal_day = day_from_start.total_seconds()/(24 * 3600)
        days.append(decimal_day)

    return days

def simulate(t_list, v_list, v_list_pred, v_list_fine, C_h):
    # t_list: list of decimal time stamps in unit of days (e.g. 71.85893518518519 day), same length as v_list
    # v_list: list of voltage values from SFMC
    # C_h: capacitance of the capacitor being filled up by harvester

    #assume capacitor is completely discharged at start
    e_minimal_stored = 0
    e_minimal_stored_theo = 0

    #Initialize evaluation metrics
    false_act = 0
    max_act = 0
    pred_act = 0
    succ_act = 0

    total_E = 0
    total_E_pred = 0

    #Calculate maximum energy
    #for i in range(len(v_list_fine) - 1):
    #    t = (v_list_fine.index[i+1] - v_list_fine.index[i]).total_seconds()
    #    total_E, ignore = update_capEnergy(total_E, V_applied=v_list_fine['V1 [10nV]'][i], R=internal_R_v0(), C=C_h[0], dt = t)
    #print(total_E/Minimal_energy())
    #for each voltage data point
    for jj in range(len(v_list) - 1): #last data point was at 71.85893518518519 day
        t = (v_list.index[jj+1] - v_list.index[jj]).total_seconds()
        total_E, ignore = update_capEnergy(total_E, V_applied=v_list[jj], R=internal_R_v0(), C=C_h[0], dt = t)
        total_E_pred, ignore = update_capEnergy(total_E_pred, V_applied=v_list_pred[jj], R=internal_R_v0(), C=C_h[0], dt = t)
        if t <= time_frame_seconds:
          #Total predicted vs. actual energy stored
          #Predict energy stored during scheduled sub-interval
          E_Minimal_pred, v_minimal_pred = update_capEnergy(e_minimal_stored, V_applied=v_list_pred[jj], R=internal_R_v0(), C=C_h[0], dt = t) #set dt as length of prediction interval, in seconds
          pred_act += math.floor(E_Minimal_pred/Minimal_energy()) #Update number of activations predicted
          itn = 0
          if math.floor(E_Minimal_pred/Minimal_energy()) > 0:
              minimal_intervals = [date for date in group_util(v_list_pred.index[jj], v_list_pred.index[jj] + timedelta(seconds=t), math.floor(E_Minimal_pred/Minimal_energy()))]
              #Calculate desired interval
              int_len = time_frame_seconds /  math.floor(E_Minimal_pred/Minimal_energy())
              for i in range(len(minimal_intervals) - 1):
                  #Determine actual energy stored during scheduled sub-interval
                  start = v_list_fine.index.searchsorted(minimal_intervals[i])
                  end =  v_list_fine.index.searchsorted(minimal_intervals[i+1])
                  v = v_list_fine.iloc[start:end]['Voltage (mV)'].mean()

                  #interval_length = ((v_list_fine.index[end]) - (v_list_fine.index[start])).total_seconds()
                  #if interval_length > int_len:
                  #  print('interval_length > int_len')
                  #  print('interval_length, int_len:', interval_length, int_len)
                  #  print(v_list_fine.index[start], v_list_fine.index[end])
                  #else:
                  #  print('interval_length <= int_len')
                  #  print('interval_length, int_len:', interval_length, int_len)
                  #  print(v_list_fine.index[start], v_list_fine.index[end])

                  E_Minimal, ignore = update_capEnergy(e_minimal_stored, V_applied=v, R=internal_R_v0(), C=C_h[0], dt = int_len)
                  if not math.isnan(v_list_fine.iloc[start:end]['Voltage (mV)'].mean()):
                    if E_Minimal < Minimal_energy():
                        false_act += 1
                        e_minimal_stored = max(0, E_Minimal - Minimal_energy())
                        itn += 1

                    elif E_Minimal >= Minimal_energy():
                        succ_act += 1
                        e_minimal_stored = max(0, E_Minimal - Minimal_energy())
                        itn+= 1

                    else:
                      print('Error')
                      print(e_minimal_stored, v)

                  #Unit test
                  #else:
                  #  print("?")
                  #  print(v_list_fine.index[start])
                  #  print(v_list_fine.index[end])
                  #  print(minimal_intervals[i], minimal_intervals[i+1])

              #Unit test
              #if itn != math.floor(E_Minimal_pred/Minimal_energy()):
              #    print("itn not matching")
              #    print(itn, math.floor(E_Minimal_pred/Minimal_energy()))
              #    continue

          else:
              e_minimal_stored, ignore = update_capEnergy(e_minimal_stored, V_applied=v_list[jj], R=internal_R_v0(), C=C_h[0], dt = t)
              #Added this
              #start = v_list_fine.index.searchsorted(v_list.index[jj])
              #end =  v_list_fine.index.searchsorted(v_list.index[jj+1])
              #for h in range(start, end):
              #    v = v_list_fine.iloc[h]['V1 [mV]']
              #    interval_length = ((v_list_fine.index[h+1]) - (v_list_fine.index[h])).total_seconds()
              #    E_Minimal, ignore = update_capEnergy(e_minimal_stored, V_applied=v, R=internal_R_v0(), C=C_h[0], dt = interval_length)
              #    e_minimal_stored = E_Minimal


        else:
          print("It's over 9000!", v_list.index[jj], v_list.index[jj+1])

    print("Runtime total_E activations:", total_E/Minimal_energy())
    print("Runtime total_E_pred activations:", total_E_pred/Minimal_energy())
    return pred_act, false_act, succ_act, total_E, total_E_pred

# %% [markdown]
# ## Specify Device so we can use GPU

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %% [markdown]
# ## Network Architecture

# %%
beta = 0.9

# old design network
# model = Sequential()
# model.add(LSTM(200, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu'))
# model.add(Dense(100, activation='relu'))
# model.add(Dense(3))
# model.compile(loss=quantile_loss, metrics=['mape'], optimizer='adam')

# Define Network
class Net(nn.Module):
    def __init__(self, num_inputs, num_steps):
        super().__init__()

        self.num_inputs = num_inputs
        self.num_steps = num_steps

        num_hidden1 = 200

        # layer 1
        self.slstm1 = snn.SLSTM(num_inputs, num_hidden1, threshold = 0.25)

        # layer 2
        self.fc1 = torch.nn.Linear(in_features=num_hidden1, out_features=100)
        self.lif1 = snn.Leaky(beta=beta, threshold = 0.5)

        # randomly initialize decay rate for output neuron
        beta_out = random.uniform(0.5, 1)

        # layer 2
        self.fc2 = torch.nn.Linear(in_features=100, out_features=3)
        self.lif2 = snn.Leaky(beta=beta_out, learn_beta=True, reset_mechanism="none")


    def forward(self, x):
        # Initialize hidden states and outputs at t=0
        syn1, mem1 = self.slstm1.reset_mem()
        mem2 = self.lif1.reset_mem()
        mem3 = self.lif2.reset_mem()

        # Record the final layer
        spk1_rec = []
        spk2_rec = []
        spk3_rec = []
        mem_rec = []

        for step in range(self.num_steps):
            spk1, syn1, mem1 = self.slstm1(x.flatten(1), syn1, mem1)
            spk2, mem2 = self.lif1(self.fc1(spk1), mem2)
            spk3, mem3 = self.lif2(self.fc2(spk2), mem3)

            # Append the Spike and Membrane History
            spk1_rec.append(spk1)
            spk2_rec.append(spk2)
            spk3_rec.append(spk3)
            mem_rec.append(mem3)

        return torch.stack(spk1_rec), torch.stack(spk2_rec), torch.stack(spk3_rec), torch.stack(mem_rec)

# %%
from sklearn.model_selection import TimeSeriesSplit
# from keras.models import Sequential
# from keras.layers import Dense
# from keras.layers import LSTM
# from keras import backend as K
from torch.utils.data import DataLoader, TensorDataset

# %%
X_train, X_test = train_test_split(pd.concat([df["power - 1h"], df["power - 2h"], df["power - 3h"], df["V1 - 1h"], df["V1 - 2h"], df["V1 - 3h"], df["I1L - 1h"], df["I1L - 2h"], df["I1L - 3h"],df["EC - 1h"], df["EC - 2h"], df["EC - 3h"], df["raw_VWC - 1h"], df["raw_VWC - 2h"], df["raw_VWC - 3h"], df["temp - 1h"], df["temp - 2h"], df["temp - 3h"], df["tsd"], df["hour"]], axis = 1), test_size=0.3, shuffle=False)
y_train, y_test = train_test_split(pd.concat([df['Power (uW)'], df['Voltage (mV)'], df['Current (uA)']], axis = 1), test_size=0.3, shuffle=False)

# %%
X_valid, X_test = train_test_split(X_test, test_size=0.5, shuffle=False)
y_valid, y_test = train_test_split(y_test, test_size=0.5, shuffle=False)

# %%
#All Data (For Type 1 and 2 Models)
X = pd.concat([df["power - 1h"], df["power - 2h"], df["power - 3h"], df["V1 - 1h"], df["V1 - 2h"], df["V1 - 3h"], df["I1L - 1h"], df["I1L - 2h"], df["I1L - 3h"],df["EC - 1h"], df["EC - 2h"], df["EC - 3h"], df["raw_VWC - 1h"], df["raw_VWC - 2h"], df["raw_VWC - 3h"], df["temp - 1h"], df["temp - 2h"], df["temp - 3h"], df["tsd"], df["hour"]], axis = 1)

#Electricity Data Omitted (For Type 1A and 2A Models)
#X = pd.concat([df["EC - 1h"], df["EC - 2h"], df["EC - 3h"], df["raw_VWC - 1h"], df["raw_VWC - 2h"], df["raw_VWC - 3h"], df["temp - 1h"], df["temp - 2h"], df["temp - 3h"], df["tsd"], df["hour"]], axis = 1)

#Environmental Data Omitted (For Type 1B and 2B Models)
#X = pd.concat([df["power - 1h"], df["power - 2h"], df["power - 3h"], df["V1 - 1h"], df["V1 - 2h"], df["V1 - 3h"], df["I1L - 1h"], df["I1L - 2h"], df["I1L - 3h"]], axis = 1)

y = pd.concat([df["Power (uW)"], df['Voltage (mV)'], df['Current (uA)']], axis = 1)

print("Rows " + str(X.shape[0]) + " Columns " + str(X.shape[1]))

print("Rows " + str(y.shape[0]) + " Columns " + str(y.shape[1]))
# Out:
# Rows 969652 Columns 20
# Rows 969652 Columns 3

# %% [markdown]
# ## 2. Train and Load Models

# %% [markdown]
# ###  2.1 Train new SNN model

# %%
power_mape = []
voltage_mape = []
current_mape = []

E_actual_list = []
E_pred_list = []

max_act_list = []
pred_act_list = []
succ_act_list = []

pred_act_naive_list = []
false_act_naive_list = []
succ_act_naive_list = []

#Set parameters
batchsize_list = [300, 150, 50, 20, 8]
time_frame_list = ['3min', '5min', '15min', '30min', '60min']
time_frame_seconds_list = [180, 300, 900, 1800, 3600]
n = 0

for j in range(len(batchsize_list)):
    n += 1
    if n == 2: #Select which timescales to train for
        #Normalize Data
        X_normalized = ((X - X.min()) / (X.max() - X.min()))

        #Split train and test sets
        X_train, X_test = train_test_split(X_normalized, test_size=0.3, shuffle=False)
        y_train, y_test = train_test_split(y, test_size=0.3, shuffle=False)

        X_valid, X_test = train_test_split(X_test, test_size=0.5, shuffle=False)
        y_valid, y_test = train_test_split(y_test, test_size=0.5, shuffle=False)

        batchsize = batchsize_list[j]
        time_frame = time_frame_list[j]
        time_frame_seconds = time_frame_seconds_list[j]

        print(time_frame)

        #Resample data
        X_train = X_train.resample(time_frame).mean().dropna()
        X_valid = X_valid.resample(time_frame).mean().dropna()
        X_test = X_test.resample(time_frame).mean().dropna()

        y_train = y_train.resample(time_frame).mean().dropna()
        y_valid = y_valid.resample(time_frame).mean().dropna()
        y_test = y_test.resample(time_frame).mean().dropna()

        #Reshape data
        X_train = X_train.values.reshape((X_train.shape[0], 1, X_train.shape[1]))
        X_valid = X_valid.values.reshape((X_valid.shape[0], 1, X_valid.shape[1]))
        X_test = X_test.values.reshape((X_test.shape[0], 1, X_test.shape[1]))

        # convert to tensor
        X_train = torch.tensor(X_train)
        y_train = torch.tensor(y_train.values)
        X_test = torch.tensor(X_test)
        y_test = torch.tensor(y_test.values)

        # make datasets
        train_dataset = TensorDataset(X_train, y_train)
        test_dataset = TensorDataset(X_test, y_test)

        # Create DataLoaders
        train_loader = DataLoader(train_dataset, batch_size=batchsize, shuffle=False)
        test_loader = DataLoader(test_dataset, batch_size=batchsize, shuffle=False)

        # Define the number of time steps for the spiking
        num_steps = 50
        num_inputs = X_train.shape[2]

        # create new inctance of the SNN Class
        model = Net(num_inputs, num_steps).to(device)

        # define optimizer
        optimizer = torch.optim.Adam(params=model.parameters(), lr=1e-3)

        # define loss function
        def quantile_loss(y_true, y_pred, quantile=0.5):
            error = y_true - y_pred
            loss = torch.mean(torch.max(quantile * error, (quantile - 1) * error))
            return loss
        loss_fn = quantile_loss
        #loss_fn = torch.nn.MSELoss()
        #loss_fn = torch.nn.L1Loss()

        # initialize histories
        loss_hist = []
        avg_loss_hist = []
        acc_hist = []
        mape_hist = []
        num_epochs = 25

        # put model into train mode
        model.train()

        # Train Loop
        for epoch in range(num_epochs):
            for i, (data, targets) in enumerate(iter(train_loader)):
                # move to device
                data = data.to(device)
                targets = targets.to(device)

                # change to floats
                data = data.float()
                targets = targets.float()

                # run forward pass
                _, _, _, mem = model(data)
                # calculate loss
                loss_val = loss_fn(mem[-1], targets)

                # calculate and store MAPE Loss
                mem_numpy = mem.cpu().detach().numpy()
                #mem_numpy = mem.detach().numpy()
                targets_numpy = targets.cpu().detach().numpy()
                #targets_numpy = targets.detach().numpy()
                mape_hist.append(MAPE(mem_numpy[-1], targets_numpy))
                power_mape.append(MAPE(mem_numpy[-1][:,0], targets_numpy[:,0]))
                voltage_mape.append(MAPE(mem_numpy[-1][:,1], targets_numpy[:,1]))
                current_mape.append(MAPE(mem_numpy[-1][:,2], targets_numpy[:,2]))

                # Gradient calculation + weight update
                optimizer.zero_grad()
                loss_val.backward()
                optimizer.step()

                # Store loss history for future plotting
                loss_hist.append(loss_val.item())

                if i%10 == 0:
                    print(f"Epoch {epoch}, Iteration {i} Train Loss: {loss_val.item():.2f}")
                if len(loss_hist) > 100:
                    avg_loss_hist.append(sum(loss_hist[-100:])/len(loss_hist[-100:]))
                else:
                    avg_loss_hist.append(0)

            if len(loss_hist) > 100:
                print(f'New Epoch! Avg loss for the last 100 iterations: {avg_loss_hist[-1]}')
# Out:
# 3min
# Epoch 0, Iteration 0 Train Loss: 10971.40
# Epoch 0, Iteration 10 Train Loss: 915.95
# Epoch 0, Iteration 20 Train Loss: 762.81
# Epoch 0, Iteration 30 Train Loss: 1777.55
# Epoch 0, Iteration 40 Train Loss: 1382.86
# Epoch 0, Iteration 50 Train Loss: 902.26
# Epoch 0, Iteration 60 Train Loss: 1050.10
# Epoch 0, Iteration 70 Train Loss: 1094.10
# Epoch 0, Iteration 80 Train Loss: 1182.41
# Epoch 0, Iteration 90 Train Loss: 931.53
# Epoch 0, Iteration 100 Train Loss: 834.55
# Epoch 0, Iteration 110 Train Loss: 732.78
# Epoch 0, Iteration 120 Train Loss: 791.05
# Epoch 0, Iteration 130 Train Loss: 764.48
# Epoch 0, Iteration 140 Train Loss: 524.42
# Epoch 0, Iteration 150 Train Loss: 443.54
# Epoch 0, Iteration 160 Train Loss: 457.31
# Epoch 0, Iteration 170 Train Loss: 485.84
# New Epoch! Avg loss for the last 100 iterations: 742.8388580322265
# Epoch 1, Iteration 0 Train Loss: 10677.97
# Epoch 1, Iteration 10 Train Loss: 606.98
# Epoch 1, Iteration 20 Train Loss: 441.39
# Epoch 1, Iteration 30 Train Loss: 1435.31
# Epoch 1, Iteration 40 Train Loss: 1027.10
# Epoch 1, Iteration 50 Train Loss: 522.75
# Epoch 1, Iteration 60 Train Loss: 649.82
# Epoch 1, Iteration 70 Train Loss: 673.15
# Epoch 1, Iteration 80 Train Loss: 745.56
# Epoch 1, Iteration 90 Train Loss: 486.50
# Epoch 1, Iteration 100 Train Loss: 399.94
# Epoch 1, Iteration 110 Train Loss: 310.88
# Epoch 1, Iteration 120 Train Loss: 353.42
# Epoch 1, Iteration 130 Train Loss: 351.15
# Epoch 1, Iteration 140 Train Loss: 284.46
# Epoch 1, Iteration 150 Train Loss: 253.11
# Epoch 1, Iteration 160 Train Loss: 289.28
# Epoch 1, Iteration 170 Train Loss: 274.17
# New Epoch! Avg loss for the last 100 iterations: 390.1534860229492
# Epoch 2, Iteration 0 Train Loss: 10445.59
# Epoch 2, Iteration 10 Train Loss: 444.95
# Epoch 2, Iteration 20 Train Loss: 245.20
# Epoch 2, Iteration 30 Train Loss: 1253.51
# Epoch 2, Iteration 40 Train Loss: 922.61
# Epoch 2, Iteration 50 Train Loss: 359.14
# Epoch 2, Iteration 60 Train Loss: 512.66
# Epoch 2, Iteration 70 Train Loss: 529.59
# Epoch 2, Iteration 80 Train Loss: 593.34
# Epoch 2, Iteration 90 Train Loss: 331.45
# Epoch 2, Iteration 100 Train Loss: 256.08
# Epoch 2, Iteration 110 Train Loss: 192.93
# Epoch 2, Iteration 120 Train Loss: 212.21
# Epoch 2, Iteration 130 Train Loss: 257.68
# Epoch 2, Iteration 140 Train Loss: 295.46
# Epoch 2, Iteration 150 Train Loss: 270.03
# Epoch 2, Iteration 160 Train Loss: 295.32
# Epoch 2, Iteration 170 Train Loss: 215.55
# New Epoch! Avg loss for the last 100 iterations: 295.0554278564453
# Epoch 3, Iteration 0 Train Loss: 10318.11
# Epoch 3, Iteration 10 Train Loss: 383.85
# Epoch 3, Iteration 20 Train Loss: 164.56
# Epoch 3, Iteration 30 Train Loss: 1175.55
# Epoch 3, Iteration 40 Train Loss: 881.52
# Epoch 3, Iteration 50 Train Loss: 292.08
# Epoch 3, Iteration 60 Train Loss: 446.25
# Epoch 3, Iteration 70 Train Loss: 482.59
# Epoch 3, Iteration 80 Train Loss: 518.44
# Epoch 3, Iteration 90 Train Loss: 249.19
# Epoch 3, Iteration 100 Train Loss: 232.39
# Epoch 3, Iteration 110 Train Loss: 160.15
# Epoch 3, Iteration 120 Train Loss: 147.50
# Epoch 3, Iteration 130 Train Loss: 265.16
# Epoch 3, Iteration 140 Train Loss: 316.11
# Epoch 3, Iteration 150 Train Loss: 293.28
# Epoch 3, Iteration 160 Train Loss: 310.31
# Epoch 3, Iteration 170 Train Loss: 227.37
# New Epoch! Avg loss for the last 100 iterations: 264.203352355957
# Epoch 4, Iteration 0 Train Loss: 10248.49
# Epoch 4, Iteration 10 Train Loss: 353.92
# Epoch 4, Iteration 20 Train Loss: 139.31
# Epoch 4, Iteration 30 Train Loss: 1141.45
# Epoch 4, Iteration 40 Train Loss: 861.59
# Epoch 4, Iteration 50 Train Loss: 263.76
# Epoch 4, Iteration 60 Train Loss: 412.40
# Epoch 4, Iteration 70 Train Loss: 463.77
# Epoch 4, Iteration 80 Train Loss: 484.84
# Epoch 4, Iteration 90 Train Loss: 213.56
# Epoch 4, Iteration 100 Train Loss: 231.03
# Epoch 4, Iteration 110 Train Loss: 156.97
# Epoch 4, Iteration 120 Train Loss: 142.70
# Epoch 4, Iteration 130 Train Loss: 273.50
# Epoch 4, Iteration 140 Train Loss: 331.28
# Epoch 4, Iteration 150 Train Loss: 310.36
# Epoch 4, Iteration 160 Train Loss: 321.47
# Epoch 4, Iteration 170 Train Loss: 240.41
# New Epoch! Avg loss for the last 100 iterations: 256.6750114440918
# Epoch 5, Iteration 0 Train Loss: 10213.23
# Epoch 5, Iteration 10 Train Loss: 338.73
# Epoch 5, Iteration 20 Train Loss: 141.08
# Epoch 5, Iteration 30 Train Loss: 1125.24
# Epoch 5, Iteration 40 Train Loss: 850.28
# Epoch 5, Iteration 50 Train Loss: 249.62
# Epoch 5, Iteration 60 Train Loss: 395.01
# Epoch 5, Iteration 70 Train Loss: 456.49
# Epoch 5, Iteration 80 Train Loss: 468.01
# Epoch 5, Iteration 90 Train Loss: 201.79
# Epoch 5, Iteration 100 Train Loss: 232.06
# Epoch 5, Iteration 110 Train Loss: 161.29
# Epoch 5, Iteration 120 Train Loss: 151.05
# Epoch 5, Iteration 130 Train Loss: 279.11
# Epoch 5, Iteration 140 Train Loss: 339.88
# Epoch 5, Iteration 150 Train Loss: 320.20
# Epoch 5, Iteration 160 Train Loss: 328.34
# Epoch 5, Iteration 170 Train Loss: 247.93
# New Epoch! Avg loss for the last 100 iterations: 255.48306694030762
# Epoch 6, Iteration 0 Train Loss: 10196.55
# Epoch 6, Iteration 10 Train Loss: 330.98
# Epoch 6, Iteration 20 Train Loss: 145.29
# Epoch 6, Iteration 30 Train Loss: 1117.56
# Epoch 6, Iteration 40 Train Loss: 844.09
# Epoch 6, Iteration 50 Train Loss: 242.35
# Epoch 6, Iteration 60 Train Loss: 386.20
# Epoch 6, Iteration 70 Train Loss: 454.54
# Epoch 6, Iteration 80 Train Loss: 459.49
# Epoch 6, Iteration 90 Train Loss: 197.65
# Epoch 6, Iteration 100 Train Loss: 233.05
# Epoch 6, Iteration 110 Train Loss: 166.22
# Epoch 6, Iteration 120 Train Loss: 156.51
# Epoch 6, Iteration 130 Train Loss: 282.83
# Epoch 6, Iteration 140 Train Loss: 344.79
# Epoch 6, Iteration 150 Train Loss: 325.58
# Epoch 6, Iteration 160 Train Loss: 332.39
# Epoch 6, Iteration 170 Train Loss: 252.27
# New Epoch! Avg loss for the last 100 iterations: 255.77916542053222
# Epoch 7, Iteration 0 Train Loss: 10188.04
# Epoch 7, Iteration 10 Train Loss: 326.70
# Epoch 7, Iteration 20 Train Loss: 148.09
# Epoch 7, Iteration 30 Train Loss: 1113.39
# Epoch 7, Iteration 40 Train Loss: 840.46
# Epoch 7, Iteration 50 Train Loss: 238.24
# Epoch 7, Iteration 60 Train Loss: 381.39
# Epoch 7, Iteration 70 Train Loss: 453.26
# Epoch 7, Iteration 80 Train Loss: 454.86
# Epoch 7, Iteration 90 Train Loss: 195.79
# Epoch 7, Iteration 100 Train Loss: 233.74
# Epoch 7, Iteration 110 Train Loss: 169.77
# Epoch 7, Iteration 120 Train Loss: 159.85
# Epoch 7, Iteration 130 Train Loss: 285.39
# Epoch 7, Iteration 140 Train Loss: 347.79
# Epoch 7, Iteration 150 Train Loss: 328.79
# Epoch 7, Iteration 160 Train Loss: 334.97
# Epoch 7, Iteration 170 Train Loss: 254.95
# New Epoch! Avg loss for the last 100 iterations: 256.2976567077637
# Epoch 8, Iteration 0 Train Loss: 10183.41
# Epoch 8, Iteration 10 Train Loss: 324.08
# Epoch 8, Iteration 20 Train Loss: 149.77
# Epoch 8, Iteration 30 Train Loss: 1110.88
# Epoch 8, Iteration 40 Train Loss: 838.11
# Epoch 8, Iteration 50 Train Loss: 235.68
# Epoch 8, Iteration 60 Train Loss: 378.52
# Epoch 8, Iteration 70 Train Loss: 452.24
# Epoch 8, Iteration 80 Train Loss: 452.15
# Epoch 8, Iteration 90 Train Loss: 194.93
# Epoch 8, Iteration 100 Train Loss: 234.23
# Epoch 8, Iteration 110 Train Loss: 172.18
# Epoch 8, Iteration 120 Train Loss: 162.12
# Epoch 8, Iteration 130 Train Loss: 287.34
# Epoch 8, Iteration 140 Train Loss: 349.85
# Epoch 8, Iteration 150 Train Loss: 330.94
# Epoch 8, Iteration 160 Train Loss: 336.84
# Epoch 8, Iteration 170 Train Loss: 256.84
# New Epoch! Avg loss for the last 100 iterations: 256.81769546508787
# Epoch 9, Iteration 0 Train Loss: 10180.63
# Epoch 9, Iteration 10 Train Loss: 322.27
# Epoch 9, Iteration 20 Train Loss: 150.90
# Epoch 9, Iteration 30 Train Loss: 1109.22
# Epoch 9, Iteration 40 Train Loss: 836.42
# Epoch 9, Iteration 50 Train Loss: 233.91
# Epoch 9, Iteration 60 Train Loss: 376.64
# Epoch 9, Iteration 70 Train Loss: 451.40
# Epoch 9, Iteration 80 Train Loss: 450.42
# Epoch 9, Iteration 90 Train Loss: 194.51
# Epoch 9, Iteration 100 Train Loss: 234.60
# Epoch 9, Iteration 110 Train Loss: 173.74
# Epoch 9, Iteration 120 Train Loss: 163.66
# Epoch 9, Iteration 130 Train Loss: 288.75
# Epoch 9, Iteration 140 Train Loss: 351.24
# Epoch 9, Iteration 150 Train Loss: 332.34
# Epoch 9, Iteration 160 Train Loss: 338.11
# Epoch 9, Iteration 170 Train Loss: 258.12
# New Epoch! Avg loss for the last 100 iterations: 257.21146789550784
# Epoch 10, Iteration 0 Train Loss: 10178.90
# Epoch 10, Iteration 10 Train Loss: 321.03
# Epoch 10, Iteration 20 Train Loss: 151.66
# Epoch 10, Iteration 30 Train Loss: 1108.11
# Epoch 10, Iteration 40 Train Loss: 835.24
# Epoch 10, Iteration 50 Train Loss: 232.68
# Epoch 10, Iteration 60 Train Loss: 375.37
# Epoch 10, Iteration 70 Train Loss: 450.78
# Epoch 10, Iteration 80 Train Loss: 449.26
# Epoch 10, Iteration 90 Train Loss: 194.27
# Epoch 10, Iteration 100 Train Loss: 234.86
# Epoch 10, Iteration 110 Train Loss: 174.86
# Epoch 10, Iteration 120 Train Loss: 164.75
# Epoch 10, Iteration 130 Train Loss: 289.74
# Epoch 10, Iteration 140 Train Loss: 352.18
# Epoch 10, Iteration 150 Train Loss: 333.30
# Epoch 10, Iteration 160 Train Loss: 338.98
# Epoch 10, Iteration 170 Train Loss: 258.97
# New Epoch! Avg loss for the last 100 iterations: 257.49335418701173
# Epoch 11, Iteration 0 Train Loss: 10177.72
# Epoch 11, Iteration 10 Train Loss: 320.21
# Epoch 11, Iteration 20 Train Loss: 152.19
# Epoch 11, Iteration 30 Train Loss: 1107.39
# Epoch 11, Iteration 40 Train Loss: 834.48
# Epoch 11, Iteration 50 Train Loss: 231.88
# Epoch 11, Iteration 60 Train Loss: 374.55
# Epoch 11, Iteration 70 Train Loss: 450.36
# Epoch 11, Iteration 80 Train Loss: 448.52
# Epoch 11, Iteration 90 Train Loss: 194.16
# Epoch 11, Iteration 100 Train Loss: 235.04
# Epoch 11, Iteration 110 Train Loss: 175.58
# Epoch 11, Iteration 120 Train Loss: 165.47
# Epoch 11, Iteration 130 Train Loss: 290.37
# Epoch 11, Iteration 140 Train Loss: 352.76
# Epoch 11, Iteration 150 Train Loss: 333.89
# Epoch 11, Iteration 160 Train Loss: 339.51
# Epoch 11, Iteration 170 Train Loss: 259.50
# New Epoch! Avg loss for the last 100 iterations: 257.67290161132814
# Epoch 12, Iteration 0 Train Loss: 10176.94
# Epoch 12, Iteration 10 Train Loss: 319.71
# Epoch 12, Iteration 20 Train Loss: 152.52
# Epoch 12, Iteration 30 Train Loss: 1106.96
# Epoch 12, Iteration 40 Train Loss: 834.01
# Epoch 12, Iteration 50 Train Loss: 231.38
# Epoch 12, Iteration 60 Train Loss: 374.03
# Epoch 12, Iteration 70 Train Loss: 450.09
# Epoch 12, Iteration 80 Train Loss: 448.05
# Epoch 12, Iteration 90 Train Loss: 194.10
# Epoch 12, Iteration 100 Train Loss: 235.16
# Epoch 12, Iteration 110 Train Loss: 176.03
# Epoch 12, Iteration 120 Train Loss: 165.93
# Epoch 12, Iteration 130 Train Loss: 290.79
# Epoch 12, Iteration 140 Train Loss: 353.15
# Epoch 12, Iteration 150 Train Loss: 334.28
# Epoch 12, Iteration 160 Train Loss: 339.85
# Epoch 12, Iteration 170 Train Loss: 259.84
# New Epoch! Avg loss for the last 100 iterations: 257.7944913482666
# Epoch 13, Iteration 0 Train Loss: 10176.41
# Epoch 13, Iteration 10 Train Loss: 319.40
# Epoch 13, Iteration 20 Train Loss: 152.75
# Epoch 13, Iteration 30 Train Loss: 1106.67
# Epoch 13, Iteration 40 Train Loss: 833.66
# Epoch 13, Iteration 50 Train Loss: 231.01
# Epoch 13, Iteration 60 Train Loss: 373.67
# Epoch 13, Iteration 70 Train Loss: 449.87
# Epoch 13, Iteration 80 Train Loss: 447.74
# Epoch 13, Iteration 90 Train Loss: 194.09
# Epoch 13, Iteration 100 Train Loss: 235.25
# Epoch 13, Iteration 110 Train Loss: 176.36
# Epoch 13, Iteration 120 Train Loss: 166.27
# Epoch 13, Iteration 130 Train Loss: 291.11
# Epoch 13, Iteration 140 Train Loss: 353.42
# Epoch 13, Iteration 150 Train Loss: 334.55
# Epoch 13, Iteration 160 Train Loss: 340.10
# Epoch 13, Iteration 170 Train Loss: 260.08
# New Epoch! Avg loss for the last 100 iterations: 257.88532165527346
# Epoch 14, Iteration 0 Train Loss: 10176.04
# Epoch 14, Iteration 10 Train Loss: 319.18
# Epoch 14, Iteration 20 Train Loss: 152.91
# Epoch 14, Iteration 30 Train Loss: 1106.40
# Epoch 14, Iteration 40 Train Loss: 833.43
# Epoch 14, Iteration 50 Train Loss: 230.13
# Epoch 14, Iteration 60 Train Loss: 372.44
# Epoch 14, Iteration 70 Train Loss: 447.67
# Epoch 14, Iteration 80 Train Loss: 445.55
# Epoch 14, Iteration 90 Train Loss: 194.24
# Epoch 14, Iteration 100 Train Loss: 236.41
# Epoch 14, Iteration 110 Train Loss: 179.37
# Epoch 14, Iteration 120 Train Loss: 169.15
# Epoch 14, Iteration 130 Train Loss: 294.08
# Epoch 14, Iteration 140 Train Loss: 355.54
# Epoch 14, Iteration 150 Train Loss: 335.99
# Epoch 14, Iteration 160 Train Loss: 340.98
# Epoch 14, Iteration 170 Train Loss: 260.68
# New Epoch! Avg loss for the last 100 iterations: 258.57847732543945
# Epoch 15, Iteration 0 Train Loss: 10175.67
# Epoch 15, Iteration 10 Train Loss: 318.86
# Epoch 15, Iteration 20 Train Loss: 153.31
# Epoch 15, Iteration 30 Train Loss: 1106.24
# Epoch 15, Iteration 40 Train Loss: 833.03
# Epoch 15, Iteration 50 Train Loss: 229.96
# Epoch 15, Iteration 60 Train Loss: 372.48
# Epoch 15, Iteration 70 Train Loss: 448.63
# Epoch 15, Iteration 80 Train Loss: 446.24
# Epoch 15, Iteration 90 Train Loss: 194.09
# Epoch 15, Iteration 100 Train Loss: 235.89
# Epoch 15, Iteration 110 Train Loss: 178.25
# Epoch 15, Iteration 120 Train Loss: 168.09
# Epoch 15, Iteration 130 Train Loss: 292.88
# Epoch 15, Iteration 140 Train Loss: 354.79
# Epoch 15, Iteration 150 Train Loss: 335.58
# Epoch 15, Iteration 160 Train Loss: 340.63
# Epoch 15, Iteration 170 Train Loss: 258.12
# New Epoch! Avg loss for the last 100 iterations: 258.22610931396486
# Epoch 16, Iteration 0 Train Loss: 10175.44
# Epoch 16, Iteration 10 Train Loss: 321.76
# Epoch 16, Iteration 20 Train Loss: 141.38
# Epoch 16, Iteration 30 Train Loss: 1109.25
# Epoch 16, Iteration 40 Train Loss: 840.18
# Epoch 16, Iteration 50 Train Loss: 232.32
# Epoch 16, Iteration 60 Train Loss: 376.21
# Epoch 16, Iteration 70 Train Loss: 453.31
# Epoch 16, Iteration 80 Train Loss: 473.43
# Epoch 16, Iteration 90 Train Loss: 194.48
# Epoch 16, Iteration 100 Train Loss: 235.71
# Epoch 16, Iteration 110 Train Loss: 175.71
# Epoch 16, Iteration 120 Train Loss: 164.42
# Epoch 16, Iteration 130 Train Loss: 290.37
# Epoch 16, Iteration 140 Train Loss: 352.33
# Epoch 16, Iteration 150 Train Loss: 311.43
# Epoch 16, Iteration 160 Train Loss: 293.22
# Epoch 16, Iteration 170 Train Loss: 218.04
# New Epoch! Avg loss for the last 100 iterations: 250.6683000946045
# Epoch 17, Iteration 0 Train Loss: 10161.21
# Epoch 17, Iteration 10 Train Loss: 312.97
# Epoch 17, Iteration 20 Train Loss: 142.21
# Epoch 17, Iteration 30 Train Loss: 1099.46
# Epoch 17, Iteration 40 Train Loss: 824.19
# Epoch 17, Iteration 50 Train Loss: 221.89
# Epoch 17, Iteration 60 Train Loss: 363.79
# Epoch 17, Iteration 70 Train Loss: 449.65
# Epoch 17, Iteration 80 Train Loss: 477.79
# Epoch 17, Iteration 90 Train Loss: 186.78
# Epoch 17, Iteration 100 Train Loss: 235.96
# Epoch 17, Iteration 110 Train Loss: 163.07
# Epoch 17, Iteration 120 Train Loss: 155.50
# Epoch 17, Iteration 130 Train Loss: 280.95
# Epoch 17, Iteration 140 Train Loss: 330.88
# Epoch 17, Iteration 150 Train Loss: 268.44
# Epoch 17, Iteration 160 Train Loss: 259.34
# Epoch 17, Iteration 170 Train Loss: 204.79
# New Epoch! Avg loss for the last 100 iterations: 242.360863571167
# Epoch 18, Iteration 0 Train Loss: 10133.57
# Epoch 18, Iteration 10 Train Loss: 302.05
# Epoch 18, Iteration 20 Train Loss: 138.71
# Epoch 18, Iteration 30 Train Loss: 1087.95
# Epoch 18, Iteration 40 Train Loss: 802.30
# Epoch 18, Iteration 50 Train Loss: 206.88
# Epoch 18, Iteration 60 Train Loss: 344.18
# Epoch 18, Iteration 70 Train Loss: 438.61
# Epoch 18, Iteration 80 Train Loss: 463.18
# Epoch 18, Iteration 90 Train Loss: 185.47
# Epoch 18, Iteration 100 Train Loss: 250.79
# Epoch 18, Iteration 110 Train Loss: 172.65
# Epoch 18, Iteration 120 Train Loss: 148.47
# Epoch 18, Iteration 130 Train Loss: 258.32
# Epoch 18, Iteration 140 Train Loss: 238.12
# Epoch 18, Iteration 150 Train Loss: 177.16
# Epoch 18, Iteration 160 Train Loss: 204.96
# Epoch 18, Iteration 170 Train Loss: 213.27
# New Epoch! Avg loss for the last 100 iterations: 224.14679954528808
# Epoch 19, Iteration 0 Train Loss: 10103.65
# Epoch 19, Iteration 10 Train Loss: 284.27
# Epoch 19, Iteration 20 Train Loss: 195.08
# Epoch 19, Iteration 30 Train Loss: 1080.88
# Epoch 19, Iteration 40 Train Loss: 784.91
# Epoch 19, Iteration 50 Train Loss: 197.24
# Epoch 19, Iteration 60 Train Loss: 329.92
# Epoch 19, Iteration 70 Train Loss: 430.01
# Epoch 19, Iteration 80 Train Loss: 402.22
# Epoch 19, Iteration 90 Train Loss: 186.77
# Epoch 19, Iteration 100 Train Loss: 242.17
# Epoch 19, Iteration 110 Train Loss: 208.05
# Epoch 19, Iteration 120 Train Loss: 172.97
# Epoch 19, Iteration 130 Train Loss: 206.25
# Epoch 19, Iteration 140 Train Loss: 238.07
# Epoch 19, Iteration 150 Train Loss: 189.92
# Epoch 19, Iteration 160 Train Loss: 186.13
# Epoch 19, Iteration 170 Train Loss: 195.92
# New Epoch! Avg loss for the last 100 iterations: 214.12556381225585
# Epoch 20, Iteration 0 Train Loss: 10109.71
# Epoch 20, Iteration 10 Train Loss: 273.63
# Epoch 20, Iteration 20 Train Loss: 190.15
# Epoch 20, Iteration 30 Train Loss: 1075.45
# Epoch 20, Iteration 40 Train Loss: 772.51
# Epoch 20, Iteration 50 Train Loss: 186.76
# Epoch 20, Iteration 60 Train Loss: 323.15
# Epoch 20, Iteration 70 Train Loss: 417.08
# Epoch 20, Iteration 80 Train Loss: 396.28
# Epoch 20, Iteration 90 Train Loss: 189.21
# Epoch 20, Iteration 100 Train Loss: 240.92
# Epoch 20, Iteration 110 Train Loss: 142.11
# Epoch 20, Iteration 120 Train Loss: 133.46
# Epoch 20, Iteration 130 Train Loss: 175.48
# Epoch 20, Iteration 140 Train Loss: 218.77
# Epoch 20, Iteration 150 Train Loss: 172.31
# Epoch 20, Iteration 160 Train Loss: 175.40
# Epoch 20, Iteration 170 Train Loss: 187.84
# New Epoch! Avg loss for the last 100 iterations: 203.08940757751463
# Epoch 21, Iteration 0 Train Loss: 10102.89
# Epoch 21, Iteration 10 Train Loss: 252.42
# Epoch 21, Iteration 20 Train Loss: 201.11
# Epoch 21, Iteration 30 Train Loss: 1066.33
# Epoch 21, Iteration 40 Train Loss: 748.65
# Epoch 21, Iteration 50 Train Loss: 174.85
# Epoch 21, Iteration 60 Train Loss: 310.11
# Epoch 21, Iteration 70 Train Loss: 400.85
# Epoch 21, Iteration 80 Train Loss: 385.95
# Epoch 21, Iteration 90 Train Loss: 180.56
# Epoch 21, Iteration 100 Train Loss: 243.88
# Epoch 21, Iteration 110 Train Loss: 134.38
# Epoch 21, Iteration 120 Train Loss: 177.02
# Epoch 21, Iteration 130 Train Loss: 166.45
# Epoch 21, Iteration 140 Train Loss: 225.21
# Epoch 21, Iteration 150 Train Loss: 161.63
# Epoch 21, Iteration 160 Train Loss: 169.01
# Epoch 21, Iteration 170 Train Loss: 182.06
# New Epoch! Avg loss for the last 100 iterations: 199.25642448425293
# Epoch 22, Iteration 0 Train Loss: 10097.70
# Epoch 22, Iteration 10 Train Loss: 240.33
# Epoch 22, Iteration 20 Train Loss: 207.83
# Epoch 22, Iteration 30 Train Loss: 1060.27
# Epoch 22, Iteration 40 Train Loss: 729.28
# Epoch 22, Iteration 50 Train Loss: 165.78
# Epoch 22, Iteration 60 Train Loss: 300.81
# Epoch 22, Iteration 70 Train Loss: 387.93
# Epoch 22, Iteration 80 Train Loss: 378.46
# Epoch 22, Iteration 90 Train Loss: 174.20
# Epoch 22, Iteration 100 Train Loss: 242.64
# Epoch 22, Iteration 110 Train Loss: 121.93
# Epoch 22, Iteration 120 Train Loss: 144.95
# Epoch 22, Iteration 130 Train Loss: 154.10
# Epoch 22, Iteration 140 Train Loss: 199.29
# Epoch 22, Iteration 150 Train Loss: 153.62
# Epoch 22, Iteration 160 Train Loss: 158.44
# Epoch 22, Iteration 170 Train Loss: 181.61
# New Epoch! Avg loss for the last 100 iterations: 193.7404234313965
# Epoch 23, Iteration 0 Train Loss: 10096.77
# Epoch 23, Iteration 10 Train Loss: 233.16
# Epoch 23, Iteration 20 Train Loss: 234.01
# Epoch 23, Iteration 30 Train Loss: 1062.23
# Epoch 23, Iteration 40 Train Loss: 715.56
# Epoch 23, Iteration 50 Train Loss: 157.19
# Epoch 23, Iteration 60 Train Loss: 291.22
# Epoch 23, Iteration 70 Train Loss: 384.60
# Epoch 23, Iteration 80 Train Loss: 371.51
# Epoch 23, Iteration 90 Train Loss: 193.66
# Epoch 23, Iteration 100 Train Loss: 232.95
# Epoch 23, Iteration 110 Train Loss: 156.10
# Epoch 23, Iteration 120 Train Loss: 118.47
# Epoch 23, Iteration 130 Train Loss: 206.13
# Epoch 23, Iteration 140 Train Loss: 199.26
# Epoch 23, Iteration 150 Train Loss: 152.97
# Epoch 23, Iteration 160 Train Loss: 150.75
# Epoch 23, Iteration 170 Train Loss: 179.19
# New Epoch! Avg loss for the last 100 iterations: 193.4811434173584
# Epoch 24, Iteration 0 Train Loss: 10102.63
# Epoch 24, Iteration 10 Train Loss: 227.71
# Epoch 24, Iteration 20 Train Loss: 198.58
# Epoch 24, Iteration 30 Train Loss: 1052.17
# Epoch 24, Iteration 40 Train Loss: 709.59
# Epoch 24, Iteration 50 Train Loss: 162.19
# Epoch 24, Iteration 60 Train Loss: 294.28
# Epoch 24, Iteration 70 Train Loss: 369.12
# Epoch 24, Iteration 80 Train Loss: 372.93
# Epoch 24, Iteration 90 Train Loss: 167.16
# Epoch 24, Iteration 100 Train Loss: 230.00
# Epoch 24, Iteration 110 Train Loss: 142.95
# Epoch 24, Iteration 120 Train Loss: 123.90
# Epoch 24, Iteration 130 Train Loss: 202.61
# Epoch 24, Iteration 140 Train Loss: 157.71
# Epoch 24, Iteration 150 Train Loss: 149.74
# Epoch 24, Iteration 160 Train Loss: 144.29
# Epoch 24, Iteration 170 Train Loss: 180.32
# New Epoch! Avg loss for the last 100 iterations: 189.68568572998046

# %%
#Save model
checkpoint = {'state_dict': model.state_dict(),'optimizer' :optimizer.state_dict()}
torch.save(checkpoint, 'snn_30min_quant50.pth')
# %mv snn_30min_quant50.pth 'trained_models'

# %% [markdown]
# ###  2.2 TSRV on Type 1 Models

# %%
print(df.columns)
# Out:
# Index(['sensorID', 'raw_VWC', 'temp', 'EC', 'I1L_valid', 'I2L_valid',
#        'I1H [nA]', 'Current (uA)', 'Voltage (mV)', 'V2 [10nV]', 'I2H [nA]',
#        'I2L [10pA]', 'tsd', 'hour', 'Power (uW)', 'power - 1h', 'power - 2h',
#        'power - 3h', 'EC - 1h', 'EC - 2h', 'EC - 3h', 'temp - 1h', 'temp - 2h',
#        'temp - 3h', 'raw_VWC - 1h', 'raw_VWC - 2h', 'raw_VWC - 3h', 'V1 - 1h',
#        'V1 - 2h', 'V1 - 3h', 'I1L - 1h', 'I1L - 2h', 'I1L - 3h', 'I1H - 1h',
#        'I1H - 2h', 'I1H - 3h'],
#       dtype='object')

# %%
power_mape = []
voltage_mape = []
current_mape = []

E_actual_list = []
E_pred_list = []

max_act_list = []
pred_act_list = []
succ_act_list = []

pred_act_naive_list = []
false_act_naive_list = []
succ_act_naive_list = []

#Set parameters
batchsize = 8
time_frame = '60min'
time_frame_seconds = 3600
n = 0
splits = TimeSeriesSplit(n_splits=4)
for train_index, test_index in splits.split(X):
    n += 1
    if n >= 1:
        #Split train and test sets
        X_train = X.iloc[train_index]
        X_test = X.iloc[test_index]
        y_train = y.iloc[train_index]
        y_test = y.iloc[test_index]

        X_valid, X_test = train_test_split(X_test, test_size=0.5, shuffle=False)
        y_valid, y_test = train_test_split(y_test, test_size=0.5, shuffle=False)

        #Set dataset bounds
        train_bound_lower = y_train.index[0]
        train_bound_upper = y_train.index[-1]
        valid_bound_lower = y_valid.index[0]
        valid_bound_upper = y_valid.index[-1]
        test_bound_lower = y_test.index[0]
        test_bound_upper = y_test.index[-1]

        #Resample data
        X_train = X_train.resample(time_frame).mean().dropna()
        X_valid = X_valid.resample(time_frame).mean().dropna()
        X_test = X_test.resample(time_frame).mean().dropna()

        y_train = y_train.resample(time_frame).mean().dropna()
        y_valid = y_valid.resample(time_frame).mean().dropna()
        y_test = y_test.resample(time_frame).mean().dropna()

        #Reshape data
        X_train = X_train.values.reshape((X_train.shape[0], 1, X_train.shape[1]))
        X_valid = X_valid.values.reshape((X_valid.shape[0], 1, X_valid.shape[1]))
        X_test = X_test.values.reshape((X_test.shape[0], 1, X_test.shape[1]))

        # convert to tensor
        X_train = torch.tensor(X_train)
        y_train_index_labels = y_train.index
        y_train_column_labels = y_train.columns
        y_train = torch.tensor(y_train.values)

        X_test = torch.tensor(X_test)
        y_test_index_labels = y_test.index
        y_test_column_labels = y_test.columns
        y_test = torch.tensor(y_test.values)

        # make datasets
        train_dataset = TensorDataset(X_train, y_train)
        test_dataset = TensorDataset(X_test, y_test)

        # Create DataLoaders
        train_loader = DataLoader(train_dataset, batch_size=batchsize, shuffle=False)
        test_loader = DataLoader(test_dataset, batch_size=batchsize, shuffle=False)

        # Define the number of time steps for the spiking
        num_steps = 50
        num_inputs = X_train.shape[2]

        # create new inctance of the SNN Class
        model = Net(num_inputs, num_steps).to(device)

        # define optimizer
        optimizer = torch.optim.Adam(params=model.parameters(), lr=1e-3)

        # define loss function
        def quantile_loss(y_true, y_pred, quantile=0.05):
            error = y_true - y_pred
            loss = torch.mean(torch.max(quantile * error, (quantile - 1) * error))
            return loss
        loss_fn = quantile_loss

        # initialize histories
        loss_hist = []
        avg_loss_hist = []
        acc_hist = []
        num_epochs = 25

        # put model into train mode
        model.train()

        # Train Loop
        for epoch in range(num_epochs):
            for i, (data, targets) in enumerate(iter(train_loader)):
                # move to device
                data = data.to(device)
                targets = targets.to(device)

                # change to floats
                data = data.float()
                targets = targets.float()

                _, _, _, mem = model(data)

                loss_val = loss_fn(mem[-1], targets)

                # Gradient calculation + weight update
                optimizer.zero_grad()
                loss_val.backward()
                optimizer.step()

                # Store loss history for future plotting
                loss_hist.append(loss_val.item())

                # Update loss plot
                # update_loss_plot(loss_hist)

                if i%10 == 0:
                    print(f"Epoch {epoch}, Iteration {i} Train Loss: {loss_val.item():.2f}")
                if len(loss_hist) > 100:
                    avg_loss_hist.append(sum(loss_hist[-100:])/len(loss_hist[-100:]))
                else:
                    avg_loss_hist.append(0)

            if len(loss_hist) > 100:
                print(f'New Epoch! Avg loss for the last 100 iterations: {avg_loss_hist[-1]}')

        # predictions
        model.eval()

        train_pred = []
        test_pred = []
        with torch.no_grad():
            for data, target in train_dataset:
                data = data.to(device)
                data = data.float()
                _, _, _, train_mem = model(data)
                train_pred.append(train_mem[-1])

            for data, target in test_dataset:
                data = data.to(device)
                data = data.float()
                _, _, _, test_mem = model(data)
                test_pred.append(test_mem[-1])

        # Convert to numpy
        train_pred = torch.cat(train_pred, dim=0)
        train_pred = train_pred.numpy()
        test_pred = torch.cat(test_pred, dim=0)
        test_pred = test_pred.numpy()

        # convert tensors back to dataframe
        y_test = pd.DataFrame(y_test, index=y_test_index_labels, columns=y_test_column_labels)
        y_train = pd.DataFrame(y_test, index=y_train_index_labels, columns=y_test_column_labels)

        #Prepare data for runtime simulation
        y_test['power pred'] = test_pred[:, 0]
        y_test['V1 [mV] pred'] = test_pred[:, 1]
        y_test['I1L [μA] pred'] = test_pred[:, 2]

        days  = getMFC_data(y_test, test_pred)

        v_test = df.loc[(((df.index >= test_bound_lower)) & (df.index <= test_bound_upper))]['Voltage (mV)']
        v_test = v_test.drop(v_test[(v_test.index > '2021-11-11') & (v_test.index < '2021-11-22 01:00:00')].index)
        v_test = pd.DataFrame(v_test)/1E5
        v_avg_true = v_test['Voltage (mV)'].resample(time_frame).mean().dropna()
        v_avg_pred = y_test['V1 [mV] pred']/1E5
        C0 = [0.007000000000000006, 0.007000000000000006, 0.007000000000000006]

        #Remove first and last entries of averaged data to prevent overestimation of available energy
        v_avg_true = v_avg_true[1:][:-1]
        v_avg_pred = v_avg_pred[1:][:-1]

        #Run oracle model
        max_act = oracle_simulate(v_test, C0)

        #Call simulate function
        pred_act, false_act, succ_act, total_E, total_E_pred = simulate(days, v_avg_true, v_avg_pred, v_test, C0)

        #Run naive model
        v_valid = df.loc[(((df.index >= valid_bound_lower)) & (df.index < valid_bound_upper))]['Voltage (mV)']/1E5
        pred_act_naive, false_act_naive, succ_act_naive, total_E = naive_simulate(days, v_avg_true, v_valid, v_test, C0)
        print("Dataset, train set, and test set size:", len(y_train) + len(y_valid) + len(y_test), len(y_train), len(y_test))
        print('Timeframe:', time_frame)

        print('Minimal Application')
        print("Naive vs. DL succesful activations:", succ_act/succ_act_naive)
        #print('Predicted vs. Actual percent difference: %.3f%%' % ((total_E * 100 / total_E_pred) - 100))
        print('Maximum possible activations:', max_act)
        print('Predicted activations:', pred_act)
        print('Successful activations: %d, %.3f%%' % (succ_act, succ_act * 100/pred_act))
        print('Failed activations: %d, %.3f%%' % (false_act, false_act * 100/pred_act))
        print('Missed activations: %d, %.3f%%' % (max_act - succ_act, (max_act - succ_act) * 100/max_act))

        #Naive model
        print('Naive predicted activations (usual actual energy average):', pred_act_naive)
        print('Naive successful activations (usual actual energy average): %d, %.3f%%' % (succ_act_naive, succ_act_naive * 100/pred_act_naive))
        print('Naive failed activations (usual actual energy average): %d, %.3f%%' % (false_act_naive, false_act_naive * 100/pred_act_naive))
        print('Naive missed activations (usual actual energy average): %d, %.3f%%' % (max_act - succ_act_naive, (max_act - succ_act_naive) * 100/max_act))


        print('Voltage overestimation rate: %.3f%%' % ((y_test['Voltage (mV)'].values <= y_test['Voltage (mV)']).mean() * 100))
        print("Test MAPE power: %3f" %  MAPE(y_test['Power (uW)'].values.ravel(), y_test['power pred']))
        print("Test MAPE voltage: %3f" % MAPE(y_test['Voltage (mV)'], y_test['V1 [mV] pred']))
        print("Test MAPE current: %3f" % MAPE(y_test['Current (uA)'], y_test['I1L [μA] pred']))
# Out:
# Epoch 0, Iteration 0 Train Loss: 22023.83
# Epoch 0, Iteration 10 Train Loss: 2211.05
# Epoch 0, Iteration 20 Train Loss: 1743.63
# Epoch 0, Iteration 30 Train Loss: 1186.39
# Epoch 0, Iteration 40 Train Loss: 1397.68
# Epoch 0, Iteration 50 Train Loss: 1696.61
# Epoch 0, Iteration 60 Train Loss: 1203.95
# Epoch 0, Iteration 70 Train Loss: 2920.93
# Epoch 0, Iteration 80 Train Loss: 1765.85
# Epoch 0, Iteration 90 Train Loss: 2137.57
# Epoch 1, Iteration 0 Train Loss: 21849.47
# Epoch 1, Iteration 10 Train Loss: 1908.69
# Epoch 1, Iteration 20 Train Loss: 1313.47
# Epoch 1, Iteration 30 Train Loss: 790.27
# Epoch 1, Iteration 40 Train Loss: 948.51
# Epoch 1, Iteration 50 Train Loss: 1170.54
# Epoch 1, Iteration 60 Train Loss: 748.62
# Epoch 1, Iteration 70 Train Loss: 2351.21
# Epoch 1, Iteration 80 Train Loss: 1193.84
# Epoch 1, Iteration 90 Train Loss: 1607.48
# New Epoch! Avg loss for the last 100 iterations: 2057.9776861572263
# Epoch 2, Iteration 0 Train Loss: 21298.33
# Epoch 2, Iteration 10 Train Loss: 1501.35
# Epoch 2, Iteration 20 Train Loss: 998.89
# Epoch 2, Iteration 30 Train Loss: 526.90
# Epoch 2, Iteration 40 Train Loss: 694.05
# Epoch 2, Iteration 50 Train Loss: 906.56
# Epoch 2, Iteration 60 Train Loss: 565.22
# Epoch 2, Iteration 70 Train Loss: 2069.83
# Epoch 2, Iteration 80 Train Loss: 941.65
# Epoch 2, Iteration 90 Train Loss: 1412.79
# New Epoch! Avg loss for the last 100 iterations: 1753.4434071350097
# Epoch 3, Iteration 0 Train Loss: 21021.34
# Epoch 3, Iteration 10 Train Loss: 1254.03
# Epoch 3, Iteration 20 Train Loss: 776.43
# Epoch 3, Iteration 30 Train Loss: 341.61
# Epoch 3, Iteration 40 Train Loss: 504.38
# Epoch 3, Iteration 50 Train Loss: 694.78
# Epoch 3, Iteration 60 Train Loss: 433.95
# Epoch 3, Iteration 70 Train Loss: 1866.21
# Epoch 3, Iteration 80 Train Loss: 742.02
# Epoch 3, Iteration 90 Train Loss: 1294.74
# New Epoch! Avg loss for the last 100 iterations: 1553.691488494873
# Epoch 4, Iteration 0 Train Loss: 20792.76
# Epoch 4, Iteration 10 Train Loss: 1045.38
# Epoch 4, Iteration 20 Train Loss: 587.03
# Epoch 4, Iteration 30 Train Loss: 211.01
# Epoch 4, Iteration 40 Train Loss: 374.11
# Epoch 4, Iteration 50 Train Loss: 512.57
# Epoch 4, Iteration 60 Train Loss: 345.38
# Epoch 4, Iteration 70 Train Loss: 1709.49
# Epoch 4, Iteration 80 Train Loss: 566.82
# Epoch 4, Iteration 90 Train Loss: 1202.57
# New Epoch! Avg loss for the last 100 iterations: 1398.1909908294679
# Epoch 5, Iteration 0 Train Loss: 20594.45
# Epoch 5, Iteration 10 Train Loss: 869.26
# Epoch 5, Iteration 20 Train Loss: 418.14
# Epoch 5, Iteration 30 Train Loss: 94.61
# Epoch 5, Iteration 40 Train Loss: 262.53
# Epoch 5, Iteration 50 Train Loss: 350.10
# Epoch 5, Iteration 60 Train Loss: 285.69
# Epoch 5, Iteration 70 Train Loss: 1589.61
# Epoch 5, Iteration 80 Train Loss: 411.78
# Epoch 5, Iteration 90 Train Loss: 1119.70
# New Epoch! Avg loss for the last 100 iterations: 1271.6241143798827
# Epoch 6, Iteration 0 Train Loss: 20420.51
# Epoch 6, Iteration 10 Train Loss: 736.21
# Epoch 6, Iteration 20 Train Loss: 262.49
# Epoch 6, Iteration 30 Train Loss: 46.19
# Epoch 6, Iteration 40 Train Loss: 180.54
# Epoch 6, Iteration 50 Train Loss: 204.07
# Epoch 6, Iteration 60 Train Loss: 242.43
# Epoch 6, Iteration 70 Train Loss: 1492.71
# Epoch 6, Iteration 80 Train Loss: 292.46
# Epoch 6, Iteration 90 Train Loss: 1046.36
# New Epoch! Avg loss for the last 100 iterations: 1174.1021392440796
# Epoch 7, Iteration 0 Train Loss: 20268.17
# Epoch 7, Iteration 10 Train Loss: 649.82
# Epoch 7, Iteration 20 Train Loss: 133.17
# Epoch 7, Iteration 30 Train Loss: 33.32
# Epoch 7, Iteration 40 Train Loss: 111.85
# Epoch 7, Iteration 50 Train Loss: 108.75
# Epoch 7, Iteration 60 Train Loss: 203.07
# Epoch 7, Iteration 70 Train Loss: 1413.04
# Epoch 7, Iteration 80 Train Loss: 212.59
# Epoch 7, Iteration 90 Train Loss: 981.11
# New Epoch! Avg loss for the last 100 iterations: 1106.282715549469
# Epoch 8, Iteration 0 Train Loss: 20145.85
# Epoch 8, Iteration 10 Train Loss: 583.18
# Epoch 8, Iteration 20 Train Loss: 59.40
# Epoch 8, Iteration 30 Train Loss: 38.59
# Epoch 8, Iteration 40 Train Loss: 59.53
# Epoch 8, Iteration 50 Train Loss: 61.00
# Epoch 8, Iteration 60 Train Loss: 166.90
# Epoch 8, Iteration 70 Train Loss: 1344.81
# Epoch 8, Iteration 80 Train Loss: 146.49
# Epoch 8, Iteration 90 Train Loss: 917.49
# New Epoch! Avg loss for the last 100 iterations: 1057.8584557723998
# Epoch 9, Iteration 0 Train Loss: 20040.42
# Epoch 9, Iteration 10 Train Loss: 526.99
# Epoch 9, Iteration 20 Train Loss: 29.11
# Epoch 9, Iteration 30 Train Loss: 44.20
# Epoch 9, Iteration 40 Train Loss: 34.05
# Epoch 9, Iteration 50 Train Loss: 41.97
# Epoch 9, Iteration 60 Train Loss: 139.37
# Epoch 9, Iteration 70 Train Loss: 1282.16
# Epoch 9, Iteration 80 Train Loss: 90.22
# Epoch 9, Iteration 90 Train Loss: 861.07
# New Epoch! Avg loss for the last 100 iterations: 1020.9884093093872
# Epoch 10, Iteration 0 Train Loss: 19943.04
# Epoch 10, Iteration 10 Train Loss: 482.48
# Epoch 10, Iteration 20 Train Loss: 20.62
# Epoch 10, Iteration 30 Train Loss: 49.11
# Epoch 10, Iteration 40 Train Loss: 37.84
# Epoch 10, Iteration 50 Train Loss: 36.49
# Epoch 10, Iteration 60 Train Loss: 114.90
# Epoch 10, Iteration 70 Train Loss: 1227.74
# Epoch 10, Iteration 80 Train Loss: 55.55
# Epoch 10, Iteration 90 Train Loss: 817.92
# New Epoch! Avg loss for the last 100 iterations: 992.6474810028076
# Epoch 11, Iteration 0 Train Loss: 19858.87
# Epoch 11, Iteration 10 Train Loss: 444.78
# Epoch 11, Iteration 20 Train Loss: 23.74
# Epoch 11, Iteration 30 Train Loss: 53.31
# Epoch 11, Iteration 40 Train Loss: 41.95
# Epoch 11, Iteration 50 Train Loss: 35.47
# Epoch 11, Iteration 60 Train Loss: 99.76
# Epoch 11, Iteration 70 Train Loss: 1181.99
# Epoch 11, Iteration 80 Train Loss: 32.24
# Epoch 11, Iteration 90 Train Loss: 785.69
# New Epoch! Avg loss for the last 100 iterations: 971.3683575820922
# Epoch 12, Iteration 0 Train Loss: 19785.56
# Epoch 12, Iteration 10 Train Loss: 414.83
# Epoch 12, Iteration 20 Train Loss: 27.55
# Epoch 12, Iteration 30 Train Loss: 57.08
# Epoch 12, Iteration 40 Train Loss: 45.67
# Epoch 12, Iteration 50 Train Loss: 37.30
# Epoch 12, Iteration 60 Train Loss: 86.14
# Epoch 12, Iteration 70 Train Loss: 1139.70
# Epoch 12, Iteration 80 Train Loss: 23.08
# Epoch 12, Iteration 90 Train Loss: 756.79
# New Epoch! Avg loss for the last 100 iterations: 954.7050536537171
# Epoch 13, Iteration 0 Train Loss: 19719.60
# Epoch 13, Iteration 10 Train Loss: 388.56
# Epoch 13, Iteration 20 Train Loss: 30.97
# Epoch 13, Iteration 30 Train Loss: 60.42
# Epoch 13, Iteration 40 Train Loss: 48.96
# Epoch 13, Iteration 50 Train Loss: 39.12
# Epoch 13, Iteration 60 Train Loss: 74.81
# Epoch 13, Iteration 70 Train Loss: 1102.47
# Epoch 13, Iteration 80 Train Loss: 26.22
# Epoch 13, Iteration 90 Train Loss: 730.67
# New Epoch! Avg loss for the last 100 iterations: 941.2894047164917
# Epoch 14, Iteration 0 Train Loss: 19659.57
# Epoch 14, Iteration 10 Train Loss: 364.61
# Epoch 14, Iteration 20 Train Loss: 34.12
# Epoch 14, Iteration 30 Train Loss: 63.52
# Epoch 14, Iteration 40 Train Loss: 52.04
# Epoch 14, Iteration 50 Train Loss: 40.95
# Epoch 14, Iteration 60 Train Loss: 72.69
# Epoch 14, Iteration 70 Train Loss: 1066.47
# Epoch 14, Iteration 80 Train Loss: 29.26
# Epoch 14, Iteration 90 Train Loss: 709.35
# New Epoch! Avg loss for the last 100 iterations: 929.584207725525
# Epoch 15, Iteration 0 Train Loss: 19601.89
# Epoch 15, Iteration 10 Train Loss: 341.91
# Epoch 15, Iteration 20 Train Loss: 37.16
# Epoch 15, Iteration 30 Train Loss: 66.54
# Epoch 15, Iteration 40 Train Loss: 55.05
# Epoch 15, Iteration 50 Train Loss: 42.78
# Epoch 15, Iteration 60 Train Loss: 70.86
# Epoch 15, Iteration 70 Train Loss: 1031.28
# Epoch 15, Iteration 80 Train Loss: 32.17
# Epoch 15, Iteration 90 Train Loss: 688.77
# New Epoch! Avg loss for the last 100 iterations: 918.8475792121887
# Epoch 16, Iteration 0 Train Loss: 19547.32
# Epoch 16, Iteration 10 Train Loss: 321.04
# Epoch 16, Iteration 20 Train Loss: 40.04
# Epoch 16, Iteration 30 Train Loss: 69.36
# Epoch 16, Iteration 40 Train Loss: 57.84
# Epoch 16, Iteration 50 Train Loss: 44.55
# Epoch 16, Iteration 60 Train Loss: 69.09
# Epoch 16, Iteration 70 Train Loss: 997.74
# Epoch 16, Iteration 80 Train Loss: 34.93
# Epoch 16, Iteration 90 Train Loss: 668.91
# New Epoch! Avg loss for the last 100 iterations: 909.3845602989197
# Epoch 17, Iteration 0 Train Loss: 19495.35
# Epoch 17, Iteration 10 Train Loss: 301.22
# Epoch 17, Iteration 20 Train Loss: 42.77
# Epoch 17, Iteration 30 Train Loss: 72.07
# Epoch 17, Iteration 40 Train Loss: 60.54
# Epoch 17, Iteration 50 Train Loss: 46.28
# Epoch 17, Iteration 60 Train Loss: 69.49
# Epoch 17, Iteration 70 Train Loss: 966.01
# Epoch 17, Iteration 80 Train Loss: 37.57
# Epoch 17, Iteration 90 Train Loss: 650.39
# New Epoch! Avg loss for the last 100 iterations: 901.3115556144714
# Epoch 18, Iteration 0 Train Loss: 19445.61
# Epoch 18, Iteration 10 Train Loss: 282.50
# Epoch 18, Iteration 20 Train Loss: 45.38
# Epoch 18, Iteration 30 Train Loss: 74.69
# Epoch 18, Iteration 40 Train Loss: 63.15
# Epoch 18, Iteration 50 Train Loss: 47.90
# Epoch 18, Iteration 60 Train Loss: 72.09
# Epoch 18, Iteration 70 Train Loss: 935.87
# Epoch 18, Iteration 80 Train Loss: 40.17
# Epoch 18, Iteration 90 Train Loss: 632.42
# New Epoch! Avg loss for the last 100 iterations: 894.2223109436035
# Epoch 19, Iteration 0 Train Loss: 19396.19
# Epoch 19, Iteration 10 Train Loss: 264.24
# Epoch 19, Iteration 20 Train Loss: 47.99
# Epoch 19, Iteration 30 Train Loss: 77.27
# Epoch 19, Iteration 40 Train Loss: 65.72
# Epoch 19, Iteration 50 Train Loss: 49.57
# Epoch 19, Iteration 60 Train Loss: 74.66
# Epoch 19, Iteration 70 Train Loss: 905.64
# Epoch 19, Iteration 80 Train Loss: 42.70
# Epoch 19, Iteration 90 Train Loss: 614.60
# New Epoch! Avg loss for the last 100 iterations: 887.5212768745422
# Epoch 20, Iteration 0 Train Loss: 19348.38
# Epoch 20, Iteration 10 Train Loss: 250.07
# Epoch 20, Iteration 20 Train Loss: 50.51
# Epoch 20, Iteration 30 Train Loss: 79.79
# Epoch 20, Iteration 40 Train Loss: 68.23
# Epoch 20, Iteration 50 Train Loss: 51.88
# Epoch 20, Iteration 60 Train Loss: 77.15
# Epoch 20, Iteration 70 Train Loss: 875.70
# Epoch 20, Iteration 80 Train Loss: 45.19
# Epoch 20, Iteration 90 Train Loss: 596.79
# New Epoch! Avg loss for the last 100 iterations: 881.185779838562
# Epoch 21, Iteration 0 Train Loss: 19301.15
# Epoch 21, Iteration 10 Train Loss: 235.95
# Epoch 21, Iteration 20 Train Loss: 53.04
# Epoch 21, Iteration 30 Train Loss: 82.30
# Epoch 21, Iteration 40 Train Loss: 70.74
# Epoch 21, Iteration 50 Train Loss: 54.38
# Epoch 21, Iteration 60 Train Loss: 79.65
# Epoch 21, Iteration 70 Train Loss: 845.63
# Epoch 21, Iteration 80 Train Loss: 47.67
# Epoch 21, Iteration 90 Train Loss: 579.13
# New Epoch! Avg loss for the last 100 iterations: 875.0239909553528
# Epoch 22, Iteration 0 Train Loss: 19254.38
# Epoch 22, Iteration 10 Train Loss: 222.04
# Epoch 22, Iteration 20 Train Loss: 55.51
# Epoch 22, Iteration 30 Train Loss: 84.76
# Epoch 22, Iteration 40 Train Loss: 73.19
# Epoch 22, Iteration 50 Train Loss: 56.83
# Epoch 22, Iteration 60 Train Loss: 82.09
# Epoch 22, Iteration 70 Train Loss: 816.08
# Epoch 22, Iteration 80 Train Loss: 50.11
# Epoch 22, Iteration 90 Train Loss: 561.47
# New Epoch! Avg loss for the last 100 iterations: 869.1401818084717
# Epoch 23, Iteration 0 Train Loss: 19208.21
# Epoch 23, Iteration 10 Train Loss: 208.52
# Epoch 23, Iteration 20 Train Loss: 57.93
# Epoch 23, Iteration 30 Train Loss: 87.16
# Epoch 23, Iteration 40 Train Loss: 75.58
# Epoch 23, Iteration 50 Train Loss: 59.21
# Epoch 23, Iteration 60 Train Loss: 84.46
# Epoch 23, Iteration 70 Train Loss: 788.82
# Epoch 23, Iteration 80 Train Loss: 52.46
# Epoch 23, Iteration 90 Train Loss: 543.98
# New Epoch! Avg loss for the last 100 iterations: 863.4273038864136
# Epoch 24, Iteration 0 Train Loss: 19163.70
# Epoch 24, Iteration 10 Train Loss: 196.16
# Epoch 24, Iteration 20 Train Loss: 60.30
# Epoch 24, Iteration 30 Train Loss: 89.51
# Epoch 24, Iteration 40 Train Loss: 77.93
# Epoch 24, Iteration 50 Train Loss: 61.55
# Epoch 24, Iteration 60 Train Loss: 86.78
# Epoch 24, Iteration 70 Train Loss: 763.69
# Epoch 24, Iteration 80 Train Loss: 54.76
# Epoch 24, Iteration 90 Train Loss: 526.65
# New Epoch! Avg loss for the last 100 iterations: 858.1060397720337
# Discontinuity
# 2021-09-24 04:17:21-07:00 2021-08-17 06:37:13-07:00
# 0.04926536 0.0012214300000000001
# Oracle activations: 34073
# It's over 9000! 2021-08-17 06:00:00-07:00 2021-09-24 04:00:00-07:00
# Runtime total_E activations: 90546.45301288954
# Runtime total_E_pred activations: 217609.9672111894
# It's over 9000! 2021-08-17 06:00:00-07:00 2021-09-24 04:00:00-07:00
# Naive total_E activations: 33131.984647044796
# Naive total_E_pred activations: 39451.51160935354
# Dataset, train set, and test set size: 1476 738 369
# Timeframe: 60min
# Minimal Application
# Naive vs. DL succesful activations: 0.6196012210170813
# Maximum possible activations: 34073
# Predicted activations: 66326
# Successful activations: 9540, 14.383%
# Failed activations: 55448, 83.599%
# Missed activations: 24533, 72.001%
# Naive predicted activations (usual actual energy average): 46478
# Naive successful activations (usual actual energy average): 15397, 33.128%
# Naive failed activations (usual actual energy average): 29769, 64.050%
# Naive missed activations (usual actual energy average): 18676, 54.812%
# Voltage overestimation rate: 100.000%
# Test MAPE power: 2.027503
# Test MAPE voltage: 0.628806
# Test MAPE current: 0.450791
# Epoch 0, Iteration 0 Train Loss: 22023.80
# Epoch 0, Iteration 10 Train Loss: 2212.84
# Epoch 0, Iteration 20 Train Loss: 1747.41
# Epoch 0, Iteration 30 Train Loss: 1192.65
# Epoch 0, Iteration 40 Train Loss: 1407.05
# Epoch 0, Iteration 50 Train Loss: 1710.03
# Epoch 0, Iteration 60 Train Loss: 1223.64
# Epoch 0, Iteration 70 Train Loss: 2950.82
# Epoch 0, Iteration 80 Train Loss: 1814.60
# Epoch 0, Iteration 90 Train Loss: 2223.56
# Epoch 0, Iteration 100 Train Loss: 1405.54
# Epoch 0, Iteration 110 Train Loss: 1731.01
# Epoch 0, Iteration 120 Train Loss: 1808.59
# Epoch 0, Iteration 130 Train Loss: 1544.61
# Epoch 0, Iteration 140 Train Loss: 1297.70
# Epoch 0, Iteration 150 Train Loss: 1610.35
# Epoch 0, Iteration 160 Train Loss: 1687.54
# Epoch 0, Iteration 170 Train Loss: 1113.21
# Epoch 0, Iteration 180 Train Loss: 1200.09
# New Epoch! Avg loss for the last 100 iterations: 1503.9342529296875
# Epoch 1, Iteration 0 Train Loss: 21267.39
# Epoch 1, Iteration 10 Train Loss: 1474.68
# Epoch 1, Iteration 20 Train Loss: 969.37
# Epoch 1, Iteration 30 Train Loss: 488.85
# Epoch 1, Iteration 40 Train Loss: 649.53
# Epoch 1, Iteration 50 Train Loss: 856.47
# Epoch 1, Iteration 60 Train Loss: 519.55
# Epoch 1, Iteration 70 Train Loss: 2004.89
# Epoch 1, Iteration 80 Train Loss: 883.62
# Epoch 1, Iteration 90 Train Loss: 1362.54
# Epoch 1, Iteration 100 Train Loss: 553.02
# Epoch 1, Iteration 110 Train Loss: 806.29
# Epoch 1, Iteration 120 Train Loss: 1000.45
# Epoch 1, Iteration 130 Train Loss: 861.22
# Epoch 1, Iteration 140 Train Loss: 719.23
# Epoch 1, Iteration 150 Train Loss: 1022.17
# Epoch 1, Iteration 160 Train Loss: 1083.70
# Epoch 1, Iteration 170 Train Loss: 586.83
# Epoch 1, Iteration 180 Train Loss: 685.11
# New Epoch! Avg loss for the last 100 iterations: 814.9352656555176
# Epoch 2, Iteration 0 Train Loss: 20693.27
# Epoch 2, Iteration 10 Train Loss: 945.34
# Epoch 2, Iteration 20 Train Loss: 481.77
# Epoch 2, Iteration 30 Train Loss: 129.99
# Epoch 2, Iteration 40 Train Loss: 292.35
# Epoch 2, Iteration 50 Train Loss: 403.39
# Epoch 2, Iteration 60 Train Loss: 296.28
# Epoch 2, Iteration 70 Train Loss: 1621.90
# Epoch 2, Iteration 80 Train Loss: 453.70
# Epoch 2, Iteration 90 Train Loss: 1131.22
# Epoch 2, Iteration 100 Train Loss: 242.35
# Epoch 2, Iteration 110 Train Loss: 392.27
# Epoch 2, Iteration 120 Train Loss: 734.44
# Epoch 2, Iteration 130 Train Loss: 538.85
# Epoch 2, Iteration 140 Train Loss: 324.08
# Epoch 2, Iteration 150 Train Loss: 707.84
# Epoch 2, Iteration 160 Train Loss: 697.41
# Epoch 2, Iteration 170 Train Loss: 236.71
# Epoch 2, Iteration 180 Train Loss: 467.67
# New Epoch! Avg loss for the last 100 iterations: 493.77716423034667
# Epoch 3, Iteration 0 Train Loss: 20300.80
# Epoch 3, Iteration 10 Train Loss: 664.70
# Epoch 3, Iteration 20 Train Loss: 127.35
# Epoch 3, Iteration 30 Train Loss: 33.34
# Epoch 3, Iteration 40 Train Loss: 96.76
# Epoch 3, Iteration 50 Train Loss: 102.83
# Epoch 3, Iteration 60 Train Loss: 192.05
# Epoch 3, Iteration 70 Train Loss: 1400.72
# Epoch 3, Iteration 80 Train Loss: 196.19
# Epoch 3, Iteration 90 Train Loss: 962.86
# Epoch 3, Iteration 100 Train Loss: 105.27
# Epoch 3, Iteration 110 Train Loss: 113.40
# Epoch 3, Iteration 120 Train Loss: 557.62
# Epoch 3, Iteration 130 Train Loss: 371.60
# Epoch 3, Iteration 140 Train Loss: 84.24
# Epoch 3, Iteration 150 Train Loss: 538.65
# Epoch 3, Iteration 160 Train Loss: 478.49
# Epoch 3, Iteration 170 Train Loss: 134.90
# Epoch 3, Iteration 180 Train Loss: 369.03
# New Epoch! Avg loss for the last 100 iterations: 327.701100358963
# Epoch 4, Iteration 0 Train Loss: 20046.31
# Epoch 4, Iteration 10 Train Loss: 523.71
# Epoch 4, Iteration 20 Train Loss: 21.41
# Epoch 4, Iteration 30 Train Loss: 43.94
# Epoch 4, Iteration 40 Train Loss: 32.73
# Epoch 4, Iteration 50 Train Loss: 37.14
# Epoch 4, Iteration 60 Train Loss: 125.16
# Epoch 4, Iteration 70 Train Loss: 1256.49
# Epoch 4, Iteration 80 Train Loss: 70.16
# Epoch 4, Iteration 90 Train Loss: 835.07
# Epoch 4, Iteration 100 Train Loss: 48.15
# Epoch 4, Iteration 110 Train Loss: 36.01
# Epoch 4, Iteration 120 Train Loss: 432.98
# Epoch 4, Iteration 130 Train Loss: 261.48
# Epoch 4, Iteration 140 Train Loss: 20.98
# Epoch 4, Iteration 150 Train Loss: 414.95
# Epoch 4, Iteration 160 Train Loss: 342.69
# Epoch 4, Iteration 170 Train Loss: 97.18
# Epoch 4, Iteration 180 Train Loss: 295.72
# New Epoch! Avg loss for the last 100 iterations: 250.16662691116332
# Epoch 5, Iteration 0 Train Loss: 19881.63
# Epoch 5, Iteration 10 Train Loss: 446.84
# Epoch 5, Iteration 20 Train Loss: 22.76
# Epoch 5, Iteration 30 Train Loss: 52.42
# Epoch 5, Iteration 40 Train Loss: 41.05
# Epoch 5, Iteration 50 Train Loss: 33.67
# Epoch 5, Iteration 60 Train Loss: 85.75
# Epoch 5, Iteration 70 Train Loss: 1147.56
# Epoch 5, Iteration 80 Train Loss: 19.93
# Epoch 5, Iteration 90 Train Loss: 759.69
# Epoch 5, Iteration 100 Train Loss: 38.38
# Epoch 5, Iteration 110 Train Loss: 29.97
# Epoch 5, Iteration 120 Train Loss: 342.86
# Epoch 5, Iteration 130 Train Loss: 198.99
# Epoch 5, Iteration 140 Train Loss: 20.56
# Epoch 5, Iteration 150 Train Loss: 322.49
# Epoch 5, Iteration 160 Train Loss: 250.78
# Epoch 5, Iteration 170 Train Loss: 78.35
# Epoch 5, Iteration 180 Train Loss: 239.62
# New Epoch! Avg loss for the last 100 iterations: 209.29172178268433
# Epoch 6, Iteration 0 Train Loss: 19762.63
# Epoch 6, Iteration 10 Train Loss: 393.56
# Epoch 6, Iteration 20 Train Loss: 29.10
# Epoch 6, Iteration 30 Train Loss: 58.63
# Epoch 6, Iteration 40 Train Loss: 47.18
# Epoch 6, Iteration 50 Train Loss: 37.14
# Epoch 6, Iteration 60 Train Loss: 67.99
# Epoch 6, Iteration 70 Train Loss: 1062.45
# Epoch 6, Iteration 80 Train Loss: 24.53
# Epoch 6, Iteration 90 Train Loss: 704.64
# Epoch 6, Iteration 100 Train Loss: 44.19
# Epoch 6, Iteration 110 Train Loss: 30.81
# Epoch 6, Iteration 120 Train Loss: 284.89
# Epoch 6, Iteration 130 Train Loss: 157.03
# Epoch 6, Iteration 140 Train Loss: 26.15
# Epoch 6, Iteration 150 Train Loss: 250.86
# Epoch 6, Iteration 160 Train Loss: 180.15
# Epoch 6, Iteration 170 Train Loss: 70.44
# Epoch 6, Iteration 180 Train Loss: 199.37
# New Epoch! Avg loss for the last 100 iterations: 184.1804153060913
# Epoch 7, Iteration 0 Train Loss: 19660.81
# Epoch 7, Iteration 10 Train Loss: 350.15
# Epoch 7, Iteration 20 Train Loss: 34.27
# Epoch 7, Iteration 30 Train Loss: 63.75
# Epoch 7, Iteration 40 Train Loss: 52.27
# Epoch 7, Iteration 50 Train Loss: 40.33
# Epoch 7, Iteration 60 Train Loss: 63.46
# Epoch 7, Iteration 70 Train Loss: 991.04
# Epoch 7, Iteration 80 Train Loss: 29.50
# Epoch 7, Iteration 90 Train Loss: 662.36
# Epoch 7, Iteration 100 Train Loss: 49.06
# Epoch 7, Iteration 110 Train Loss: 32.83
# Epoch 7, Iteration 120 Train Loss: 243.49
# Epoch 7, Iteration 130 Train Loss: 125.56
# Epoch 7, Iteration 140 Train Loss: 30.92
# Epoch 7, Iteration 150 Train Loss: 207.80
# Epoch 7, Iteration 160 Train Loss: 131.63
# Epoch 7, Iteration 170 Train Loss: 67.69
# Epoch 7, Iteration 180 Train Loss: 167.99
# New Epoch! Avg loss for the last 100 iterations: 167.39197404861451
# Epoch 8, Iteration 0 Train Loss: 19574.72
# Epoch 8, Iteration 10 Train Loss: 312.95
# Epoch 8, Iteration 20 Train Loss: 38.84
# Epoch 8, Iteration 30 Train Loss: 68.29
# Epoch 8, Iteration 40 Train Loss: 56.78
# Epoch 8, Iteration 50 Train Loss: 43.52
# Epoch 8, Iteration 60 Train Loss: 65.78
# Epoch 8, Iteration 70 Train Loss: 925.64
# Epoch 8, Iteration 80 Train Loss: 33.88
# Epoch 8, Iteration 90 Train Loss: 623.40
# Epoch 8, Iteration 100 Train Loss: 53.39
# Epoch 8, Iteration 110 Train Loss: 36.02
# Epoch 8, Iteration 120 Train Loss: 206.62
# Epoch 8, Iteration 130 Train Loss: 104.10
# Epoch 8, Iteration 140 Train Loss: 35.18
# Epoch 8, Iteration 150 Train Loss: 172.30
# Epoch 8, Iteration 160 Train Loss: 96.08
# Epoch 8, Iteration 170 Train Loss: 67.46
# Epoch 8, Iteration 180 Train Loss: 138.93
# New Epoch! Avg loss for the last 100 iterations: 154.40458992004395
# Epoch 9, Iteration 0 Train Loss: 19496.45
# Epoch 9, Iteration 10 Train Loss: 283.98
# Epoch 9, Iteration 20 Train Loss: 43.04
# Epoch 9, Iteration 30 Train Loss: 72.46
# Epoch 9, Iteration 40 Train Loss: 60.94
# Epoch 9, Iteration 50 Train Loss: 46.46
# Epoch 9, Iteration 60 Train Loss: 69.90
# Epoch 9, Iteration 70 Train Loss: 863.53
# Epoch 9, Iteration 80 Train Loss: 38.00
# Epoch 9, Iteration 90 Train Loss: 586.06
# Epoch 9, Iteration 100 Train Loss: 57.48
# Epoch 9, Iteration 110 Train Loss: 38.97
# Epoch 9, Iteration 120 Train Loss: 177.78
# Epoch 9, Iteration 130 Train Loss: 83.44
# Epoch 9, Iteration 140 Train Loss: 39.09
# Epoch 9, Iteration 150 Train Loss: 143.25
# Epoch 9, Iteration 160 Train Loss: 69.49
# Epoch 9, Iteration 170 Train Loss: 68.58
# Epoch 9, Iteration 180 Train Loss: 111.81
# New Epoch! Avg loss for the last 100 iterations: 143.49215589523317
# Epoch 10, Iteration 0 Train Loss: 19427.19
# Epoch 10, Iteration 10 Train Loss: 260.24
# Epoch 10, Iteration 20 Train Loss: 46.91
# Epoch 10, Iteration 30 Train Loss: 76.37
# Epoch 10, Iteration 40 Train Loss: 64.84
# Epoch 10, Iteration 50 Train Loss: 49.34
# Epoch 10, Iteration 60 Train Loss: 73.77
# Epoch 10, Iteration 70 Train Loss: 801.12
# Epoch 10, Iteration 80 Train Loss: 41.87
# Epoch 10, Iteration 90 Train Loss: 548.23
# Epoch 10, Iteration 100 Train Loss: 61.32
# Epoch 10, Iteration 110 Train Loss: 41.94
# Epoch 10, Iteration 120 Train Loss: 148.27
# Epoch 10, Iteration 130 Train Loss: 67.07
# Epoch 10, Iteration 140 Train Loss: 42.91
# Epoch 10, Iteration 150 Train Loss: 114.45
# Epoch 10, Iteration 160 Train Loss: 49.25
# Epoch 10, Iteration 170 Train Loss: 69.31
# Epoch 10, Iteration 180 Train Loss: 91.47
# New Epoch! Avg loss for the last 100 iterations: 133.8959818649292
# Epoch 11, Iteration 0 Train Loss: 19356.89
# Epoch 11, Iteration 10 Train Loss: 236.92
# Epoch 11, Iteration 20 Train Loss: 50.60
# Epoch 11, Iteration 30 Train Loss: 80.02
# Epoch 11, Iteration 40 Train Loss: 68.47
# Epoch 11, Iteration 50 Train Loss: 52.35
# Epoch 11, Iteration 60 Train Loss: 77.38
# Epoch 11, Iteration 70 Train Loss: 748.58
# Epoch 11, Iteration 80 Train Loss: 45.46
# Epoch 11, Iteration 90 Train Loss: 512.63
# Epoch 11, Iteration 100 Train Loss: 64.87
# Epoch 11, Iteration 110 Train Loss: 45.43
# Epoch 11, Iteration 120 Train Loss: 126.38
# Epoch 11, Iteration 130 Train Loss: 55.08
# Epoch 11, Iteration 140 Train Loss: 46.37
# Epoch 11, Iteration 150 Train Loss: 92.97
# Epoch 11, Iteration 160 Train Loss: 37.31
# Epoch 11, Iteration 170 Train Loss: 71.56
# Epoch 11, Iteration 180 Train Loss: 77.80
# New Epoch! Avg loss for the last 100 iterations: 126.0976382637024
# Epoch 12, Iteration 0 Train Loss: 19292.86
# Epoch 12, Iteration 10 Train Loss: 215.21
# Epoch 12, Iteration 20 Train Loss: 54.03
# Epoch 12, Iteration 30 Train Loss: 83.46
# Epoch 12, Iteration 40 Train Loss: 71.91
# Epoch 12, Iteration 50 Train Loss: 55.50
# Epoch 12, Iteration 60 Train Loss: 80.78
# Epoch 12, Iteration 70 Train Loss: 698.94
# Epoch 12, Iteration 80 Train Loss: 48.86
# Epoch 12, Iteration 90 Train Loss: 477.91
# Epoch 12, Iteration 100 Train Loss: 68.25
# Epoch 12, Iteration 110 Train Loss: 48.78
# Epoch 12, Iteration 120 Train Loss: 107.10
# Epoch 12, Iteration 130 Train Loss: 47.29
# Epoch 12, Iteration 140 Train Loss: 49.61
# Epoch 12, Iteration 150 Train Loss: 74.08
# Epoch 12, Iteration 160 Train Loss: 30.01
# Epoch 12, Iteration 170 Train Loss: 74.19
# Epoch 12, Iteration 180 Train Loss: 66.30
# New Epoch! Avg loss for the last 100 iterations: 119.54981201171876
# Epoch 13, Iteration 0 Train Loss: 19234.42
# Epoch 13, Iteration 10 Train Loss: 194.93
# Epoch 13, Iteration 20 Train Loss: 57.21
# Epoch 13, Iteration 30 Train Loss: 86.64
# Epoch 13, Iteration 40 Train Loss: 75.08
# Epoch 13, Iteration 50 Train Loss: 58.66
# Epoch 13, Iteration 60 Train Loss: 83.94
# Epoch 13, Iteration 70 Train Loss: 658.61
# Epoch 13, Iteration 80 Train Loss: 52.00
# Epoch 13, Iteration 90 Train Loss: 445.27
# Epoch 13, Iteration 100 Train Loss: 71.36
# Epoch 13, Iteration 110 Train Loss: 51.87
# Epoch 13, Iteration 120 Train Loss: 90.88
# Epoch 13, Iteration 130 Train Loss: 47.36
# Epoch 13, Iteration 140 Train Loss: 52.56
# Epoch 13, Iteration 150 Train Loss: 58.45
# Epoch 13, Iteration 160 Train Loss: 26.46
# Epoch 13, Iteration 170 Train Loss: 76.41
# Epoch 13, Iteration 180 Train Loss: 59.69
# New Epoch! Avg loss for the last 100 iterations: 114.46207761764526
# Epoch 14, Iteration 0 Train Loss: 19181.74
# Epoch 14, Iteration 10 Train Loss: 177.02
# Epoch 14, Iteration 20 Train Loss: 60.00
# Epoch 14, Iteration 30 Train Loss: 89.41
# Epoch 14, Iteration 40 Train Loss: 77.84
# Epoch 14, Iteration 50 Train Loss: 61.41
# Epoch 14, Iteration 60 Train Loss: 86.68
# Epoch 14, Iteration 70 Train Loss: 622.42
# Epoch 14, Iteration 80 Train Loss: 54.73
# Epoch 14, Iteration 90 Train Loss: 415.65
# Epoch 14, Iteration 100 Train Loss: 74.08
# Epoch 14, Iteration 110 Train Loss: 54.59
# Epoch 14, Iteration 120 Train Loss: 80.59
# Epoch 14, Iteration 130 Train Loss: 50.07
# Epoch 14, Iteration 140 Train Loss: 55.26
# Epoch 14, Iteration 150 Train Loss: 48.02
# Epoch 14, Iteration 160 Train Loss: 29.06
# Epoch 14, Iteration 170 Train Loss: 79.25
# Epoch 14, Iteration 180 Train Loss: 55.81
# New Epoch! Avg loss for the last 100 iterations: 110.61079139709473
# Epoch 15, Iteration 0 Train Loss: 19132.69
# Epoch 15, Iteration 10 Train Loss: 160.44
# Epoch 15, Iteration 20 Train Loss: 62.80
# Epoch 15, Iteration 30 Train Loss: 92.24
# Epoch 15, Iteration 40 Train Loss: 80.66
# Epoch 15, Iteration 50 Train Loss: 64.21
# Epoch 15, Iteration 60 Train Loss: 89.46
# Epoch 15, Iteration 70 Train Loss: 587.29
# Epoch 15, Iteration 80 Train Loss: 57.51
# Epoch 15, Iteration 90 Train Loss: 385.13
# Epoch 15, Iteration 100 Train Loss: 76.86
# Epoch 15, Iteration 110 Train Loss: 57.35
# Epoch 15, Iteration 120 Train Loss: 69.93
# Epoch 15, Iteration 130 Train Loss: 52.82
# Epoch 15, Iteration 140 Train Loss: 57.97
# Epoch 15, Iteration 150 Train Loss: 41.34
# Epoch 15, Iteration 160 Train Loss: 31.79
# Epoch 15, Iteration 170 Train Loss: 81.44
# Epoch 15, Iteration 180 Train Loss: 55.48
# New Epoch! Avg loss for the last 100 iterations: 107.08996452331543
# Epoch 16, Iteration 0 Train Loss: 19082.96
# Epoch 16, Iteration 10 Train Loss: 149.77
# Epoch 16, Iteration 20 Train Loss: 65.43
# Epoch 16, Iteration 30 Train Loss: 94.86
# Epoch 16, Iteration 40 Train Loss: 83.27
# Epoch 16, Iteration 50 Train Loss: 66.81
# Epoch 16, Iteration 60 Train Loss: 92.05
# Epoch 16, Iteration 70 Train Loss: 558.41
# Epoch 16, Iteration 80 Train Loss: 60.09
# Epoch 16, Iteration 90 Train Loss: 356.15
# Epoch 16, Iteration 100 Train Loss: 79.43
# Epoch 16, Iteration 110 Train Loss: 59.89
# Epoch 16, Iteration 120 Train Loss: 60.44
# Epoch 16, Iteration 130 Train Loss: 55.21
# Epoch 16, Iteration 140 Train Loss: 60.22
# Epoch 16, Iteration 150 Train Loss: 40.84
# Epoch 16, Iteration 160 Train Loss: 33.92
# Epoch 16, Iteration 170 Train Loss: 84.73
# Epoch 16, Iteration 180 Train Loss: 57.65
# New Epoch! Avg loss for the last 100 iterations: 104.26410133361816
# Epoch 17, Iteration 0 Train Loss: 19040.68
# Epoch 17, Iteration 10 Train Loss: 140.56
# Epoch 17, Iteration 20 Train Loss: 67.87
# Epoch 17, Iteration 30 Train Loss: 97.31
# Epoch 17, Iteration 40 Train Loss: 85.71
# Epoch 17, Iteration 50 Train Loss: 69.24
# Epoch 17, Iteration 60 Train Loss: 94.47
# Epoch 17, Iteration 70 Train Loss: 530.38
# Epoch 17, Iteration 80 Train Loss: 62.54
# Epoch 17, Iteration 90 Train Loss: 327.87
# Epoch 17, Iteration 100 Train Loss: 81.86
# Epoch 17, Iteration 110 Train Loss: 62.33
# Epoch 17, Iteration 120 Train Loss: 56.65
# Epoch 17, Iteration 130 Train Loss: 57.74
# Epoch 17, Iteration 140 Train Loss: 62.85
# Epoch 17, Iteration 150 Train Loss: 43.52
# Epoch 17, Iteration 160 Train Loss: 36.59
# Epoch 17, Iteration 170 Train Loss: 86.34
# Epoch 17, Iteration 180 Train Loss: 60.19
# New Epoch! Avg loss for the last 100 iterations: 102.00724571228028
# Epoch 18, Iteration 0 Train Loss: 18992.50
# Epoch 18, Iteration 10 Train Loss: 130.36
# Epoch 18, Iteration 20 Train Loss: 70.38
# Epoch 18, Iteration 30 Train Loss: 99.80
# Epoch 18, Iteration 40 Train Loss: 88.19
# Epoch 18, Iteration 50 Train Loss: 71.71
# Epoch 18, Iteration 60 Train Loss: 96.95
# Epoch 18, Iteration 70 Train Loss: 502.88
# Epoch 18, Iteration 80 Train Loss: 65.00
# Epoch 18, Iteration 90 Train Loss: 300.70
# Epoch 18, Iteration 100 Train Loss: 84.29
# Epoch 18, Iteration 110 Train Loss: 64.75
# Epoch 18, Iteration 120 Train Loss: 56.16
# Epoch 18, Iteration 130 Train Loss: 60.10
# Epoch 18, Iteration 140 Train Loss: 65.20
# Epoch 18, Iteration 150 Train Loss: 45.86
# Epoch 18, Iteration 160 Train Loss: 38.92
# Epoch 18, Iteration 170 Train Loss: 88.57
# Epoch 18, Iteration 180 Train Loss: 62.51
# New Epoch! Avg loss for the last 100 iterations: 100.30204025268554
# Epoch 19, Iteration 0 Train Loss: 18946.03
# Epoch 19, Iteration 10 Train Loss: 122.81
# Epoch 19, Iteration 20 Train Loss: 72.74
# Epoch 19, Iteration 30 Train Loss: 102.01
# Epoch 19, Iteration 40 Train Loss: 90.38
# Epoch 19, Iteration 50 Train Loss: 73.89
# Epoch 19, Iteration 60 Train Loss: 99.12
# Epoch 19, Iteration 70 Train Loss: 477.84
# Epoch 19, Iteration 80 Train Loss: 67.15
# Epoch 19, Iteration 90 Train Loss: 275.52
# Epoch 19, Iteration 100 Train Loss: 86.46
# Epoch 19, Iteration 110 Train Loss: 66.91
# Epoch 19, Iteration 120 Train Loss: 58.31
# Epoch 19, Iteration 130 Train Loss: 62.23
# Epoch 19, Iteration 140 Train Loss: 67.29
# Epoch 19, Iteration 150 Train Loss: 47.94
# Epoch 19, Iteration 160 Train Loss: 40.99
# Epoch 19, Iteration 170 Train Loss: 90.83
# Epoch 19, Iteration 180 Train Loss: 64.57
# New Epoch! Avg loss for the last 100 iterations: 98.92023929595948
# Epoch 20, Iteration 0 Train Loss: 18905.93
# Epoch 20, Iteration 10 Train Loss: 119.83
# Epoch 20, Iteration 20 Train Loss: 74.76
# Epoch 20, Iteration 30 Train Loss: 104.17
# Epoch 20, Iteration 40 Train Loss: 92.54
# Epoch 20, Iteration 50 Train Loss: 76.05
# Epoch 20, Iteration 60 Train Loss: 101.28
# Epoch 20, Iteration 70 Train Loss: 457.16
# Epoch 20, Iteration 80 Train Loss: 69.31
# Epoch 20, Iteration 90 Train Loss: 250.90
# Epoch 20, Iteration 100 Train Loss: 88.60
# Epoch 20, Iteration 110 Train Loss: 69.05
# Epoch 20, Iteration 120 Train Loss: 60.45
# Epoch 20, Iteration 130 Train Loss: 64.36
# Epoch 20, Iteration 140 Train Loss: 69.40
# Epoch 20, Iteration 150 Train Loss: 50.03
# Epoch 20, Iteration 160 Train Loss: 43.07
# Epoch 20, Iteration 170 Train Loss: 93.10
# Epoch 20, Iteration 180 Train Loss: 66.61
# New Epoch! Avg loss for the last 100 iterations: 97.8128419494629
# Epoch 21, Iteration 0 Train Loss: 18866.57
# Epoch 21, Iteration 10 Train Loss: 117.36
# Epoch 21, Iteration 20 Train Loss: 76.91
# Epoch 21, Iteration 30 Train Loss: 106.24
# Epoch 21, Iteration 40 Train Loss: 94.56
# Epoch 21, Iteration 50 Train Loss: 78.05
# Epoch 21, Iteration 60 Train Loss: 103.28
# Epoch 21, Iteration 70 Train Loss: 439.28
# Epoch 21, Iteration 80 Train Loss: 71.32
# Epoch 21, Iteration 90 Train Loss: 232.58
# Epoch 21, Iteration 100 Train Loss: 90.58
# Epoch 21, Iteration 110 Train Loss: 71.01
# Epoch 21, Iteration 120 Train Loss: 62.49
# Epoch 21, Iteration 130 Train Loss: 66.36
# Epoch 21, Iteration 140 Train Loss: 71.34
# Epoch 21, Iteration 150 Train Loss: 51.92
# Epoch 21, Iteration 160 Train Loss: 44.93
# Epoch 21, Iteration 170 Train Loss: 95.12
# Epoch 21, Iteration 180 Train Loss: 68.46
# New Epoch! Avg loss for the last 100 iterations: 97.10407962799073
# Epoch 22, Iteration 0 Train Loss: 18825.83
# Epoch 22, Iteration 10 Train Loss: 119.51
# Epoch 22, Iteration 20 Train Loss: 78.87
# Epoch 22, Iteration 30 Train Loss: 108.14
# Epoch 22, Iteration 40 Train Loss: 96.50
# Epoch 22, Iteration 50 Train Loss: 79.99
# Epoch 22, Iteration 60 Train Loss: 105.22
# Epoch 22, Iteration 70 Train Loss: 422.28
# Epoch 22, Iteration 80 Train Loss: 73.27
# Epoch 22, Iteration 90 Train Loss: 214.50
# Epoch 22, Iteration 100 Train Loss: 92.60
# Epoch 22, Iteration 110 Train Loss: 72.97
# Epoch 22, Iteration 120 Train Loss: 64.49
# Epoch 22, Iteration 130 Train Loss: 68.26
# Epoch 22, Iteration 140 Train Loss: 73.27
# Epoch 22, Iteration 150 Train Loss: 53.88
# Epoch 22, Iteration 160 Train Loss: 46.95
# Epoch 22, Iteration 170 Train Loss: 96.93
# Epoch 22, Iteration 180 Train Loss: 70.46
# New Epoch! Avg loss for the last 100 iterations: 96.47717441558838
# Epoch 23, Iteration 0 Train Loss: 18784.35
# Epoch 23, Iteration 10 Train Loss: 120.86
# Epoch 23, Iteration 20 Train Loss: 80.86
# Epoch 23, Iteration 30 Train Loss: 110.11
# Epoch 23, Iteration 40 Train Loss: 98.46
# Epoch 23, Iteration 50 Train Loss: 81.95
# Epoch 23, Iteration 60 Train Loss: 107.44
# Epoch 23, Iteration 70 Train Loss: 403.58
# Epoch 23, Iteration 80 Train Loss: 75.19
# Epoch 23, Iteration 90 Train Loss: 196.45
# Epoch 23, Iteration 100 Train Loss: 94.44
# Epoch 23, Iteration 110 Train Loss: 74.87
# Epoch 23, Iteration 120 Train Loss: 66.34
# Epoch 23, Iteration 130 Train Loss: 70.08
# Epoch 23, Iteration 140 Train Loss: 75.09
# Epoch 23, Iteration 150 Train Loss: 55.83
# Epoch 23, Iteration 160 Train Loss: 49.26
# Epoch 23, Iteration 170 Train Loss: 98.77
# Epoch 23, Iteration 180 Train Loss: 72.23
# New Epoch! Avg loss for the last 100 iterations: 95.81461601257324
# Epoch 24, Iteration 0 Train Loss: 18746.00
# Epoch 24, Iteration 10 Train Loss: 122.87
# Epoch 24, Iteration 20 Train Loss: 82.55
# Epoch 24, Iteration 30 Train Loss: 111.97
# Epoch 24, Iteration 40 Train Loss: 100.30
# Epoch 24, Iteration 50 Train Loss: 83.78
# Epoch 24, Iteration 60 Train Loss: 109.03
# Epoch 24, Iteration 70 Train Loss: 386.12
# Epoch 24, Iteration 80 Train Loss: 77.04
# Epoch 24, Iteration 90 Train Loss: 179.08
# Epoch 24, Iteration 100 Train Loss: 96.28
# Epoch 24, Iteration 110 Train Loss: 76.70
# Epoch 24, Iteration 120 Train Loss: 68.14
# Epoch 24, Iteration 130 Train Loss: 71.71
# Epoch 24, Iteration 140 Train Loss: 76.51
# Epoch 24, Iteration 150 Train Loss: 57.00
# Epoch 24, Iteration 160 Train Loss: 49.99
# Epoch 24, Iteration 170 Train Loss: 101.36
# Epoch 24, Iteration 180 Train Loss: 73.57
# New Epoch! Avg loss for the last 100 iterations: 95.28480339050293
# Discontinuity
# 2021-11-22 01:00:02-08:00 2021-11-10 23:59:53-08:00
# 0.0012214300000000001 0.02535399
# Oracle activations: 10996
# It's over 9000! 2021-11-10 23:00:00-08:00 2021-11-22 01:00:00-08:00
# Runtime total_E activations: 23962.27847877203
# Runtime total_E_pred activations: 211656.0136320862
# It's over 9000! 2021-11-10 23:00:00-08:00 2021-11-22 01:00:00-08:00
# Naive total_E activations: 10347.00107440601
# Naive total_E_pred activations: 14082.006131178232
# Dataset, train set, and test set size: 2211 1474 367
# Timeframe: 60min
# Minimal Application
# Naive vs. DL succesful activations: 0.000171939477303989
# Maximum possible activations: 10996
# Predicted activations: 123057
# Successful activations: 1, 0.001%
# Failed activations: 95812, 77.860%
# Missed activations: 10995, 99.991%
# Naive predicted activations (usual actual energy average): 15217
# Naive successful activations (usual actual energy average): 5816, 38.220%
# Naive failed activations (usual actual energy average): 9401, 61.780%
# Naive missed activations (usual actual energy average): 5180, 47.108%
# Voltage overestimation rate: 100.000%
# Test MAPE power: 1.869074
# Test MAPE voltage: 3.086367
# Test MAPE current: 0.118307
# Epoch 0, Iteration 0 Train Loss: 22023.71
# Epoch 0, Iteration 10 Train Loss: 2214.24
# Epoch 0, Iteration 20 Train Loss: 1750.80
# Epoch 0, Iteration 30 Train Loss: 1199.06
# Epoch 0, Iteration 40 Train Loss: 1416.59
# Epoch 0, Iteration 50 Train Loss: 1723.04
# Epoch 0, Iteration 60 Train Loss: 1241.31
# Epoch 0, Iteration 70 Train Loss: 2975.13
# Epoch 0, Iteration 80 Train Loss: 1848.36
# Epoch 0, Iteration 90 Train Loss: 2271.48
# Epoch 0, Iteration 100 Train Loss: 1476.44
# Epoch 0, Iteration 110 Train Loss: 1843.13
# Epoch 0, Iteration 120 Train Loss: 2002.87
# Epoch 0, Iteration 130 Train Loss: 1921.66
# Epoch 0, Iteration 140 Train Loss: 1815.84
# Epoch 0, Iteration 150 Train Loss: 2173.53
# Epoch 0, Iteration 160 Train Loss: 2296.93
# Epoch 0, Iteration 170 Train Loss: 1730.51
# Epoch 0, Iteration 180 Train Loss: 1828.53
# Epoch 0, Iteration 190 Train Loss: 1582.28
# Epoch 0, Iteration 200 Train Loss: 1401.03
# Epoch 0, Iteration 210 Train Loss: 1435.18
# Epoch 0, Iteration 220 Train Loss: 1894.03
# Epoch 0, Iteration 230 Train Loss: 1513.42
# Epoch 0, Iteration 240 Train Loss: 1333.09
# Epoch 0, Iteration 250 Train Loss: 813.98
# Epoch 0, Iteration 260 Train Loss: 857.90
# Epoch 0, Iteration 270 Train Loss: 317.48
# New Epoch! Avg loss for the last 100 iterations: 1236.7516720581054
# Epoch 1, Iteration 0 Train Loss: 20899.91
# Epoch 1, Iteration 10 Train Loss: 1154.24
# Epoch 1, Iteration 20 Train Loss: 701.67
# Epoch 1, Iteration 30 Train Loss: 280.06
# Epoch 1, Iteration 40 Train Loss: 430.01
# Epoch 1, Iteration 50 Train Loss: 577.99
# Epoch 1, Iteration 60 Train Loss: 364.46
# Epoch 1, Iteration 70 Train Loss: 1729.59
# Epoch 1, Iteration 80 Train Loss: 595.07
# Epoch 1, Iteration 90 Train Loss: 1202.94
# Epoch 1, Iteration 100 Train Loss: 319.41
# Epoch 1, Iteration 110 Train Loss: 501.15
# Epoch 1, Iteration 120 Train Loss: 799.21
# Epoch 1, Iteration 130 Train Loss: 601.02
# Epoch 1, Iteration 140 Train Loss: 402.07
# Epoch 1, Iteration 150 Train Loss: 748.66
# Epoch 1, Iteration 160 Train Loss: 749.40
# Epoch 1, Iteration 170 Train Loss: 272.45
# Epoch 1, Iteration 180 Train Loss: 484.19
# Epoch 1, Iteration 190 Train Loss: 157.79
# Epoch 1, Iteration 200 Train Loss: 272.81
# Epoch 1, Iteration 210 Train Loss: 104.33
# Epoch 1, Iteration 220 Train Loss: 369.08
# Epoch 1, Iteration 230 Train Loss: 153.76
# Epoch 1, Iteration 240 Train Loss: 116.92
# Epoch 1, Iteration 250 Train Loss: 164.20
# Epoch 1, Iteration 260 Train Loss: 179.53
# Epoch 1, Iteration 270 Train Loss: 38.34
# New Epoch! Avg loss for the last 100 iterations: 176.75044609069823
# Epoch 2, Iteration 0 Train Loss: 20185.08
# Epoch 2, Iteration 10 Train Loss: 585.78
# Epoch 2, Iteration 20 Train Loss: 69.31
# Epoch 2, Iteration 30 Train Loss: 37.71
# Epoch 2, Iteration 40 Train Loss: 83.38
# Epoch 2, Iteration 50 Train Loss: 55.86
# Epoch 2, Iteration 60 Train Loss: 182.57
# Epoch 2, Iteration 70 Train Loss: 1369.68
# Epoch 2, Iteration 80 Train Loss: 167.29
# Epoch 2, Iteration 90 Train Loss: 936.08
# Epoch 2, Iteration 100 Train Loss: 89.75
# Epoch 2, Iteration 110 Train Loss: 41.44
# Epoch 2, Iteration 120 Train Loss: 523.14
# Epoch 2, Iteration 130 Train Loss: 335.39
# Epoch 2, Iteration 140 Train Loss: 31.38
# Epoch 2, Iteration 150 Train Loss: 494.75
# Epoch 2, Iteration 160 Train Loss: 418.94
# Epoch 2, Iteration 170 Train Loss: 72.57
# Epoch 2, Iteration 180 Train Loss: 336.17
# Epoch 2, Iteration 190 Train Loss: 24.45
# Epoch 2, Iteration 200 Train Loss: 131.14
# Epoch 2, Iteration 210 Train Loss: 34.82
# Epoch 2, Iteration 220 Train Loss: 87.62
# Epoch 2, Iteration 230 Train Loss: 46.13
# Epoch 2, Iteration 240 Train Loss: 34.05
# Epoch 2, Iteration 250 Train Loss: 79.82
# Epoch 2, Iteration 260 Train Loss: 72.14
# Epoch 2, Iteration 270 Train Loss: 54.31
# New Epoch! Avg loss for the last 100 iterations: 73.94092569351196
# Epoch 3, Iteration 0 Train Loss: 19884.17
# Epoch 3, Iteration 10 Train Loss: 468.43
# Epoch 3, Iteration 20 Train Loss: 22.98
# Epoch 3, Iteration 30 Train Loss: 52.75
# Epoch 3, Iteration 40 Train Loss: 41.41
# Epoch 3, Iteration 50 Train Loss: 25.97
# Epoch 3, Iteration 60 Train Loss: 111.51
# Epoch 3, Iteration 70 Train Loss: 1217.82
# Epoch 3, Iteration 80 Train Loss: 46.74
# Epoch 3, Iteration 90 Train Loss: 805.12
# Epoch 3, Iteration 100 Train Loss: 41.92
# Epoch 3, Iteration 110 Train Loss: 20.32
# Epoch 3, Iteration 120 Train Loss: 389.53
# Epoch 3, Iteration 130 Train Loss: 231.04
# Epoch 3, Iteration 140 Train Loss: 21.90
# Epoch 3, Iteration 150 Train Loss: 369.43
# Epoch 3, Iteration 160 Train Loss: 296.12
# Epoch 3, Iteration 170 Train Loss: 33.04
# Epoch 3, Iteration 180 Train Loss: 263.83
# Epoch 3, Iteration 190 Train Loss: 33.29
# Epoch 3, Iteration 200 Train Loss: 66.87
# Epoch 3, Iteration 210 Train Loss: 38.44
# Epoch 3, Iteration 220 Train Loss: 34.88
# Epoch 3, Iteration 230 Train Loss: 29.79
# Epoch 3, Iteration 240 Train Loss: 27.90
# Epoch 3, Iteration 250 Train Loss: 53.03
# Epoch 3, Iteration 260 Train Loss: 43.63
# Epoch 3, Iteration 270 Train Loss: 62.81
# New Epoch! Avg loss for the last 100 iterations: 54.36867282867431
# Epoch 4, Iteration 0 Train Loss: 19725.05
# Epoch 4, Iteration 10 Train Loss: 407.96
# Epoch 4, Iteration 20 Train Loss: 31.38
# Epoch 4, Iteration 30 Train Loss: 61.12
# Epoch 4, Iteration 40 Train Loss: 49.72
# Epoch 4, Iteration 50 Train Loss: 33.42
# Epoch 4, Iteration 60 Train Loss: 76.96
# Epoch 4, Iteration 70 Train Loss: 1112.38
# Epoch 4, Iteration 80 Train Loss: 27.45
# Epoch 4, Iteration 90 Train Loss: 731.82
# Epoch 4, Iteration 100 Train Loss: 47.32
# Epoch 4, Iteration 110 Train Loss: 28.11
# Epoch 4, Iteration 120 Train Loss: 310.70
# Epoch 4, Iteration 130 Train Loss: 174.69
# Epoch 4, Iteration 140 Train Loss: 29.54
# Epoch 4, Iteration 150 Train Loss: 274.54
# Epoch 4, Iteration 160 Train Loss: 204.43
# Epoch 4, Iteration 170 Train Loss: 33.97
# Epoch 4, Iteration 180 Train Loss: 213.26
# Epoch 4, Iteration 190 Train Loss: 40.53
# Epoch 4, Iteration 200 Train Loss: 58.85
# Epoch 4, Iteration 210 Train Loss: 45.58
# Epoch 4, Iteration 220 Train Loss: 26.35
# Epoch 4, Iteration 230 Train Loss: 34.81
# Epoch 4, Iteration 240 Train Loss: 34.75
# Epoch 4, Iteration 250 Train Loss: 51.01
# Epoch 4, Iteration 260 Train Loss: 41.53
# Epoch 4, Iteration 270 Train Loss: 69.29
# New Epoch! Avg loss for the last 100 iterations: 52.85868638992309
# Epoch 5, Iteration 0 Train Loss: 19603.31
# Epoch 5, Iteration 10 Train Loss: 360.18
# Epoch 5, Iteration 20 Train Loss: 37.73
# Epoch 5, Iteration 30 Train Loss: 67.36
# Epoch 5, Iteration 40 Train Loss: 55.90
# Epoch 5, Iteration 50 Train Loss: 39.57
# Epoch 5, Iteration 60 Train Loss: 70.26
# Epoch 5, Iteration 70 Train Loss: 1023.57
# Epoch 5, Iteration 80 Train Loss: 33.46
# Epoch 5, Iteration 90 Train Loss: 679.24
# Epoch 5, Iteration 100 Train Loss: 53.22
# Epoch 5, Iteration 110 Train Loss: 33.93
# Epoch 5, Iteration 120 Train Loss: 256.88
# Epoch 5, Iteration 130 Train Loss: 135.70
# Epoch 5, Iteration 140 Train Loss: 35.22
# Epoch 5, Iteration 150 Train Loss: 218.52
# Epoch 5, Iteration 160 Train Loss: 141.74
# Epoch 5, Iteration 170 Train Loss: 39.43
# Epoch 5, Iteration 180 Train Loss: 175.47
# Epoch 5, Iteration 190 Train Loss: 45.70
# Epoch 5, Iteration 200 Train Loss: 60.75
# Epoch 5, Iteration 210 Train Loss: 50.50
# Epoch 5, Iteration 220 Train Loss: 27.63
# Epoch 5, Iteration 230 Train Loss: 39.56
# Epoch 5, Iteration 240 Train Loss: 39.41
# Epoch 5, Iteration 250 Train Loss: 52.21
# Epoch 5, Iteration 260 Train Loss: 43.07
# Epoch 5, Iteration 270 Train Loss: 73.70
# New Epoch! Avg loss for the last 100 iterations: 55.04367702484131
# Epoch 6, Iteration 0 Train Loss: 19520.56
# Epoch 6, Iteration 10 Train Loss: 326.19
# Epoch 6, Iteration 20 Train Loss: 42.29
# Epoch 6, Iteration 30 Train Loss: 71.94
# Epoch 6, Iteration 40 Train Loss: 60.47
# Epoch 6, Iteration 50 Train Loss: 44.12
# Epoch 6, Iteration 60 Train Loss: 69.54
# Epoch 6, Iteration 70 Train Loss: 947.73
# Epoch 6, Iteration 80 Train Loss: 38.01
# Epoch 6, Iteration 90 Train Loss: 633.34
# Epoch 6, Iteration 100 Train Loss: 57.74
# Epoch 6, Iteration 110 Train Loss: 38.43
# Epoch 6, Iteration 120 Train Loss: 212.53
# Epoch 6, Iteration 130 Train Loss: 109.04
# Epoch 6, Iteration 140 Train Loss: 39.64
# Epoch 6, Iteration 150 Train Loss: 176.21
# Epoch 6, Iteration 160 Train Loss: 99.64
# Epoch 6, Iteration 170 Train Loss: 43.75
# Epoch 6, Iteration 180 Train Loss: 141.59
# Epoch 6, Iteration 190 Train Loss: 50.16
# Epoch 6, Iteration 200 Train Loss: 63.70
# Epoch 6, Iteration 210 Train Loss: 55.05
# Epoch 6, Iteration 220 Train Loss: 30.74
# Epoch 6, Iteration 230 Train Loss: 44.13
# Epoch 6, Iteration 240 Train Loss: 43.96
# Epoch 6, Iteration 250 Train Loss: 55.03
# Epoch 6, Iteration 260 Train Loss: 46.64
# Epoch 6, Iteration 270 Train Loss: 78.16
# New Epoch! Avg loss for the last 100 iterations: 58.16828601837158
# Epoch 7, Iteration 0 Train Loss: 19436.10
# Epoch 7, Iteration 10 Train Loss: 293.74
# Epoch 7, Iteration 20 Train Loss: 46.74
# Epoch 7, Iteration 30 Train Loss: 76.32
# Epoch 7, Iteration 40 Train Loss: 64.82
# Epoch 7, Iteration 50 Train Loss: 48.44
# Epoch 7, Iteration 60 Train Loss: 73.84
# Epoch 7, Iteration 70 Train Loss: 875.08
# Epoch 7, Iteration 80 Train Loss: 42.24
# Epoch 7, Iteration 90 Train Loss: 589.91
# Epoch 7, Iteration 100 Train Loss: 61.93
# Epoch 7, Iteration 110 Train Loss: 42.59
# Epoch 7, Iteration 120 Train Loss: 179.03
# Epoch 7, Iteration 130 Train Loss: 84.93
# Epoch 7, Iteration 140 Train Loss: 43.74
# Epoch 7, Iteration 150 Train Loss: 143.19
# Epoch 7, Iteration 160 Train Loss: 70.64
# Epoch 7, Iteration 170 Train Loss: 47.71
# Epoch 7, Iteration 180 Train Loss: 112.48
# Epoch 7, Iteration 190 Train Loss: 54.05
# Epoch 7, Iteration 200 Train Loss: 67.06
# Epoch 7, Iteration 210 Train Loss: 58.90
# Epoch 7, Iteration 220 Train Loss: 34.12
# Epoch 7, Iteration 230 Train Loss: 47.96
# Epoch 7, Iteration 240 Train Loss: 47.79
# Epoch 7, Iteration 250 Train Loss: 58.83
# Epoch 7, Iteration 260 Train Loss: 50.07
# Epoch 7, Iteration 270 Train Loss: 81.94
# New Epoch! Avg loss for the last 100 iterations: 61.38369632720947
# Epoch 8, Iteration 0 Train Loss: 19364.17
# Epoch 8, Iteration 10 Train Loss: 270.02
# Epoch 8, Iteration 20 Train Loss: 50.63
# Epoch 8, Iteration 30 Train Loss: 80.21
# Epoch 8, Iteration 40 Train Loss: 68.70
# Epoch 8, Iteration 50 Train Loss: 52.30
# Epoch 8, Iteration 60 Train Loss: 77.68
# Epoch 8, Iteration 70 Train Loss: 807.61
# Epoch 8, Iteration 80 Train Loss: 46.07
# Epoch 8, Iteration 90 Train Loss: 549.37
# Epoch 8, Iteration 100 Train Loss: 65.71
# Epoch 8, Iteration 110 Train Loss: 46.34
# Epoch 8, Iteration 120 Train Loss: 147.82
# Epoch 8, Iteration 130 Train Loss: 68.58
# Epoch 8, Iteration 140 Train Loss: 47.23
# Epoch 8, Iteration 150 Train Loss: 111.74
# Epoch 8, Iteration 160 Train Loss: 49.97
# Epoch 8, Iteration 170 Train Loss: 51.01
# Epoch 8, Iteration 180 Train Loss: 89.86
# Epoch 8, Iteration 190 Train Loss: 57.23
# Epoch 8, Iteration 200 Train Loss: 70.74
# Epoch 8, Iteration 210 Train Loss: 61.98
# Epoch 8, Iteration 220 Train Loss: 37.77
# Epoch 8, Iteration 230 Train Loss: 51.04
# Epoch 8, Iteration 240 Train Loss: 50.84
# Epoch 8, Iteration 250 Train Loss: 61.92
# Epoch 8, Iteration 260 Train Loss: 53.38
# Epoch 8, Iteration 270 Train Loss: 85.16
# New Epoch! Avg loss for the last 100 iterations: 64.51632789611817
# Epoch 9, Iteration 0 Train Loss: 19302.87
# Epoch 9, Iteration 10 Train Loss: 249.31
# Epoch 9, Iteration 20 Train Loss: 54.07
# Epoch 9, Iteration 30 Train Loss: 83.69
# Epoch 9, Iteration 40 Train Loss: 72.18
# Epoch 9, Iteration 50 Train Loss: 55.76
# Epoch 9, Iteration 60 Train Loss: 81.14
# Epoch 9, Iteration 70 Train Loss: 751.24
# Epoch 9, Iteration 80 Train Loss: 49.54
# Epoch 9, Iteration 90 Train Loss: 510.27
# Epoch 9, Iteration 100 Train Loss: 69.15
# Epoch 9, Iteration 110 Train Loss: 49.77
# Epoch 9, Iteration 120 Train Loss: 124.76
# Epoch 9, Iteration 130 Train Loss: 55.11
# Epoch 9, Iteration 140 Train Loss: 50.79
# Epoch 9, Iteration 150 Train Loss: 90.27
# Epoch 9, Iteration 160 Train Loss: 37.01
# Epoch 9, Iteration 170 Train Loss: 54.61
# Epoch 9, Iteration 180 Train Loss: 77.12
# Epoch 9, Iteration 190 Train Loss: 60.84
# Epoch 9, Iteration 200 Train Loss: 73.66
# Epoch 9, Iteration 210 Train Loss: 65.62
# Epoch 9, Iteration 220 Train Loss: 40.71
# Epoch 9, Iteration 230 Train Loss: 54.66
# Epoch 9, Iteration 240 Train Loss: 54.46
# Epoch 9, Iteration 250 Train Loss: 65.51
# Epoch 9, Iteration 260 Train Loss: 56.48
# Epoch 9, Iteration 270 Train Loss: 88.68
# New Epoch! Avg loss for the last 100 iterations: 67.55155437469483
# ...
# Epoch 15, Iteration 270 Train Loss: 100.49
# Epoch 15, Iteration 280 Train Loss: 87.36
# Epoch 15, Iteration 290 Train Loss: 97.33
# Epoch 15, Iteration 300 Train Loss: 93.29
# Epoch 15, Iteration 310 Train Loss: 82.71
# Epoch 15, Iteration 320 Train Loss: 77.58
# Epoch 15, Iteration 330 Train Loss: 92.68
# Epoch 15, Iteration 340 Train Loss: 93.26
# Epoch 15, Iteration 350 Train Loss: 60.63
# Epoch 15, Iteration 360 Train Loss: 67.23
# New Epoch! Avg loss for the last 100 iterations: 86.80113403320313
# Epoch 16, Iteration 0 Train Loss: 19061.08
# Epoch 16, Iteration 10 Train Loss: 170.20
# Epoch 16, Iteration 20 Train Loss: 67.33
# Epoch 16, Iteration 30 Train Loss: 97.04
# Epoch 16, Iteration 40 Train Loss: 85.50
# Epoch 16, Iteration 50 Train Loss: 69.00
# Epoch 16, Iteration 60 Train Loss: 94.36
# Epoch 16, Iteration 70 Train Loss: 557.41
# Epoch 16, Iteration 80 Train Loss: 62.88
# Epoch 16, Iteration 90 Train Loss: 346.02
# Epoch 16, Iteration 100 Train Loss: 82.60
# Epoch 16, Iteration 110 Train Loss: 63.19
# Epoch 16, Iteration 120 Train Loss: 60.04
# Epoch 16, Iteration 130 Train Loss: 58.76
# Epoch 16, Iteration 140 Train Loss: 63.88
# Epoch 16, Iteration 150 Train Loss: 44.62
# Epoch 16, Iteration 160 Train Loss: 37.91
# Epoch 16, Iteration 170 Train Loss: 67.24
# Epoch 16, Iteration 180 Train Loss: 61.26
# Epoch 16, Iteration 190 Train Loss: 73.12
# Epoch 16, Iteration 200 Train Loss: 88.71
# Epoch 16, Iteration 210 Train Loss: 77.77
# Epoch 16, Iteration 220 Train Loss: 55.75
# Epoch 16, Iteration 230 Train Loss: 66.86
# Epoch 16, Iteration 240 Train Loss: 66.71
# Epoch 16, Iteration 250 Train Loss: 79.17
# Epoch 16, Iteration 260 Train Loss: 69.73
# Epoch 16, Iteration 270 Train Loss: 101.69
# Epoch 16, Iteration 280 Train Loss: 88.57
# Epoch 16, Iteration 290 Train Loss: 98.49
# Epoch 16, Iteration 300 Train Loss: 94.48
# Epoch 16, Iteration 310 Train Loss: 83.90
# Epoch 16, Iteration 320 Train Loss: 78.77
# Epoch 16, Iteration 330 Train Loss: 93.87
# Epoch 16, Iteration 340 Train Loss: 94.40
# Epoch 16, Iteration 350 Train Loss: 61.81
# Epoch 16, Iteration 360 Train Loss: 68.40
# New Epoch! Avg loss for the last 100 iterations: 87.99209510803223
# Epoch 17, Iteration 0 Train Loss: 19038.99
# Epoch 17, Iteration 10 Train Loss: 165.60
# Epoch 17, Iteration 20 Train Loss: 68.51
# Epoch 17, Iteration 30 Train Loss: 98.22
# Epoch 17, Iteration 40 Train Loss: 86.67
# Epoch 17, Iteration 50 Train Loss: 70.16
# Epoch 17, Iteration 60 Train Loss: 95.52
# Epoch 17, Iteration 70 Train Loss: 544.05
# Epoch 17, Iteration 80 Train Loss: 64.06
# Epoch 17, Iteration 90 Train Loss: 332.54
# Epoch 17, Iteration 100 Train Loss: 83.78
# Epoch 17, Iteration 110 Train Loss: 64.36
# Epoch 17, Iteration 120 Train Loss: 58.27
# Epoch 17, Iteration 130 Train Loss: 59.94
# Epoch 17, Iteration 140 Train Loss: 65.06
# Epoch 17, Iteration 150 Train Loss: 45.77
# Epoch 17, Iteration 160 Train Loss: 39.03
# Epoch 17, Iteration 170 Train Loss: 68.36
# Epoch 17, Iteration 180 Train Loss: 62.37
# Epoch 17, Iteration 190 Train Loss: 74.23
# Epoch 17, Iteration 200 Train Loss: 89.81
# Epoch 17, Iteration 210 Train Loss: 78.86
# Epoch 17, Iteration 220 Train Loss: 56.83
# Epoch 17, Iteration 230 Train Loss: 67.95
# Epoch 17, Iteration 240 Train Loss: 67.80
# Epoch 17, Iteration 250 Train Loss: 80.22
# Epoch 17, Iteration 260 Train Loss: 70.79
# Epoch 17, Iteration 270 Train Loss: 102.78
# Epoch 17, Iteration 280 Train Loss: 89.65
# Epoch 17, Iteration 290 Train Loss: 99.53
# Epoch 17, Iteration 300 Train Loss: 95.56
# Epoch 17, Iteration 310 Train Loss: 84.97
# Epoch 17, Iteration 320 Train Loss: 79.84
# Epoch 17, Iteration 330 Train Loss: 94.94
# Epoch 17, Iteration 340 Train Loss: 95.46
# Epoch 17, Iteration 350 Train Loss: 62.90
# Epoch 17, Iteration 360 Train Loss: 69.48
# New Epoch! Avg loss for the last 100 iterations: 89.07453510284424
# Epoch 18, Iteration 0 Train Loss: 19018.39
# Epoch 18, Iteration 10 Train Loss: 161.12
# Epoch 18, Iteration 20 Train Loss: 69.63
# Epoch 18, Iteration 30 Train Loss: 99.32
# Epoch 18, Iteration 40 Train Loss: 87.76
# Epoch 18, Iteration 50 Train Loss: 71.24
# Epoch 18, Iteration 60 Train Loss: 96.60
# Epoch 18, Iteration 70 Train Loss: 531.96
# Epoch 18, Iteration 80 Train Loss: 65.15
# Epoch 18, Iteration 90 Train Loss: 320.39
# Epoch 18, Iteration 100 Train Loss: 84.88
# Epoch 18, Iteration 110 Train Loss: 65.48
# Epoch 18, Iteration 120 Train Loss: 56.96
# Epoch 18, Iteration 130 Train Loss: 60.96
# Epoch 18, Iteration 140 Train Loss: 66.05
# Epoch 18, Iteration 150 Train Loss: 46.76
# Epoch 18, Iteration 160 Train Loss: 40.01
# Epoch 18, Iteration 170 Train Loss: 69.31
# Epoch 18, Iteration 180 Train Loss: 63.31
# Epoch 18, Iteration 190 Train Loss: 75.16
# Epoch 18, Iteration 200 Train Loss: 90.72
# Epoch 18, Iteration 210 Train Loss: 79.79
# Epoch 18, Iteration 220 Train Loss: 57.73
# Epoch 18, Iteration 230 Train Loss: 68.87
# Epoch 18, Iteration 240 Train Loss: 68.72
# Epoch 18, Iteration 250 Train Loss: 81.11
# Epoch 18, Iteration 260 Train Loss: 71.68
# Epoch 18, Iteration 270 Train Loss: 103.70
# Epoch 18, Iteration 280 Train Loss: 90.57
# Epoch 18, Iteration 290 Train Loss: 100.41
# Epoch 18, Iteration 300 Train Loss: 96.47
# Epoch 18, Iteration 310 Train Loss: 85.88
# Epoch 18, Iteration 320 Train Loss: 80.74
# Epoch 18, Iteration 330 Train Loss: 95.83
# Epoch 18, Iteration 340 Train Loss: 96.30
# Epoch 18, Iteration 350 Train Loss: 63.75
# Epoch 18, Iteration 360 Train Loss: 70.33
# New Epoch! Avg loss for the last 100 iterations: 89.94097873687744
# Epoch 19, Iteration 0 Train Loss: 19002.32
# Epoch 19, Iteration 10 Train Loss: 157.79
# Epoch 19, Iteration 20 Train Loss: 70.49
# Epoch 19, Iteration 30 Train Loss: 100.19
# Epoch 19, Iteration 40 Train Loss: 88.63
# Epoch 19, Iteration 50 Train Loss: 72.11
# Epoch 19, Iteration 60 Train Loss: 97.48
# Epoch 19, Iteration 70 Train Loss: 521.95
# Epoch 19, Iteration 80 Train Loss: 66.04
# Epoch 19, Iteration 90 Train Loss: 310.17
# Epoch 19, Iteration 100 Train Loss: 85.76
# Epoch 19, Iteration 110 Train Loss: 66.35
# Epoch 19, Iteration 120 Train Loss: 57.83
# Epoch 19, Iteration 130 Train Loss: 61.83
# Epoch 19, Iteration 140 Train Loss: 66.92
# Epoch 19, Iteration 150 Train Loss: 47.63
# Epoch 19, Iteration 160 Train Loss: 40.88
# Epoch 19, Iteration 170 Train Loss: 70.18
# Epoch 19, Iteration 180 Train Loss: 64.18
# Epoch 19, Iteration 190 Train Loss: 76.03
# Epoch 19, Iteration 200 Train Loss: 91.57
# Epoch 19, Iteration 210 Train Loss: 80.65
# Epoch 19, Iteration 220 Train Loss: 58.56
# Epoch 19, Iteration 230 Train Loss: 69.73
# Epoch 19, Iteration 240 Train Loss: 69.57
# Epoch 19, Iteration 250 Train Loss: 81.96
# Epoch 19, Iteration 260 Train Loss: 72.56
# Epoch 19, Iteration 270 Train Loss: 104.51
# Epoch 19, Iteration 280 Train Loss: 91.38
# Epoch 19, Iteration 290 Train Loss: 101.29
# Epoch 19, Iteration 300 Train Loss: 97.27
# Epoch 19, Iteration 310 Train Loss: 86.68
# Epoch 19, Iteration 320 Train Loss: 81.54
# Epoch 19, Iteration 330 Train Loss: 96.62
# Epoch 19, Iteration 340 Train Loss: 97.17
# Epoch 19, Iteration 350 Train Loss: 64.54
# Epoch 19, Iteration 360 Train Loss: 71.12
# New Epoch! Avg loss for the last 100 iterations: 90.75917461395264
# Epoch 20, Iteration 0 Train Loss: 18987.44
# Epoch 20, Iteration 10 Train Loss: 154.52
# Epoch 20, Iteration 20 Train Loss: 71.30
# Epoch 20, Iteration 30 Train Loss: 101.00
# Epoch 20, Iteration 40 Train Loss: 89.44
# Epoch 20, Iteration 50 Train Loss: 72.92
# Epoch 20, Iteration 60 Train Loss: 98.28
# Epoch 20, Iteration 70 Train Loss: 512.20
# Epoch 20, Iteration 80 Train Loss: 66.82
# Epoch 20, Iteration 90 Train Loss: 300.96
# Epoch 20, Iteration 100 Train Loss: 86.51
# Epoch 20, Iteration 110 Train Loss: 67.09
# Epoch 20, Iteration 120 Train Loss: 58.55
# Epoch 20, Iteration 130 Train Loss: 62.54
# Epoch 20, Iteration 140 Train Loss: 67.61
# Epoch 20, Iteration 150 Train Loss: 48.31
# Epoch 20, Iteration 160 Train Loss: 41.56
# Epoch 20, Iteration 170 Train Loss: 70.86
# Epoch 20, Iteration 180 Train Loss: 64.85
# Epoch 20, Iteration 190 Train Loss: 76.70
# Epoch 20, Iteration 200 Train Loss: 92.34
# Epoch 20, Iteration 210 Train Loss: 81.32
# Epoch 20, Iteration 220 Train Loss: 59.43
# Epoch 20, Iteration 230 Train Loss: 70.39
# Epoch 20, Iteration 240 Train Loss: 70.25
# Epoch 20, Iteration 250 Train Loss: 82.63
# Epoch 20, Iteration 260 Train Loss: 73.20
# Epoch 20, Iteration 270 Train Loss: 105.25
# Epoch 20, Iteration 280 Train Loss: 92.12
# Epoch 20, Iteration 290 Train Loss: 101.90
# Epoch 20, Iteration 300 Train Loss: 98.01
# Epoch 20, Iteration 310 Train Loss: 87.42
# Epoch 20, Iteration 320 Train Loss: 82.27
# Epoch 20, Iteration 330 Train Loss: 97.37
# Epoch 20, Iteration 340 Train Loss: 97.80
# Epoch 20, Iteration 350 Train Loss: 65.31
# Epoch 20, Iteration 360 Train Loss: 71.88
# New Epoch! Avg loss for the last 100 iterations: 91.49620178222656
# Epoch 21, Iteration 0 Train Loss: 18972.88
# Epoch 21, Iteration 10 Train Loss: 151.56
# Epoch 21, Iteration 20 Train Loss: 72.08
# Epoch 21, Iteration 30 Train Loss: 101.78
# Epoch 21, Iteration 40 Train Loss: 89.89
# Epoch 21, Iteration 50 Train Loss: 73.37
# Epoch 21, Iteration 60 Train Loss: 98.71
# Epoch 21, Iteration 70 Train Loss: 511.44
# Epoch 21, Iteration 80 Train Loss: 67.21
# Epoch 21, Iteration 90 Train Loss: 300.58
# Epoch 21, Iteration 100 Train Loss: 86.86
# Epoch 21, Iteration 110 Train Loss: 67.43
# Epoch 21, Iteration 120 Train Loss: 58.90
# Epoch 21, Iteration 130 Train Loss: 62.89
# Epoch 21, Iteration 140 Train Loss: 67.97
# Epoch 21, Iteration 150 Train Loss: 48.67
# Epoch 21, Iteration 160 Train Loss: 41.92
# Epoch 21, Iteration 170 Train Loss: 71.21
# Epoch 21, Iteration 180 Train Loss: 65.21
# Epoch 21, Iteration 190 Train Loss: 76.92
# Epoch 21, Iteration 200 Train Loss: 91.89
# Epoch 21, Iteration 210 Train Loss: 81.28
# Epoch 21, Iteration 220 Train Loss: 58.49
# Epoch 21, Iteration 230 Train Loss: 70.19
# Epoch 21, Iteration 240 Train Loss: 69.95
# Epoch 21, Iteration 250 Train Loss: 81.88
# Epoch 21, Iteration 260 Train Loss: 72.60
# Epoch 21, Iteration 270 Train Loss: 104.65
# Epoch 21, Iteration 280 Train Loss: 91.47
# Epoch 21, Iteration 290 Train Loss: 101.17
# Epoch 21, Iteration 300 Train Loss: 97.27
# Epoch 21, Iteration 310 Train Loss: 86.63
# Epoch 21, Iteration 320 Train Loss: 81.44
# Epoch 21, Iteration 330 Train Loss: 96.54
# Epoch 21, Iteration 340 Train Loss: 96.97
# Epoch 21, Iteration 350 Train Loss: 64.45
# Epoch 21, Iteration 360 Train Loss: 71.00
# New Epoch! Avg loss for the last 100 iterations: 91.00118942260742
# Epoch 22, Iteration 0 Train Loss: 18969.87
# Epoch 22, Iteration 10 Train Loss: 154.67
# Epoch 22, Iteration 20 Train Loss: 71.11
# Epoch 22, Iteration 30 Train Loss: 101.87
# Epoch 22, Iteration 40 Train Loss: 89.19
# Epoch 22, Iteration 50 Train Loss: 72.65
# Epoch 22, Iteration 60 Train Loss: 98.91
# Epoch 22, Iteration 70 Train Loss: 505.31
# Epoch 22, Iteration 80 Train Loss: 66.52
# Epoch 22, Iteration 90 Train Loss: 291.81
# Epoch 22, Iteration 100 Train Loss: 86.52
# Epoch 22, Iteration 110 Train Loss: 67.08
# Epoch 22, Iteration 120 Train Loss: 58.68
# Epoch 22, Iteration 130 Train Loss: 62.46
# Epoch 22, Iteration 140 Train Loss: 67.47
# Epoch 22, Iteration 150 Train Loss: 48.14
# Epoch 22, Iteration 160 Train Loss: 42.40
# Epoch 22, Iteration 170 Train Loss: 70.85
# Epoch 22, Iteration 180 Train Loss: 64.85
# Epoch 22, Iteration 190 Train Loss: 76.68
# Epoch 22, Iteration 200 Train Loss: 92.75
# Epoch 22, Iteration 210 Train Loss: 81.28
# Epoch 22, Iteration 220 Train Loss: 60.12
# Epoch 22, Iteration 230 Train Loss: 70.36
# Epoch 22, Iteration 240 Train Loss: 70.22
# Epoch 22, Iteration 250 Train Loss: 82.81
# Epoch 22, Iteration 260 Train Loss: 73.21
# Epoch 22, Iteration 270 Train Loss: 105.25
# Epoch 22, Iteration 280 Train Loss: 92.10
# Epoch 22, Iteration 290 Train Loss: 101.79
# Epoch 22, Iteration 300 Train Loss: 97.95
# Epoch 22, Iteration 310 Train Loss: 87.33
# Epoch 22, Iteration 320 Train Loss: 82.16
# Epoch 22, Iteration 330 Train Loss: 97.27
# Epoch 22, Iteration 340 Train Loss: 97.66
# Epoch 22, Iteration 350 Train Loss: 65.18
# Epoch 22, Iteration 360 Train Loss: 71.74
# New Epoch! Avg loss for the last 100 iterations: 91.70239856719971
# Epoch 23, Iteration 0 Train Loss: 18944.65
# Epoch 23, Iteration 10 Train Loss: 153.38
# Epoch 23, Iteration 20 Train Loss: 71.90
# Epoch 23, Iteration 30 Train Loss: 101.52
# Epoch 23, Iteration 40 Train Loss: 89.92
# Epoch 23, Iteration 50 Train Loss: 73.36
# Epoch 23, Iteration 60 Train Loss: 99.11
# Epoch 23, Iteration 70 Train Loss: 489.78
# Epoch 23, Iteration 80 Train Loss: 67.13
# Epoch 23, Iteration 90 Train Loss: 277.94
# Epoch 23, Iteration 100 Train Loss: 86.78
# Epoch 23, Iteration 110 Train Loss: 67.34
# Epoch 23, Iteration 120 Train Loss: 59.94
# Epoch 23, Iteration 130 Train Loss: 63.68
# Epoch 23, Iteration 140 Train Loss: 67.77
# Epoch 23, Iteration 150 Train Loss: 49.86
# Epoch 23, Iteration 160 Train Loss: 42.91
# Epoch 23, Iteration 170 Train Loss: 71.02
# Epoch 23, Iteration 180 Train Loss: 65.96
# Epoch 23, Iteration 190 Train Loss: 76.82
# Epoch 23, Iteration 200 Train Loss: 92.48
# Epoch 23, Iteration 210 Train Loss: 81.39
# Epoch 23, Iteration 220 Train Loss: 59.94
# Epoch 23, Iteration 230 Train Loss: 70.43
# Epoch 23, Iteration 240 Train Loss: 70.27
# Epoch 23, Iteration 250 Train Loss: 82.64
# Epoch 23, Iteration 260 Train Loss: 73.15
# Epoch 23, Iteration 270 Train Loss: 105.26
# Epoch 23, Iteration 280 Train Loss: 92.00
# Epoch 23, Iteration 290 Train Loss: 101.62
# Epoch 23, Iteration 300 Train Loss: 97.61
# Epoch 23, Iteration 310 Train Loss: 86.87
# Epoch 23, Iteration 320 Train Loss: 81.59
# Epoch 23, Iteration 330 Train Loss: 97.64
# Epoch 23, Iteration 340 Train Loss: 97.33
# Epoch 23, Iteration 350 Train Loss: 64.55
# Epoch 23, Iteration 360 Train Loss: 71.05
# New Epoch! Avg loss for the last 100 iterations: 91.36141368865967
# Epoch 24, Iteration 0 Train Loss: 18932.65
# Epoch 24, Iteration 10 Train Loss: 153.28
# Epoch 24, Iteration 20 Train Loss: 71.21
# Epoch 24, Iteration 30 Train Loss: 98.23
# Epoch 24, Iteration 40 Train Loss: 89.74
# Epoch 24, Iteration 50 Train Loss: 73.22
# Epoch 24, Iteration 60 Train Loss: 97.80
# Epoch 24, Iteration 70 Train Loss: 499.94
# Epoch 24, Iteration 80 Train Loss: 67.13
# Epoch 24, Iteration 90 Train Loss: 288.25
# Epoch 24, Iteration 100 Train Loss: 85.72
# Epoch 24, Iteration 110 Train Loss: 66.14
# Epoch 24, Iteration 120 Train Loss: 56.73
# Epoch 24, Iteration 130 Train Loss: 60.96
# Epoch 24, Iteration 140 Train Loss: 65.24
# Epoch 24, Iteration 150 Train Loss: 46.65
# Epoch 24, Iteration 160 Train Loss: 41.40
# Epoch 24, Iteration 170 Train Loss: 68.23
# Epoch 24, Iteration 180 Train Loss: 62.86
# Epoch 24, Iteration 190 Train Loss: 73.71
# Epoch 24, Iteration 200 Train Loss: 95.33
# Epoch 24, Iteration 210 Train Loss: 76.36
# Epoch 24, Iteration 220 Train Loss: 62.86
# Epoch 24, Iteration 230 Train Loss: 65.91
# Epoch 24, Iteration 240 Train Loss: 65.94
# Epoch 24, Iteration 250 Train Loss: 81.23
# Epoch 24, Iteration 260 Train Loss: 70.19
# Epoch 24, Iteration 270 Train Loss: 101.44
# Epoch 24, Iteration 280 Train Loss: 88.31
# Epoch 24, Iteration 290 Train Loss: 98.68
# Epoch 24, Iteration 300 Train Loss: 94.17
# Epoch 24, Iteration 310 Train Loss: 83.55
# Epoch 24, Iteration 320 Train Loss: 78.38
# Epoch 24, Iteration 330 Train Loss: 93.49
# Epoch 24, Iteration 340 Train Loss: 94.47
# Epoch 24, Iteration 350 Train Loss: 61.40
# Epoch 24, Iteration 360 Train Loss: 65.37
# New Epoch! Avg loss for the last 100 iterations: 87.8874264907837
# Oracle activations: 3948
# Runtime total_E activations: 3453.388158721049
# Runtime total_E_pred activations: 85525.46181033726
# Naive total_E activations: 3453.388158721049
# Naive total_E_pred activations: 4740.710587099603
# Dataset, train set, and test set size: 3680 2943 368
# Timeframe: 60min
# Minimal Application
# Naive vs. DL succesful activations: 0.0
# Maximum possible activations: 3948
# Predicted activations: 85775
# Successful activations: 0, 0.000%
# Failed activations: 85754, 99.976%
# Missed activations: 3948, 100.000%
# Naive predicted activations (usual actual energy average): 4881
# Naive successful activations (usual actual energy average): 1049, 21.491%
# Naive failed activations (usual actual energy average): 3832, 78.509%
# Naive missed activations (usual actual energy average): 2899, 73.430%
# Voltage overestimation rate: 100.000%
# Test MAPE power: 2.560718
# Test MAPE voltage: 4.244638
# Test MAPE current: 0.347500

# %%
# Print out predictions for power, voltage, and current
print("5-Minute-Ahead Predictions:")
print("Power Predictions (uW):")
print(y_test[:, 0])

print("\nVoltage Predictions (mV):")
print(y_test[:, 1])

print("\nCurrent Predictions (μA):")
print(y_test[:, 2])
# Out:
# 5-Minute-Ahead Predictions:
# Power Predictions (uW):
# tensor([405.1541, 341.6363, 381.8097, 378.0867, 448.1771, 309.7523, 319.9965,
#         283.5214, 377.2062, 293.7655, 324.5557, 314.3519, 329.7565, 280.7470,
#         290.2442, 314.8520, 253.1244, 216.8007, 238.8424, 293.0437, 278.7045,
#         247.5437, 247.1386, 288.8400, 263.1261, 318.4699, 305.4739, 341.9922,
#         306.8654, 314.7618, 264.4440, 270.7533, 300.5112, 277.7155, 306.7275,
#         278.6054, 260.1407, 259.2924, 272.8766, 306.1858, 299.8885, 256.6909,
#         233.9902, 271.3538, 282.8519, 285.3684, 323.8132, 355.6323, 314.4305,
#         308.6498, 336.6819, 356.4979, 323.8845, 364.1196, 340.2905, 317.3364,
#         339.4746, 308.2276, 345.0291, 294.6420, 294.0039, 309.0331, 289.7521,
#         284.8598, 247.1115, 284.5787, 253.3137, 270.9416, 258.9177, 285.2174,
#         327.3894, 334.6517, 345.3905, 343.8805, 347.8802, 350.3924, 316.4610,
#         347.2957, 342.1163, 330.5285, 331.4545, 330.0189, 288.2295, 275.7054,
#         276.2240, 290.5864, 360.0129, 289.0474, 273.2044, 241.9356, 259.2729,
#         281.9079, 285.6443, 313.7457, 289.6444, 313.6797, 372.7445, 355.5765,
#         311.0305, 317.6335, 329.6048, 297.9542, 310.3824, 316.3052, 294.2267,
#         259.8239, 289.7308, 293.4862, 261.3968, 279.9381, 268.8415, 262.6471,
#         253.1802, 187.2291, 213.0157, 245.0198, 250.1489, 254.2797, 229.0311,
#         274.7945, 267.7357, 297.0917, 382.8164, 298.9328, 266.1207, 255.5197,
#         285.0063, 257.6254, 332.7714, 230.3460, 280.2160, 249.1877, 239.9578,
#         237.1380, 296.4401, 243.0739, 208.6070, 199.9534, 226.0310, 232.1928,
#         257.0473, 219.8837, 242.6310, 283.7455, 300.4396, 284.9909, 336.1612,
#         390.4150, 243.8799, 337.0522, 264.2761, 267.2654, 254.5903, 257.6173,
#         234.1257, 265.9736, 242.7278, 228.7850, 265.6898, 248.6260, 235.0724,
#         178.9514, 198.7948, 234.2617, 248.9206, 297.1851, 215.9564, 275.9974,
#         294.5373, 265.5342, 321.7462, 302.1636, 370.6151, 263.0452, 275.4879,
#         266.5866, 274.3461, 454.0768, 277.3041, 273.8725, 298.7043, 237.2857,
#         247.7569, 240.4252, 210.2603, 178.2971, 164.6751, 224.2980, 211.7901,
#         195.0988, 339.0842, 246.1688, 307.7656, 360.5594, 262.3825, 258.1109,
#         339.9808, 270.4024, 288.8622, 269.6407, 220.7215, 260.6527, 243.8794,
#         329.8658, 244.4985, 248.2535, 273.5233, 258.5843, 224.9200, 208.1233,
#         221.3904, 242.0049, 222.8984, 270.3570, 254.4611, 282.5220, 291.1537,
#         305.3055, 396.3424, 281.9746, 304.0836, 292.4203, 380.7521, 244.8622,
#         293.4929, 273.0834, 254.3257, 224.4496, 248.8941, 267.0394, 265.2797,
#         356.4292, 205.6831, 190.7298, 195.7842, 230.0186, 208.6601, 190.6281,
#         243.1124, 243.2449, 286.8858, 292.3472, 283.1457, 245.6697, 275.3958,
#         258.3997, 244.7022, 253.7739, 264.1939, 241.0583, 237.6788, 295.9976,
#         244.4686, 264.7345, 239.9556, 224.2445, 180.8140, 191.6601, 189.2757,
#         450.2868, 204.5834, 190.0358, 270.4844, 248.1202, 260.2151, 267.9907,
#         252.7836, 235.8461, 245.2506, 254.6213, 255.1989, 245.2023, 228.3368,
#         285.5178, 266.0512, 397.9293, 241.4357, 250.2916, 257.0650, 247.9635,
#         224.7430, 218.5621, 226.1155, 212.8928, 297.9300, 251.5496, 287.5944,
#         318.9876, 294.8558, 349.1324, 346.1577, 287.4058, 312.1699, 315.3993,
#         295.6378, 332.4660, 272.2697, 302.0571, 278.0274, 381.3976, 380.6468,
#         245.8351, 271.9312, 228.5937, 216.9683, 225.1010, 244.2692, 251.1851,
#         242.3425, 246.3390, 267.2344, 329.9023, 341.0879, 373.8284, 346.5866,
#         313.5989, 453.1540, 343.7915, 341.5696, 291.1813, 276.4535, 285.6744,
#         354.3984, 312.8030, 264.1919, 263.2581, 253.8948, 315.9275, 274.3293,
#         278.5444, 222.1016, 242.3544, 283.2551, 242.1540, 284.9246, 296.9821,
#         290.6543, 319.3452, 297.0758, 329.2016, 273.6167, 307.0146, 301.7557,
#         266.4702, 239.6974, 255.7179, 382.0910, 267.8841, 319.4352, 260.1545,
#         289.7996, 399.7298, 262.5573, 240.7577, 218.9724, 271.9353, 250.2781,
#         207.9659, 243.9550, 355.0003, 309.4891, 260.2952, 396.5432, 350.8695,
#         293.8035, 320.8868, 289.5110, 283.7766, 269.0287, 284.2163, 285.4444,
#         282.6074, 234.0346, 267.3696, 221.4236, 197.0132, 210.1542, 194.1805,
#         209.5648, 251.4577, 250.1735, 269.2987, 226.0900, 261.1664, 267.4934,
#         286.4949, 271.7977, 282.9275, 243.2873, 274.1852, 360.1640, 267.5732,
#         328.2643, 280.1306, 264.4646, 257.2045, 296.1773, 254.7508, 228.8479,
#         337.8831, 198.3428, 219.5683, 169.3465, 215.1451, 222.3885, 206.0730,
#         217.6778, 224.1790, 277.1992, 267.7934, 232.2774, 268.9814, 264.3659,
#         261.2693, 238.1868, 279.2375, 259.2616, 365.7093, 249.4362, 242.8426,
#         244.2618, 243.5636, 226.8165, 240.5198, 175.0616, 185.2172, 170.6347,
#         206.7182, 187.1650, 187.6947, 298.2989, 203.1207, 255.0560, 218.5727,
#         227.2755, 273.8236, 246.7959, 234.9248, 242.5801, 233.4741, 240.5449,
#         273.2355, 277.8968, 266.0550, 213.1619, 220.8716, 175.3310, 185.5497,
#         164.5178, 165.9576, 149.8913, 163.9314, 175.3139, 155.3545, 313.8005,
#         355.3604, 225.9570, 239.1357, 228.2799, 360.6629, 255.5635, 347.2950,
#         230.5162, 212.6373, 226.9816, 227.1752, 198.7055, 204.8381, 211.7538,
#         205.2342, 200.3579, 181.8174, 158.1335, 134.0510, 132.3318, 165.3622,
#         266.8793, 208.1421, 147.1620, 167.6415, 207.8396, 206.6136, 203.1286,
#         221.1498, 274.0563, 318.9601, 368.5502, 359.4152, 402.2977, 183.0061,
#         165.8372, 194.1706, 368.5513, 204.9131, 176.0950, 185.5079, 175.4664,
#         185.0582, 146.9811, 229.5310, 289.3213, 185.2092, 152.2350, 182.8925,
#         190.5982, 209.7459, 220.8914, 328.0531, 255.6149, 222.0099, 199.8967,
#         205.8720, 195.1792, 174.6319, 200.5905, 297.9315, 273.0791, 186.5442,
#         206.2663, 204.3952, 236.6817, 186.5699, 187.2908, 206.7899, 179.3574,
#         157.5941, 124.5536, 171.5265, 205.4641, 207.5267, 216.0246, 218.1953,
#         234.3612, 222.1238, 190.5080, 221.7916, 194.1477, 210.9245, 225.3752,
#         199.4271, 211.5865, 182.4160, 198.9591, 153.9169, 148.1659, 121.3713,
#         123.6429, 125.5080, 145.6468, 269.9649, 134.2801, 183.9014],
#        dtype=torch.float64)
#
# Voltage Predictions (mV):
# tensor([1715.0614, 1608.9509, 1525.1824, 1453.6565, 1424.5207, 1331.0839,
#         1339.2222, 1351.9997, 1398.9220, 1338.9035, 1328.2953, 1280.2741,
#         1264.3933, 1260.4707, 1268.8703, 1305.3724, 1331.0019, 1368.5202,
#         1418.6382, 1439.8939, 1461.9994, 1476.1572, 1496.4433, 1490.9085,
#         1450.5998, 1444.4744, 1433.7796, 1416.6066, 1405.5881, 1405.7270,
#         1387.1994, 1401.9077, 1387.3782, 1386.9886, 1406.2478, 1393.1857,
#         1407.7098, 1392.6627, 1405.9145, 1402.7680, 1431.9323, 1466.6159,
#         1522.6876, 1597.4103, 1610.2085, 1640.8491, 1632.7948, 1626.4684,
#         1606.3638, 1577.3607, 1563.9291, 1563.4831, 1549.0130, 1522.1618,
#         1519.5919, 1475.0001, 1448.6612, 1406.1091, 1368.7394, 1351.5644,
#         1345.4279, 1340.9167, 1350.5214, 1350.7856, 1408.2013, 1451.1998,
#         1487.1080, 1564.9204, 1622.0074, 1672.6641, 1701.8766, 1680.6779,
#         1627.6902, 1533.0818, 1490.7195, 1414.6675, 1345.2742, 1337.8511,
#         1280.8321, 1268.7903, 1249.8509, 1241.8067, 1212.4941, 1179.7189,
#         1198.5095, 1215.3721, 1229.9601, 1251.2663, 1288.9646, 1323.1771,
#         1396.8187, 1449.8989, 1496.7560, 1533.7743, 1523.4149, 1489.8421,
#         1438.8862, 1369.7513, 1302.7948, 1290.6277, 1292.0064, 1256.0730,
#         1222.1850, 1168.5768, 1124.6385, 1128.3901, 1103.7148, 1070.3253,
#         1049.0319, 1020.5841, 1003.9058, 1003.8467, 1011.5696, 1068.9003,
#         1101.6059, 1150.9997, 1169.7879, 1210.8469, 1223.6963, 1223.7310,
#         1178.7494, 1138.7187, 1139.6351, 1110.4891, 1094.3773, 1089.7975,
#         1088.8788, 1064.0081, 1077.1852, 1073.5234, 1081.9896, 1056.2381,
#         1059.7314, 1059.4372, 1044.0576, 1062.1285, 1082.1739, 1131.7074,
#         1179.4949, 1204.3295, 1232.0438, 1277.2849, 1310.9235, 1296.3723,
#         1216.6032, 1206.1606, 1200.0394, 1193.1412, 1163.7849, 1133.7149,
#         1091.0599, 1098.4458, 1049.9209, 1030.6680, 1007.9720,  984.7550,
#          985.6459,  964.3205,  953.2440,  975.7754, 1002.0696, 1020.7400,
#         1080.7040, 1123.3720, 1173.7704, 1256.4631, 1281.2224, 1279.6215,
#         1224.0249, 1189.0534, 1180.5963, 1171.2043, 1149.5429, 1113.6993,
#         1103.8051, 1053.2935, 1060.4868, 1054.1185, 1001.6316,  983.2195,
#          974.2418,  930.9762,  935.9476,  949.2388,  992.7674, 1003.2607,
#         1044.1623, 1099.8283, 1121.2545, 1148.0460, 1222.2199, 1214.3820,
#         1162.1079, 1130.5452, 1082.8676, 1104.4345, 1138.3258, 1105.8280,
#         1065.5184, 1079.5981, 1058.1232, 1047.2599, 1042.5798, 1030.0836,
#         1001.1545,  984.0733,  968.7193,  992.7315, 1023.6324, 1058.5333,
#         1157.2048, 1248.4694, 1344.1696, 1394.4415, 1417.2121, 1390.9125,
#         1290.1645, 1281.6825, 1223.6755, 1209.2206, 1173.6810, 1134.3261,
#         1132.0235, 1095.6242, 1080.5305, 1071.3223, 1027.6390, 1027.9607,
#          988.6863,  981.9935,  952.7630,  978.3741,  984.8779, 1029.8128,
#         1077.0069, 1148.1595, 1212.1186, 1077.1083, 1304.4676, 1349.5584,
#         1325.0652, 1279.8072, 1233.7995, 1172.4505, 1142.1993, 1094.0641,
#         1074.8881, 1070.3029, 1031.0713, 1017.2610, 1001.0288,  990.6007,
#          980.6841,  965.9580,  951.7993,  943.4512,  964.5751,  999.6827,
#         1064.5107, 1146.2879, 1171.0143, 1219.1060, 1240.1069, 1236.3670,
#         1187.4504, 1150.2736, 1132.1715, 1120.7696, 1111.9506, 1118.0430,
#         1109.4304, 1114.7462, 1118.7929, 1117.6139, 1119.2740, 1131.9379,
#         1120.4759, 1134.3019, 1142.9101, 1135.6494, 1149.3511, 1196.7057,
#         1271.6086, 1346.4910, 1439.0864, 1489.3246, 1510.9529, 1515.0090,
#         1469.8014, 1414.8630, 1351.6630, 1335.4983, 1305.8105, 1307.5555,
#         1263.6065, 1221.5887, 1215.4744, 1200.8444, 1183.4133, 1178.6013,
#         1167.9047, 1155.8391, 1163.0760, 1161.1593, 1215.5838, 1244.4549,
#         1276.2655, 1344.7684, 1377.9773, 1409.6543, 1429.8763, 1792.1508,
#         1702.6863, 1541.3702, 1476.1916, 1404.6732, 1376.2440, 1331.4609,
#         1314.1199, 1256.0265, 1225.2751, 1180.7587, 1189.2357, 1140.7136,
#         1114.2770, 1089.9783, 1082.4253, 1128.7327, 1116.0834, 1205.9227,
#         1274.8258, 1331.4441, 1369.0857, 1386.1047, 1436.5747, 1430.0574,
#         1356.3685, 1300.0718, 1266.8707, 1231.2272, 1192.7500, 1182.4991,
#         1140.0071, 1143.1805, 1119.7122, 1140.2599, 1181.1577, 1181.1027,
#         1186.1041, 1195.9559, 1203.1207, 1254.9619, 1265.9389, 1289.8225,
#         1308.6702, 1313.3438, 1319.3795, 1363.6142, 1398.2633, 1396.5551,
#         1342.6044, 1275.4171, 1274.3004, 1242.4863, 1161.8756, 1142.0686,
#         1115.9000, 1102.8374, 1092.1780, 1081.9933, 1061.9824, 1025.3982,
#         1017.7164, 1015.1192, 1005.2184, 1018.6855, 1028.3084, 1083.2250,
#         1119.9448, 1153.4667, 1190.5627, 1264.9014, 1290.7034, 1299.0878,
#         1236.0039, 1191.3022, 1186.5863, 1147.9440, 1127.0603, 1118.1143,
#         1111.7388, 1082.8777, 1062.6950, 1036.3207, 1023.9452, 1017.5384,
#         1001.2625,  989.9440,  973.2391, 1005.3841, 1009.6863, 1049.3879,
#         1104.3884, 1184.6281, 1223.3109, 1270.3145, 1305.4907, 1278.3127,
#         1239.5568, 1208.4826, 1165.6183, 1146.3689, 1105.0321, 1069.4166,
#         1040.6369, 1020.1573, 1007.3721,  998.6788,  963.9514,  930.2328,
#          906.6527,  895.2713,  879.7120,  885.3789,  912.7702,  966.9020,
#          993.0576, 1035.8055, 1057.1812, 1067.7098, 1115.6710, 1090.6628,
#         1042.6594, 1047.0258, 1011.9228,  993.0127,  958.6926,  948.8660,
#          923.4906,  873.3436,  896.6621,  890.0815,  858.4694,  824.6413,
#          805.7796,  777.4565,  775.9596,  799.7436,  811.7989,  826.0752,
#          891.0659,  907.5975,  917.9060,  983.0426, 1050.4315, 1034.0162,
#          970.2483,  952.9545,  927.4237,  966.7092,  945.9275,  914.6709,
#          882.7677,  846.3601,  843.8410,  834.7083,  805.8556,  758.9653,
#          750.3405,  741.8872,  730.5571,  740.5374,  769.7388,  782.5505,
#          830.6102,  863.1375,  892.7178,  924.5849,  961.8699,  970.2179,
#          921.8162,  874.4663,  880.4153,  853.0157,  850.6739,  854.8351,
#          848.1863,  797.9864,  819.7359,  769.2486,  761.1967,  747.4224,
#          759.9577,  720.0805,  737.5933,  770.1237,  825.8250,  884.6812,
#          889.9102,  924.5219,  956.2523,  957.3573,  979.9445,  998.0792,
#          920.6514,  885.3840,  859.6494,  857.4398,  825.6230,  811.3558,
#          788.1574,  754.3983,  764.2515,  752.5438,  788.5954,  808.6017,
#          798.5331,  828.3250,  816.2631,  859.3105,  863.7119,  883.2825,
#          925.1886,  953.6760,  950.3996,  956.2570,  986.9478,  993.8827,
#          923.9542,  905.0045,  906.4842,  870.9428,  878.7799,  830.4210,
#          805.8997,  783.5866,  751.6167,  728.4369,  724.9102,  712.9822,
#          673.0484,  651.7146,  666.5715,  669.3205,  700.5713,  710.8084,
#          746.6158,  786.6107,  796.1181,  854.6173,  875.7239,  881.9870],
#        dtype=torch.float64)
#
# Current Predictions (μA):
# tensor([2344.6938, 2144.5200, 2491.2890, 2615.1175, 2729.0092, 2318.1900,
#         2390.2111, 2093.0794, 2328.5797, 2254.2704, 2413.2306, 2484.6177,
#         2609.2600, 2224.8339, 2286.4686, 2379.0941, 1896.1363, 1594.3170,
#         1692.2533, 2104.9973, 1896.5797, 1680.9964, 1643.6828, 1932.2318,
#         1816.2379, 2178.2355, 2114.4976, 2409.0612, 2185.6477, 2232.7373,
#         1905.9314, 1904.6886, 2198.3037, 2042.4849, 2178.9040, 2002.7997,
#         1834.6485, 1870.4582, 1909.3993, 2179.0800, 2086.4131, 1757.2456,
#         1534.2731, 1669.0292, 1755.7260, 1725.4358, 1985.1491, 2178.5923,
#         1949.2284, 1963.3811, 2166.8876, 2281.8618, 2106.8325, 2430.0004,
#         2237.6519, 2167.2517, 2348.0716, 2214.7201, 2546.8258, 2200.1255,
#         2195.7483, 2313.3872, 2155.8953, 2146.5258, 1755.3470, 1963.8766,
#         1726.2059, 1737.1070, 1615.6161, 1712.8471, 1930.4918, 1999.0615,
#         2091.2041, 2270.1137, 2311.0940, 2438.3263, 2436.0906, 2602.9523,
#         2723.5606, 2608.0064, 2666.9151, 2630.4309, 2341.4917, 2458.3140,
#         2322.3409, 2391.7374, 2346.5747, 2332.1564, 2136.8713, 1880.0454,
#         1863.5636, 1955.7716, 1926.8428, 2051.3292, 1916.9018, 2117.1734,
#         2585.0222, 2584.8097, 2462.7791, 2503.2507, 2507.7839, 2361.2873,
#         2544.8963, 2746.3178, 2700.0759, 2305.3073, 2627.2258, 2774.0314,
#         2504.3072, 2769.8116, 2712.8690, 2644.4145, 2555.4518, 1736.3953,
#         1947.8953, 2132.4233, 2182.5013, 2116.4073, 1901.6465, 2252.1226,
#         2290.9622, 2665.7872, 2825.4079, 2750.6830, 2480.4078, 2394.5208,
#         2598.6051, 2440.9221, 2679.9952, 2148.2734, 2571.7724, 2402.4105,
#         2282.7364, 2239.8911, 2881.8254, 2281.0208, 1959.7782, 1791.3458,
#         1935.9713, 1980.7592, 2115.4956, 1735.6329, 1860.6271, 2203.1820,
#         2544.8661, 2390.7153, 2594.2147, 2719.0246, 2136.0359, 2639.6320,
#         2563.9328, 2450.1802, 2465.5287, 2527.5615, 2398.5252, 2774.2458,
#         2491.8370, 2403.0108, 2832.0288, 2566.3527, 2394.6202, 1792.9745,
#         1852.9197, 2114.1870, 2155.5061, 2190.6680, 1735.9816, 2209.0626,
#         2437.4988, 2260.8398, 2717.6014, 2589.9919, 2679.6689, 2373.0204,
#         2496.8792, 2592.6249, 2585.4377, 3194.0701, 2844.2855, 2807.3049,
#         3053.6862, 2618.8090, 2683.7180, 2549.5896, 2101.3173, 1815.8692,
#         1614.8893, 2043.8161, 1902.9741, 1757.9817, 2175.4302, 2041.0258,
#         2503.2839, 2594.7786, 2532.3262, 2387.6333, 2418.8496, 2470.6479,
#         2809.7788, 2486.4644, 2102.5898, 2519.3169, 2361.1869, 2552.4622,
#         2463.8690, 2547.9580, 2901.7297, 2627.1468, 2199.5745, 2018.2950,
#         1924.0209, 1950.7830, 1653.3498, 1981.3263, 1842.0247, 2092.7179,
#         2350.0851, 2349.6496, 2857.1415, 2322.0853, 2645.3410, 2602.2026,
#         2973.1935, 2246.1095, 2714.5432, 2557.0563, 2542.7675, 2159.0584,
#         2584.3426, 2740.3347, 2857.0711, 2728.6203, 2169.9425, 1908.7770,
#         1866.7105, 2057.0905, 1729.2535, 1798.9019, 1884.7028, 1844.2951,
#         2212.5630, 2301.4822, 2272.5307, 2126.3138, 2437.3678, 2429.8122,
#         2340.7383, 2415.6615, 2667.6971, 2430.9851, 2430.4671, 3027.5864,
#         2527.3655, 2754.2127, 2536.6293, 2410.4216, 1919.8524, 1971.8775,
#         1787.0031, 2451.2667, 1814.5235, 1562.5687, 2188.1852, 1985.0494,
#         2212.2038, 2390.7586, 2263.7103, 2155.1825, 2266.5600, 2321.7546,
#         2353.2784, 2218.9400, 2050.5962, 2558.6516, 2393.8191, 2448.3427,
#         2174.8056, 2237.8644, 2245.0114, 2204.9348, 1982.8988, 1836.4378,
#         1794.3504, 1597.0284, 1913.1317, 1686.9967, 1909.5423, 2160.0027,
#         2033.7841, 2396.2221, 2535.3604, 2182.8338, 2414.2480, 2377.7299,
#         2326.6264, 2753.8517, 2271.7730, 2545.5321, 2336.1495, 2653.7407,
#         2727.0720, 2155.6958, 2323.7154, 2003.3332, 1787.5263, 1838.0564,
#         1940.0128, 1882.6248, 1773.9562, 1756.2802, 1883.8225, 1851.2195,
#         2000.8204, 2484.6801, 2356.9809, 2229.8979, 2697.6521, 2599.4220,
#         2322.6702, 2348.6225, 2263.2891, 2455.3573, 2710.0984, 2663.4945,
#         2388.0560, 2456.9712, 2376.3742, 2413.5114, 2520.4882, 1975.2124,
#         1749.3061, 1847.5043, 2059.4041, 1773.7525, 1964.8561, 2083.2583,
#         2194.3508, 2491.7553, 2339.3625, 2639.2156, 2335.1277, 2582.2918,
#         2661.0435, 2335.8584, 2200.8849, 2260.3629, 2688.2806, 2280.3716,
#         2512.3218, 2223.3708, 2473.7908, 2454.5226, 2069.1959, 1884.8644,
#         1673.0284, 2083.2044, 1917.8517, 1538.6444, 1760.9030, 2284.3455,
#         2314.3232, 2051.8961, 2651.3055, 2531.6691, 2620.1278, 2853.5905,
#         2644.4269, 2613.6578, 2488.2001, 2640.3772, 2677.6463, 2846.0044,
#         2309.2183, 2648.9558, 2224.9974, 1952.1446, 2064.6633, 1772.4536,
#         1875.5792, 2190.6223, 2132.7444, 1789.9976, 1773.2053, 2012.1521,
#         2179.7590, 2465.4487, 2292.1316, 2526.0073, 2216.6295, 2462.1566,
#         2762.2872, 2528.1178, 2583.8799, 2700.9449, 2608.0685, 2542.5121,
#         2665.5919, 2593.1207, 2427.0629, 2670.6339, 1995.7835, 1866.1886,
#         1553.7491, 1834.5227, 1853.3034, 1639.1052, 1680.0913, 1760.5112,
#         2256.5787, 2224.4523, 2052.8772, 2371.0793, 2449.0418, 2487.3081,
#         2306.3465, 2807.6179, 2522.2920, 2953.9525, 2664.8499, 2645.8049,
#         2752.6669, 2768.8190, 2642.9640, 2743.3117, 1961.8219, 1933.5880,
#         1747.9110, 2013.8466, 1766.0490, 1789.4408, 1930.5093, 1892.0541,
#         2470.5485, 2087.8130, 2321.0312, 2763.5183, 2570.9440, 2488.6102,
#         2661.5074, 2768.8365, 2642.7175, 2406.7414, 2741.5954, 2867.5959,
#         2663.4475, 2851.6499, 2326.9934, 2352.6838, 2030.2786, 2055.0582,
#         1669.6329, 1848.4799, 1957.8419, 1600.1869, 2025.8309, 2452.8780,
#         2348.1215, 2593.6432, 2501.7547, 2837.3269, 2654.7476, 3006.3029,
#         2605.3025, 2546.0426, 2782.2066, 2725.5871, 2438.4606, 2795.4878,
#         2844.1618, 2845.5679, 2823.0813, 2488.1231, 2033.4534, 1730.7774,
#         1628.7986, 1919.4373, 2193.0335, 1921.2960, 1556.9056, 1745.4558,
#         2280.1559, 2452.7893, 2295.6355, 2669.0742, 2771.6890, 2672.0932,
#         3067.5224, 3215.7576, 3145.2517, 2481.6576, 2256.9176, 2610.1519,
#         3219.3752, 2873.2689, 2411.4064, 2414.7449, 2149.9074, 1936.8686,
#         1680.1460, 2056.7925, 2260.6869, 1852.0438, 1587.2178, 1832.3790,
#         2128.1836, 2373.1105, 2624.2240, 3073.3343, 3125.4473, 2747.8671,
#         2548.4136, 2724.0346, 2563.4830, 2476.0849, 2557.8457, 2571.9823,
#         2813.3442, 2250.0892, 2596.9940, 2343.8030, 2582.7591, 2156.5604,
#         2062.6914, 2188.4879, 1918.0910, 1720.8945, 1286.4479, 1721.8148,
#         2298.4100, 2333.3176, 2396.6609, 2545.1771, 2656.8392, 2758.7605,
#         2406.9670, 2785.9987, 2680.7082, 2950.2764, 3176.1470, 2761.9530,
#         2693.2335, 2955.7664, 2926.4347, 2344.0532, 2104.6650, 1757.7262,
#         1695.1651, 1605.7162, 1831.4113, 1960.0539, 1554.2028, 1879.9440],
#        dtype=torch.float64)

# %% [markdown]
# ##  3. Graph Selected Data

# %% [markdown]
# ###  3.1 Load and graph pretrained SNN models
#
# ###  In order to use pretrained models it is neccesary to download the ```trained_models``` directory from [Hugging Face](https://huggingface.co/datasets/adunlop621/Soil_MFC/tree/main) and store it in the same directory as this notebook

# %%
from keras.models import load_model

time_frame = '60min'
batchsize = 8

X = pd.concat([df["power - 1h"], df["power - 2h"], df["power - 3h"], df["V1 - 1h"], df["V1 - 2h"], df["V1 - 3h"], df["I1L - 1h"], df["I1L - 2h"], df["I1L - 3h"],df["EC - 1h"], df["EC - 2h"], df["EC - 3h"], df["raw_VWC - 1h"], df["raw_VWC - 2h"], df["raw_VWC - 3h"], df["temp - 1h"], df["temp - 2h"], df["temp - 3h"], df["tsd"], df["hour"]], axis = 1)
#X = pd.concat([df["power - 1h"], df["power - 2h"], df["power - 3h"], df["V1 - 1h"], df["V1 - 2h"], df["V1 - 3h"], df["I1L - 1h"], df["I1L - 2h"], df["I1L - 3h"], df["tsd"], df["hour"]], axis = 1)
y = pd.concat([df["Power (uW)"], df['Voltage (mV)'], df['Current (uA)']], axis = 1)

#Normalize Data
X_normalized = ((X - X.min()) / (X.max() - X.min()))

#Split train and test sets
X_train, X_test = train_test_split(X_normalized, test_size=0.3, shuffle=False)
y_train, y_test = train_test_split(y, test_size=0.3, shuffle=False)

X_valid, X_test = train_test_split(X_test, test_size=0.5, shuffle=False)
y_valid, y_test = train_test_split(y_test, test_size=0.5, shuffle=False)

#Resample data

X_valid = X_valid.resample(time_frame).mean().dropna()
y_valid = y_valid.resample(time_frame).mean().dropna()

X_test = X_test.resample(time_frame).mean().dropna()
y_test = y_test.resample(time_frame).mean().dropna()

#Define mv1
mv1 = y_valid

#Reshape data
X_train = X_train.values.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_valid = X_valid.values.reshape((X_valid.shape[0], 1, X_valid.shape[1]))
X_test = X_test.values.reshape((X_test.shape[0], 1, X_test.shape[1]))

# convert to tensor
X_train = torch.tensor(X_train)
y_train = torch.tensor(y_train.values)
X_valid = torch.tensor(X_valid)
y_valid = torch.tensor(y_valid.values)
X_test = torch.tensor(X_test)
y_test = torch.tensor(y_test.values)

# make datasets
train_dataset = TensorDataset(X_train, y_train)
valid_dataset = TensorDataset(X_valid, y_valid)
test_dataset = TensorDataset(X_test, y_test)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=batchsize, shuffle=False)
valid_loader = DataLoader(valid_dataset, batch_size=batchsize, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batchsize, shuffle=False)

num_steps = 50
num_inputs = X_train.shape[2]

# create new inctance of the SNN Class
model = Net(num_inputs, num_steps).to(device)

model.load_state_dict(torch.load("trained_models/snn_60min_quant50", map_location=torch.device('cpu')))
model.eval()
actuals = []
predictions = []

with torch.no_grad():
    for data, targets in valid_loader:

        # prepare data
        data = data.to(device)
        targets = targets.to(device)

        data = data.float()
        targets = targets.float()

        _, _, _, output = model(data)

        output = output.cpu()
        output = output.squeeze(1).detach()

        prediction = output[-1]

        actuals.append(targets)
        predictions.append(prediction)

# Convert lists to tensors
actuals = torch.cat(actuals, dim=0)
predictions = torch.cat(predictions, dim=0)

mv1["power_pred_med"] = predictions[:, 0]
mv1["voltage_pred_med"] = predictions[:, 1]
mv1["current_pred_med"] = predictions[:, 2]
#mv1 = mv1.loc[(mv1.index > '2022-01-04') & (mv1.index < '2022-01-06')]
mv1 = mv1.loc[(mv1.index > '2021-12-12') & (mv1.index < '2021-12-14')]
mv2 = mv1
# Out:
# /var/folders/1g/jt7x_x9n6j1f3317_dwv3k9m0000gn/T/ipykernel_36727/3182949539.py:62: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("trained_models/snn_3min_quant50.pth", map_location=torch.device('cpu')), strict=False)

# %% [markdown]
# ###  3.2 SNN Peformance Metrics

# %%
from keras.models import load_model

# Set parameters
batchsize_list = [300, 150, 50, 20, 8]
time_frame_list = ['3min', '5min', '15min', '30min', '60min']
time_frame_seconds_list = [180, 300, 900, 1800, 3600]
n = 0

snn_power_mape_list = []
snn_volt_mape_list = []
snn_curr_mape_list = []

# Dictionary to store mv variables
mv_dict = {}

for j in range(len(batchsize_list)):
    batchsize = batchsize_list[j]
    time_frame = time_frame_list[j]
    time_frame_seconds = time_frame_seconds_list[j]

    X = pd.concat([df["power - 1h"], df["power - 2h"], df["power - 3h"], 
                   df["V1 - 1h"], df["V1 - 2h"], df["V1 - 3h"], 
                   df["I1L - 1h"], df["I1L - 2h"], df["I1L - 3h"], 
                   df["EC - 1h"], df["EC - 2h"], df["EC - 3h"], 
                   df["raw_VWC - 1h"], df["raw_VWC - 2h"], df["raw_VWC - 3h"], 
                   df["temp - 1h"], df["temp - 2h"], df["temp - 3h"], 
                   df["tsd"], df["hour"]], axis=1)
    y = pd.concat([df["Power (uW)"], df['Voltage (mV)'], df['Current (uA)']], axis=1)

    # Normalize Data
    X_normalized = ((X - X.min()) / (X.max() - X.min()))

    # Split train and test sets
    X_train, X_test = train_test_split(X_normalized, test_size=0.3, shuffle=False)
    y_train, y_test = train_test_split(y, test_size=0.3, shuffle=False)

    X_valid, X_test = train_test_split(X_test, test_size=0.5, shuffle=False)
    y_valid, y_test = train_test_split(y_test, test_size=0.5, shuffle=False)

    # Calculate actual energy generated in test set
    E_actual = 0
    for i in range(len(y_test) - 1):
        t = (y_test.index[i+1] - y_test.index[i]).total_seconds()
        if t < 180:
            E_actual += y_test['Power (uW)'][i] * t

    # Resample data
    X_valid = X_valid.resample(time_frame).mean().dropna()
    y_valid = y_valid.resample(time_frame).mean().dropna()

    X_test = X_test.resample(time_frame).mean().dropna()
    y_test = y_test.resample(time_frame).mean().dropna()

    # Define mv variable for the current time frame
    mv_dict[time_frame] = y_test

    # Reshape data
    X_train = X_train.values.reshape((X_train.shape[0], 1, X_train.shape[1]))
    X_valid = X_valid.values.reshape((X_valid.shape[0], 1, X_valid.shape[1]))
    X_test = X_test.values.reshape((X_test.shape[0], 1, X_test.shape[1]))

    # Convert to tensor
    X_train = torch.tensor(X_train)
    y_train = torch.tensor(y_train.values)
    X_valid = torch.tensor(X_valid)
    y_valid = torch.tensor(y_valid.values)
    X_test = torch.tensor(X_test)
    y_test = torch.tensor(y_test.values)

    # Make datasets
    train_dataset = TensorDataset(X_train, y_train)
    valid_dataset = TensorDataset(X_valid, y_valid)
    test_dataset = TensorDataset(X_test, y_test)

    # Create DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=batchsize, shuffle=False)
    valid_loader = DataLoader(valid_dataset, batch_size=batchsize, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batchsize, shuffle=False)

    num_steps = 50
    num_inputs = X_train.shape[2]

    # Create new instance of the SNN Class
    model = Net(num_inputs, num_steps).to(device)

    file = 'trained_models/snn_' + time_frame + '_quant50.pth'
    print(file)

    checkpoint = torch.load(file, map_location=torch.device('cpu'), weights_only=True)
    model.load_state_dict(checkpoint['state_dict'])

    model.eval()
    actuals = []
    predictions = []

    with torch.no_grad():
        for data, targets in test_loader:
            # Prepare data
            data = data.to(device).float()
            targets = targets.to(device).float()

            _, _, _, output = model(data)

            output = output.cpu().squeeze(1).detach()
            actuals.append(targets)
            predictions.append(output[-1])

    # Convert lists to tensors
    actuals = torch.cat(actuals, dim=0)
    predictions = torch.cat(predictions, dim=0)

    mv = mv_dict[time_frame]
    mv["power_pred_med_" + time_frame] = predictions[:, 0].numpy()
    mv["voltage_pred_med_" + time_frame] = predictions[:, 1].numpy()
    mv["current_pred_med_" + time_frame] = predictions[:, 2].numpy()

    print(f'Voltage overestimation rate for {time_frame}: %.3f%%' % (
        (mv['Voltage (mV)'].values <= mv["voltage_pred_med_" + time_frame]).mean() * 100))
    print(f"Test MAPE power ({time_frame}): %3f" % MAPE(mv['Power (uW)'].values.ravel(), mv["power_pred_med_" + time_frame]))
    print(f"Test MAPE voltage ({time_frame}): %3f" % MAPE(mv['Voltage (mV)'], mv["voltage_pred_med_" + time_frame]))
    print(f"Test MAPE current ({time_frame}): %3f" % MAPE(mv['Current (uA)'], mv["current_pred_med_" + time_frame]))

    E_pred = 0
    for i in range(len(mv) - 1):
        t = (mv.index[i+1] - mv.index[i]).total_seconds()
        if t <= time_frame_seconds + 50:
            E_pred += mv["power_pred_med_" + time_frame][i] * t

    print(f'Predicted vs. Actual Total Energy Percent Difference ({time_frame}): %.3f%%' % (
        (E_pred - E_actual) * 100 / E_actual))

    V_actual = mv['Voltage (mV)'].mean()
    V_pred = mv["voltage_pred_med_" + time_frame].mean()
    print(f'Predicted vs. Actual Total Voltage Percent Difference ({time_frame}): %.3f%%' % (
        (V_pred - V_actual) * 100 / V_actual))
# Out:
# trained_models/snn_3min_quant50.pth
# Voltage overestimation rate for 3min: 85.231%
# Test MAPE power (3min): 0.537724
# Test MAPE voltage (3min): 0.290864
# Test MAPE current (3min): 0.316784
# Predicted vs. Actual Total Energy Percent Difference (3min): 23.419%
# Predicted vs. Actual Total Voltage Percent Difference (3min): 21.857%
# trained_models/snn_5min_quant50.pth
# Voltage overestimation rate for 5min: 73.179%
# Test MAPE power (5min): 0.394733
# Test MAPE voltage (5min): 0.214422
# Test MAPE current (5min): 0.241269
# Predicted vs. Actual Total Energy Percent Difference (5min): 16.691%
# Predicted vs. Actual Total Voltage Percent Difference (5min): 12.812%
# trained_models/snn_15min_quant50.pth
# Voltage overestimation rate for 15min: 80.689%
# Test MAPE power (15min): 0.328628
# Test MAPE voltage (15min): 0.257437
# Test MAPE current (15min): 0.227218
# Predicted vs. Actual Total Energy Percent Difference (15min): 17.349%
# Predicted vs. Actual Total Voltage Percent Difference (15min): 17.903%
# trained_models/snn_30min_quant50.pth
# Voltage overestimation rate for 30min: 82.230%
# Test MAPE power (30min): 0.317190
# Test MAPE voltage (30min): 0.264197
# Test MAPE current (30min): 0.169668
# Predicted vs. Actual Total Energy Percent Difference (30min): 19.312%
# Predicted vs. Actual Total Voltage Percent Difference (30min): 18.920%
# trained_models/snn_60min_quant50.pth
# Voltage overestimation rate for 60min: 86.775%
# Test MAPE power (60min): 0.404176
# Test MAPE voltage (60min): 0.210382
# Test MAPE current (60min): 0.183518
# Predicted vs. Actual Total Energy Percent Difference (60min): 32.517%
# Predicted vs. Actual Total Voltage Percent Difference (60min): 16.774%

# %%
print(mv_dict)
# Out:
# {'3min':                            Power (uW)  Voltage (mV)  Current (uA)
# timestamp
# 2022-01-04 00:30:00-08:00  560.181385   1833.837429   2936.854571  \
# 2022-01-04 00:33:00-08:00  344.316142   1675.286143   2122.057714
# 2022-01-04 00:36:00-08:00  259.808313   1733.951462   1479.855846
# 2022-01-04 00:39:00-08:00  340.043036   1747.128077   1866.355385
# 2022-01-04 00:42:00-08:00  397.022258   1743.545692   2208.527462
# ...                               ...           ...           ...
# 2022-01-26 23:45:00-08:00  159.688701    892.816286   1724.953429
# 2022-01-26 23:48:00-08:00  153.143727    805.634462   2100.996769
# 2022-01-26 23:51:00-08:00  193.779752    872.273692   2170.535000
# 2022-01-26 23:54:00-08:00  179.846046    854.210154   2092.793308
# 2022-01-26 23:57:00-08:00  932.169339    992.999231   5453.417308
#
#                            power_pred_med_3min  voltage_pred_med_3min
# timestamp
# 2022-01-04 00:30:00-08:00           324.363861            1384.212402  \
# 2022-01-04 00:33:00-08:00           324.363861            1384.212402
# 2022-01-04 00:36:00-08:00           324.363861            1384.212402
# 2022-01-04 00:39:00-08:00           324.363861            1384.212402
# 2022-01-04 00:42:00-08:00           324.363861            1384.212402
# ...                                        ...                    ...
# 2022-01-26 23:45:00-08:00           324.363861            1384.212402
# 2022-01-26 23:48:00-08:00           324.363861            1384.212402
# 2022-01-26 23:51:00-08:00           324.363861            1384.212402
# 2022-01-26 23:54:00-08:00           324.363861            1384.212402
# 2022-01-26 23:57:00-08:00           324.363861            1384.212402
#
#                            current_pred_med_3min
# timestamp
# 2022-01-04 00:30:00-08:00            2302.888916
# 2022-01-04 00:33:00-08:00            2302.888916
# 2022-01-04 00:36:00-08:00            2302.888916
# 2022-01-04 00:39:00-08:00            2302.888916
# 2022-01-04 00:42:00-08:00            2302.888916
# ...                                          ...
# 2022-01-26 23:45:00-08:00            2302.888916
# 2022-01-26 23:48:00-08:00            2302.888916
# 2022-01-26 23:51:00-08:00            2302.888916
# 2022-01-26 23:54:00-08:00            2302.888916
# 2022-01-26 23:57:00-08:00            2302.888916
#
# [11030 rows x 6 columns], '5min':                            Power (uW)  Voltage (mV)  Current (uA)
# timestamp
# 2022-01-04 00:30:00-08:00  449.326587   1754.061500   2518.414937  \
# 2022-01-04 00:35:00-08:00  304.964404   1724.815773   1756.690955
# 2022-01-04 00:40:00-08:00  354.664104   1736.366591   1978.934227
# 2022-01-04 00:45:00-08:00  451.239370   1738.086955   2524.728364
# 2022-01-04 00:50:00-08:00  360.457335   1686.996409   2153.452318
# ...                               ...           ...           ...
# 2022-01-26 23:35:00-08:00  106.416799    865.671333   1290.900000
# 2022-01-26 23:40:00-08:00  158.997456    864.080545   1930.088318
# 2022-01-26 23:45:00-08:00  158.345707    860.220955   1884.459091
# 2022-01-26 23:50:00-08:00  175.978169    865.694864   2002.015955
# 2022-01-26 23:55:00-08:00  629.396444    925.264000   4194.434000
#
#                            power_pred_med_5min  voltage_pred_med_5min
# timestamp
# 2022-01-04 00:30:00-08:00           307.387634            1285.042480  \
# 2022-01-04 00:35:00-08:00           304.757172            1273.070801
# 2022-01-04 00:40:00-08:00           304.757172            1273.070801
# 2022-01-04 00:45:00-08:00           307.387634            1285.042480
# 2022-01-04 00:50:00-08:00           304.757172            1273.070801
# ...                                        ...                    ...
# 2022-01-26 23:35:00-08:00           304.757172            1273.070801
# 2022-01-26 23:40:00-08:00           304.757172            1273.070801
# 2022-01-26 23:45:00-08:00           304.757172            1273.070801
# 2022-01-26 23:50:00-08:00           304.757172            1273.070801
# 2022-01-26 23:55:00-08:00           304.757172            1273.070801
#
#                            current_pred_med_5min
# timestamp
# 2022-01-04 00:30:00-08:00            2279.441406
# 2022-01-04 00:35:00-08:00            2273.185547
# 2022-01-04 00:40:00-08:00            2273.185547
# 2022-01-04 00:45:00-08:00            2279.441406
# 2022-01-04 00:50:00-08:00            2273.185547
# ...                                          ...
# 2022-01-26 23:35:00-08:00            2273.185547
# 2022-01-26 23:40:00-08:00            2273.185547
# 2022-01-26 23:45:00-08:00            2273.185547
# 2022-01-26 23:50:00-08:00            2273.185547
# 2022-01-26 23:55:00-08:00            2273.185547
#
# [6618 rows x 6 columns], '15min':                            Power (uW)  Voltage (mV)  Current (uA)
# timestamp
# 2022-01-04 00:30:00-08:00  361.684210   1736.849933   2041.306550  \
# 2022-01-04 00:45:00-08:00  444.672151   1695.253652   2620.500409
# 2022-01-04 01:00:00-08:00  336.308184   1656.395394   2018.432076
# 2022-01-04 01:15:00-08:00  243.861510   1607.952485   1563.610000
# 2022-01-04 01:30:00-08:00  387.168138   1622.294136   2354.966212
# ...                               ...           ...           ...
# 2022-01-26 22:45:00-08:00  130.330872    876.765182   1534.027924
# 2022-01-26 23:00:00-08:00  122.890172    882.723061   1439.426455
# 2022-01-26 23:15:00-08:00  125.567011    885.558606   1451.223924
# 2022-01-26 23:30:00-08:00  165.631615    875.846554   1936.343677
# 2022-01-26 23:45:00-08:00  321.240107    883.726606   2693.636348
#
#                            power_pred_med_15min  voltage_pred_med_15min
# timestamp
# 2022-01-04 00:30:00-08:00            308.522156             1339.294678  \
# 2022-01-04 00:45:00-08:00            308.522156             1339.294678
# 2022-01-04 01:00:00-08:00            308.522156             1339.294678
# 2022-01-04 01:15:00-08:00            308.522156             1339.294678
# 2022-01-04 01:30:00-08:00            308.522156             1339.294678
# ...                                         ...                     ...
# 2022-01-26 22:45:00-08:00            308.522156             1339.294678
# 2022-01-26 23:00:00-08:00            308.522156             1339.294678
# 2022-01-26 23:15:00-08:00            308.522156             1339.294678
# 2022-01-26 23:30:00-08:00            308.522156             1339.294678
# 2022-01-26 23:45:00-08:00            308.522156             1339.294678
#
#                            current_pred_med_15min
# timestamp
# 2022-01-04 00:30:00-08:00             2590.055908
# 2022-01-04 00:45:00-08:00             2590.055908
# 2022-01-04 01:00:00-08:00             2590.055908
# 2022-01-04 01:15:00-08:00             2590.055908
# 2022-01-04 01:30:00-08:00             2590.055908
# ...                                           ...
# 2022-01-26 22:45:00-08:00             2590.055908
# 2022-01-26 23:00:00-08:00             2590.055908
# 2022-01-26 23:15:00-08:00             2590.055908
# 2022-01-26 23:30:00-08:00             2590.055908
# 2022-01-26 23:45:00-08:00             2590.055908
#
# [2206 rows x 6 columns], '30min':                            Power (uW)  Voltage (mV)  Current (uA)
# timestamp
# 2022-01-04 00:30:00-08:00  405.154084   1715.061405   2344.693810  \
# 2022-01-04 01:00:00-08:00  290.084847   1632.173939   1791.021038
# 2022-01-04 01:30:00-08:00  393.187770   1585.727795   2498.019000
# 2022-01-04 02:00:00-08:00  364.317906   1550.815644   2318.975258
# 2022-01-04 02:30:00-08:00  399.435097   1499.353443   2664.918183
# ...                               ...           ...           ...
# 2022-01-26 21:30:00-08:00  189.666397    860.226523   1854.389462
# 2022-01-26 22:00:00-08:00  125.684062    872.375909   1452.308417
# 2022-01-26 22:30:00-08:00  142.876165    879.071970   1656.097189
# 2022-01-26 23:00:00-08:00  124.228592    884.140833   1445.325189
# 2022-01-26 23:30:00-08:00  244.029786    879.816656   2317.880443
#
#                            power_pred_med_30min  voltage_pred_med_30min
# timestamp
# 2022-01-04 00:30:00-08:00            313.694153             1350.370605  \
# 2022-01-04 01:00:00-08:00            313.694153             1350.370605
# 2022-01-04 01:30:00-08:00            313.694153             1350.370605
# 2022-01-04 02:00:00-08:00            313.694153             1350.370605
# 2022-01-04 02:30:00-08:00            313.694153             1350.370605
# ...                                         ...                     ...
# 2022-01-26 21:30:00-08:00            313.694153             1350.370605
# 2022-01-26 22:00:00-08:00            313.694153             1350.370605
# 2022-01-26 22:30:00-08:00            313.694153             1350.370605
# 2022-01-26 23:00:00-08:00            313.694153             1350.370605
# 2022-01-26 23:30:00-08:00            313.694153             1350.370483
#
#                            current_pred_med_30min
# timestamp
# 2022-01-04 00:30:00-08:00             2448.522461
# 2022-01-04 01:00:00-08:00             2448.522461
# 2022-01-04 01:30:00-08:00             2448.522461
# 2022-01-04 02:00:00-08:00             2448.522461
# 2022-01-04 02:30:00-08:00             2448.522461
# ...                                           ...
# 2022-01-26 21:30:00-08:00             2448.522461
# 2022-01-26 22:00:00-08:00             2448.522461
# 2022-01-26 22:30:00-08:00             2448.522461
# 2022-01-26 23:00:00-08:00             2448.522461
# 2022-01-26 23:30:00-08:00             2448.522461
#
# [1103 rows x 6 columns], '60min':                            Power (uW)  Voltage (mV)  Current (uA)
# timestamp
# 2022-01-04 00:00:00-08:00  405.154084   1715.061405   2344.693810  \
# 2022-01-04 01:00:00-08:00  341.636308   1608.950867   2144.520019
# 2022-01-04 02:00:00-08:00  381.809739   1525.182380   2491.289034
# 2022-01-04 03:00:00-08:00  378.086693   1453.656542   2615.117542
# 2022-01-04 04:00:00-08:00  448.177092   1424.520742   2729.009246
# ...                               ...           ...           ...
# 2022-01-26 19:00:00-08:00  125.508030    786.610682   1605.716220
# 2022-01-26 20:00:00-08:00  145.646759    796.118125   1831.411269
# 2022-01-26 21:00:00-08:00  269.964851    854.617288   1960.053860
# 2022-01-26 22:00:00-08:00  134.280113    875.723939   1554.202803
# 2022-01-26 23:00:00-08:00  183.901430    881.986966   1879.943966
#
#                            power_pred_med_60min  voltage_pred_med_60min
# timestamp
# 2022-01-04 00:00:00-08:00            574.392090             2262.890869  \
# 2022-01-04 01:00:00-08:00            496.834778             1907.787720
# 2022-01-04 02:00:00-08:00            493.803589             1898.618042
# 2022-01-04 03:00:00-08:00            524.047058             2012.257935
# 2022-01-04 04:00:00-08:00            524.047058             2012.257935
# ...                                         ...                     ...
# 2022-01-26 19:00:00-08:00            335.677429             1270.873901
# 2022-01-26 20:00:00-08:00            335.677429             1270.873901
# 2022-01-26 21:00:00-08:00            335.677429             1270.873901
# 2022-01-26 22:00:00-08:00            336.232025             1276.566162
# 2022-01-26 23:00:00-08:00            336.232025             1276.566162
#
#                            current_pred_med_60min
# timestamp
# 2022-01-04 00:00:00-08:00             3076.218262
# 2022-01-04 01:00:00-08:00             2873.603271
# 2022-01-04 02:00:00-08:00             2869.821777
# 2022-01-04 03:00:00-08:00             2921.923340
# 2022-01-04 04:00:00-08:00             2921.923340
# ...                                           ...
# 2022-01-26 19:00:00-08:00             2271.680176
# 2022-01-26 20:00:00-08:00             2271.680176
# 2022-01-26 21:00:00-08:00             2271.680176
# 2022-01-26 22:00:00-08:00             2249.396484
# 2022-01-26 23:00:00-08:00             2249.396484
#
# [552 rows x 6 columns]}

# %% [markdown]
# # Student Model Architecture

# %%
# beta = 0.9

# # old design network
# # model = Sequential()
# # model.add(LSTM(200, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu'))
# # model.add(Dense(100, activation='relu'))
# # model.add(Dense(3))
# # model.compile(loss=quantile_loss, metrics=['mape'], optimizer='adam')

# # Define Network
# class StudentModel(nn.Module):
#     """
#         Args:
#             input_size (int): Number of input features (e.g., raw features + teacher predictions).
#             hidden_size (int): Number of hidden units in each LSTM layer.
#             output_size (int): Number of output features (e.g., predicting Power, Voltage, Current for 15, 30, 60 min).
#             num_layers (int): Number of LSTM layers.
#             dropout (float): Dropout rate for regularization.
#     """

#     def __init__(self, num_inputs, num_steps, output_size):
#         super(StudentModel, self).__init__()

#         self.num_inputs = num_inputs
#         self.num_steps = num_steps
#         self.output_size = output_size

#         # LSTM layer (Temporal modeling)
#         self.lstm = nn.LSTM(input_size=num_inputs, hidden_size=200, num_layers=1, batch_first=True)

#         # Fully connected layers (Feed-forward modeling)
#         self.fc1 = nn.Linear(200, 100)  # Map LSTM output to intermediate features.
#         self.fc2 = nn.Linear(100, output_size)  # Map intermediate features to final outputs.

#         # Activation functions
#         self.relu = nn.ReLU()
        
#     def forward(self, x):
#         """
#         Forward pass through the student model.
#         Args:
#             x (torch.Tensor): Input tensor of shape (batch_size, num_steps, num_inputs).
#         Returns:
#             torch.Tensor: Predictions for the specified time horizons.
#         """
#         # LSTM forward pass
#         lstm_out, _ = self.lstm(x)  # Output shape: (batch_size, num_steps, hidden_size)
#         lstm_out = lstm_out[:, -1, :]  # Take the last time step's output.

#         # Fully connected layers
#         fc1_out = self.relu(self.fc1(lstm_out))
#         output = self.fc2(fc1_out)

#         return output

# %% [markdown]
# ## Prepare Data for Student Model

# %%
# Load teacher predictions
timeframe = '5min'
teacher_5min_preds = mv_dict[timeframe]
teacher_5min_preds_df = pd.DataFrame(teacher_5min_preds, columns=["teacher_power_" + timeframe, "teacher_voltage_" + timeframe, "teacher_current_" + timeframe])

# Reset indices for both DataFrames
X = X.reset_index(drop=True)
teacher_5min_preds_df = teacher_5min_preds_df.reset_index(drop=True)

# Concatenate along the columns
X_with_teacher = pd.concat([X, teacher_5min_preds_df], axis=1)

# Verify the updated shape
print("Updated X Shape: Rows " + str(X_with_teacher.shape[0]) + " Columns " + str(X_with_teacher.shape[1]))
# Out:
# Updated X Shape: Rows 969652 Columns 23

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_with_teacher, y, test_size=0.2, random_state=42)

# Verify the shapes of the splits
print("Training set shape (X_train):", X_train.shape)
print("Training labels shape (y_train):", y_train.shape)
print("Test set shape (X_test):", X_test.shape)
print("Test labels shape (y_test):", y_test.shape)
# Out:
# Training set shape (X_train): (775721, 23)
# Training labels shape (y_train): (775721, 3)
# Test set shape (X_test): (193931, 23)
# Test labels shape (y_test): (193931, 3)

# %% [markdown]
# ## Train Student model

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
import numpy as np

# Assuming you have your dataset X and y loaded

# Define quantile loss function
def quantile_loss(y_true, y_pred, quantile=0.5):
    error = y_true - y_pred
    loss = torch.mean(torch.max(quantile * error, (quantile - 1) * error))
    return loss

# Define the StudentModel (as provided earlier)
class StudentModel(nn.Module):
    def __init__(self, num_inputs, num_steps, output_size):
        super(StudentModel, self).__init__()
        self.num_inputs = num_inputs
        self.num_steps = num_steps
        self.output_size = output_size

        self.lstm = nn.LSTM(input_size=num_inputs, hidden_size=200, num_layers=1, batch_first=True)
        self.fc1 = nn.Linear(200, 100)
        self.fc2 = nn.Linear(100, output_size)
        self.relu = nn.ReLU()

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        lstm_out = lstm_out[:, -1, :]
        fc1_out = self.relu(self.fc1(lstm_out))
        output = self.fc2(fc1_out)
        return output

# Set parameters
batch_size = 32  # Adjust as needed
num_epochs = 25
learning_rate = 1e-3
beta = 0.3  # For quantile loss

# Normalize Data
X_normalized = ((X - X.min()) / (X.max() - X.min()))

# Split train and test sets
X_train, X_test = train_test_split(X_normalized, test_size=0.3, shuffle=False)
y_train, y_test = train_test_split(y, test_size=0.3, shuffle=False)

# Split the test set further into validation and test sets
X_valid, X_test = train_test_split(X_test, test_size=0.5, shuffle=False)
y_valid, y_test = train_test_split(y_test, test_size=0.5, shuffle=False)

# Reshape data for LSTM input
X_train = X_train.values.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_valid = X_valid.values.reshape((X_valid.shape[0], 1, X_valid.shape[1]))
X_test = X_test.values.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Convert to tensor
X_train = torch.tensor(X_train).float()
y_train = torch.tensor(y_train.values).float()
X_valid = torch.tensor(X_valid).float()
y_valid = torch.tensor(y_valid.values).float()
X_test = torch.tensor(X_test).float()
y_test = torch.tensor(y_test.values).float()

# Create datasets
train_dataset = TensorDataset(X_train, y_train)
valid_dataset = TensorDataset(X_valid, y_valid)
test_dataset = TensorDataset(X_test, y_test)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Define model, optimizer, and loss function
num_steps = 1  # Since you're using LSTM for time series data with one step
num_inputs = X_train.shape[2]
output_size = y_train.shape[1]
model = StudentModel(num_inputs, num_steps, output_size).to(device)

optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate)

# Training loop
model.train()
for epoch in range(num_epochs):
    running_loss = 0.0
    for i, (data, targets) in enumerate(train_loader):
        data = data.to(device)
        targets = targets.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(data)

        # Compute the loss
        loss = quantile_loss(targets, outputs, quantile=0.5)

        # Backward pass and optimize
        loss.backward()
        optimizer.step()

        # Print statistics
        running_loss += loss.item()

        if i % 10 == 0:
            print(f"Epoch {epoch + 1}/{num_epochs}, Batch {i}/{len(train_loader)}, Loss: {loss.item():.4f}")

    print(f"Epoch {epoch + 1}/{num_epochs}, Average Loss: {running_loss / len(train_loader):.4f}")

# Validation loop
model.eval()
valid_loss = 0.0
with torch.no_grad():
    for data, targets in valid_loader:
        data = data.to(device)
        targets = targets.to(device)
        
        outputs = model(data)
        loss = quantile_loss(targets, outputs, quantile=0.5)
        valid_loss += loss.item()

print(f"Validation Loss: {valid_loss / len(valid_loader):.4f}")

# Test loop
test_loss = 0.0
with torch.no_grad():
    for data, targets in test_loader:
        data = data.to(device)
        targets = targets.to(device)
        
        outputs = model(data)
        loss = quantile_loss(targets, outputs, quantile=0.5)
        test_loss += loss.item()

print(f"Test Loss: {test_loss / len(test_loader):.4f}")
# Out:
# Epoch 1/25, Batch 0/21212, Loss: 11510.8154
# Epoch 1/25, Batch 10/21212, Loss: 11551.8818
# Epoch 1/25, Batch 20/21212, Loss: 11358.7432
# Epoch 1/25, Batch 30/21212, Loss: 11602.2549
# Epoch 1/25, Batch 40/21212, Loss: 11697.6250
# Epoch 1/25, Batch 50/21212, Loss: 11584.3516
# Epoch 1/25, Batch 60/21212, Loss: 11595.3984
# Epoch 1/25, Batch 70/21212, Loss: 11659.2920
# Epoch 1/25, Batch 80/21212, Loss: 11482.1338
# Epoch 1/25, Batch 90/21212, Loss: 11528.4834
# Epoch 1/25, Batch 100/21212, Loss: 11485.4756
# Epoch 1/25, Batch 110/21212, Loss: 797.7330
# Epoch 1/25, Batch 120/21212, Loss: 7652.8218
# Epoch 1/25, Batch 130/21212, Loss: 8966.7217
# Epoch 1/25, Batch 140/21212, Loss: 9524.6973
# Epoch 1/25, Batch 150/21212, Loss: 8974.8330
# Epoch 1/25, Batch 160/21212, Loss: 8777.5889
# Epoch 1/25, Batch 170/21212, Loss: 8549.2861
# Epoch 1/25, Batch 180/21212, Loss: 7184.4199
# Epoch 1/25, Batch 190/21212, Loss: 6319.5571
# Epoch 1/25, Batch 200/21212, Loss: 6364.0044
# Epoch 1/25, Batch 210/21212, Loss: 6646.7603
# Epoch 1/25, Batch 220/21212, Loss: 6208.5698
# Epoch 1/25, Batch 230/21212, Loss: 5356.4761
# Epoch 1/25, Batch 240/21212, Loss: 5008.9287
# Epoch 1/25, Batch 250/21212, Loss: 5459.2148
# Epoch 1/25, Batch 260/21212, Loss: 5784.9595
# Epoch 1/25, Batch 270/21212, Loss: 6003.2007
# Epoch 1/25, Batch 280/21212, Loss: 5767.8403
# Epoch 1/25, Batch 290/21212, Loss: 5572.5386
# Epoch 1/25, Batch 300/21212, Loss: 4832.9072
# Epoch 1/25, Batch 310/21212, Loss: 6596.0122
# Epoch 1/25, Batch 320/21212, Loss: 5741.0415
# Epoch 1/25, Batch 330/21212, Loss: 2879.7334
# Epoch 1/25, Batch 340/21212, Loss: 2262.0969
# Epoch 1/25, Batch 350/21212, Loss: 1342.3540
# Epoch 1/25, Batch 360/21212, Loss: 897.2838
# Epoch 1/25, Batch 370/21212, Loss: 540.6933
# Epoch 1/25, Batch 380/21212, Loss: 549.2518
# Epoch 1/25, Batch 390/21212, Loss: 619.3438
# Epoch 1/25, Batch 400/21212, Loss: 590.2654
# Epoch 1/25, Batch 410/21212, Loss: 610.4284
# Epoch 1/25, Batch 420/21212, Loss: 661.6393
# Epoch 1/25, Batch 430/21212, Loss: 410.9932
# Epoch 1/25, Batch 440/21212, Loss: 460.6294
# Epoch 1/25, Batch 450/21212, Loss: 439.2909
# Epoch 1/25, Batch 460/21212, Loss: 409.1602
# Epoch 1/25, Batch 470/21212, Loss: 592.1561
# Epoch 1/25, Batch 480/21212, Loss: 427.6394
# Epoch 1/25, Batch 490/21212, Loss: 474.0693
# Epoch 1/25, Batch 500/21212, Loss: 569.0024
# Epoch 1/25, Batch 510/21212, Loss: 562.6091
# Epoch 1/25, Batch 520/21212, Loss: 516.4233
# Epoch 1/25, Batch 530/21212, Loss: 493.2340
# Epoch 1/25, Batch 540/21212, Loss: 464.3962
# Epoch 1/25, Batch 550/21212, Loss: 523.3799
# Epoch 1/25, Batch 560/21212, Loss: 449.2180
# Epoch 1/25, Batch 570/21212, Loss: 379.6859
# Epoch 1/25, Batch 580/21212, Loss: 480.2387
# Epoch 1/25, Batch 590/21212, Loss: 474.6727
# Epoch 1/25, Batch 600/21212, Loss: 399.5202
# Epoch 1/25, Batch 610/21212, Loss: 489.2234
# Epoch 1/25, Batch 620/21212, Loss: 424.7719
# Epoch 1/25, Batch 630/21212, Loss: 300.7795
# Epoch 1/25, Batch 640/21212, Loss: 613.0439
# Epoch 1/25, Batch 650/21212, Loss: 685.4099
# Epoch 1/25, Batch 660/21212, Loss: 748.9785
# Epoch 1/25, Batch 670/21212, Loss: 981.7565
# Epoch 1/25, Batch 680/21212, Loss: 1090.7915
# Epoch 1/25, Batch 690/21212, Loss: 843.6119
# Epoch 1/25, Batch 700/21212, Loss: 287.7417
# Epoch 1/25, Batch 710/21212, Loss: 302.3591
# Epoch 1/25, Batch 720/21212, Loss: 312.6166
# Epoch 1/25, Batch 730/21212, Loss: 411.9551
# Epoch 1/25, Batch 740/21212, Loss: 366.6953
# Epoch 1/25, Batch 750/21212, Loss: 462.7075
# Epoch 1/25, Batch 760/21212, Loss: 480.5771
# Epoch 1/25, Batch 770/21212, Loss: 421.9933
# Epoch 1/25, Batch 780/21212, Loss: 426.9607
# Epoch 1/25, Batch 790/21212, Loss: 518.6139
# Epoch 1/25, Batch 800/21212, Loss: 458.6660
# Epoch 1/25, Batch 810/21212, Loss: 342.1707
# Epoch 1/25, Batch 820/21212, Loss: 375.6399
# Epoch 1/25, Batch 830/21212, Loss: 258.0067
# Epoch 1/25, Batch 840/21212, Loss: 279.4447
# Epoch 1/25, Batch 850/21212, Loss: 373.7034
# Epoch 1/25, Batch 860/21212, Loss: 263.1377
# Epoch 1/25, Batch 870/21212, Loss: 214.2920
# Epoch 1/25, Batch 880/21212, Loss: 262.0989
# Epoch 1/25, Batch 890/21212, Loss: 290.4034
# Epoch 1/25, Batch 900/21212, Loss: 292.8518
# Epoch 1/25, Batch 910/21212, Loss: 343.4943
# Epoch 1/25, Batch 920/21212, Loss: 476.7579
# Epoch 1/25, Batch 930/21212, Loss: 482.8836
# Epoch 1/25, Batch 940/21212, Loss: 452.3652
# Epoch 1/25, Batch 950/21212, Loss: 423.0696
# Epoch 1/25, Batch 960/21212, Loss: 432.6013
# Epoch 1/25, Batch 970/21212, Loss: 299.0831
# Epoch 1/25, Batch 980/21212, Loss: 389.2959
# Epoch 1/25, Batch 990/21212, Loss: 329.2046
# Epoch 1/25, Batch 1000/21212, Loss: 353.8769
# Epoch 1/25, Batch 1010/21212, Loss: 435.7585
# Epoch 1/25, Batch 1020/21212, Loss: 231.7085
# Epoch 1/25, Batch 1030/21212, Loss: 249.0730
# Epoch 1/25, Batch 1040/21212, Loss: 371.2391
# Epoch 1/25, Batch 1050/21212, Loss: 333.3009
# Epoch 1/25, Batch 1060/21212, Loss: 269.7850
# Epoch 1/25, Batch 1070/21212, Loss: 160.0615
# Epoch 1/25, Batch 1080/21212, Loss: 1218.4767
# Epoch 1/25, Batch 1090/21212, Loss: 1666.2489
# Epoch 1/25, Batch 1100/21212, Loss: 1572.5900
# Epoch 1/25, Batch 1110/21212, Loss: 1392.0743
# Epoch 1/25, Batch 1120/21212, Loss: 1280.4418
# Epoch 1/25, Batch 1130/21212, Loss: 1158.3702
# Epoch 1/25, Batch 1140/21212, Loss: 1063.5991
# Epoch 1/25, Batch 1150/21212, Loss: 931.6943
# Epoch 1/25, Batch 1160/21212, Loss: 848.2087
# Epoch 1/25, Batch 1170/21212, Loss: 760.8307
# Epoch 1/25, Batch 1180/21212, Loss: 626.0579
# Epoch 1/25, Batch 1190/21212, Loss: 758.7216
# Epoch 1/25, Batch 1200/21212, Loss: 589.1050
# Epoch 1/25, Batch 1210/21212, Loss: 505.9545
# Epoch 1/25, Batch 1220/21212, Loss: 472.6998
# Epoch 1/25, Batch 1230/21212, Loss: 443.6924
# Epoch 1/25, Batch 1240/21212, Loss: 300.1776
# Epoch 1/25, Batch 1250/21212, Loss: 317.2466
# Epoch 1/25, Batch 1260/21212, Loss: 377.3027
# Epoch 1/25, Batch 1270/21212, Loss: 307.3987
# Epoch 1/25, Batch 1280/21212, Loss: 304.8833
# Epoch 1/25, Batch 1290/21212, Loss: 272.7609
# Epoch 1/25, Batch 1300/21212, Loss: 383.0083
# Epoch 1/25, Batch 1310/21212, Loss: 514.6729
# Epoch 1/25, Batch 1320/21212, Loss: 555.3391
# Epoch 1/25, Batch 1330/21212, Loss: 492.8485
# Epoch 1/25, Batch 1340/21212, Loss: 471.3783
# Epoch 1/25, Batch 1350/21212, Loss: 608.3708
# Epoch 1/25, Batch 1360/21212, Loss: 455.2035
# Epoch 1/25, Batch 1370/21212, Loss: 455.3708
# Epoch 1/25, Batch 1380/21212, Loss: 337.8374
# Epoch 1/25, Batch 1390/21212, Loss: 383.6918
# Epoch 1/25, Batch 1400/21212, Loss: 419.9526
# Epoch 1/25, Batch 1410/21212, Loss: 971.2290
# Epoch 1/25, Batch 1420/21212, Loss: 1620.2094
# Epoch 1/25, Batch 1430/21212, Loss: 1122.5029
# Epoch 1/25, Batch 1440/21212, Loss: 880.0521
# Epoch 1/25, Batch 1450/21212, Loss: 685.6497
# Epoch 1/25, Batch 1460/21212, Loss: 641.0328
# Epoch 1/25, Batch 1470/21212, Loss: 723.4622
# Epoch 1/25, Batch 1480/21212, Loss: 523.0797
# Epoch 1/25, Batch 1490/21212, Loss: 485.3602
# Epoch 1/25, Batch 1500/21212, Loss: 515.4455
# Epoch 1/25, Batch 1510/21212, Loss: 465.2143
# Epoch 1/25, Batch 1520/21212, Loss: 408.6289
# Epoch 1/25, Batch 1530/21212, Loss: 517.8701
# Epoch 1/25, Batch 1540/21212, Loss: 581.2208
# Epoch 1/25, Batch 1550/21212, Loss: 511.4389
# Epoch 1/25, Batch 1560/21212, Loss: 577.9542
# Epoch 1/25, Batch 1570/21212, Loss: 511.4919
# Epoch 1/25, Batch 1580/21212, Loss: 460.0091
# Epoch 1/25, Batch 1590/21212, Loss: 414.0299
# Epoch 1/25, Batch 1600/21212, Loss: 479.4381
# Epoch 1/25, Batch 1610/21212, Loss: 369.7357
# Epoch 1/25, Batch 1620/21212, Loss: 343.1382
# Epoch 1/25, Batch 1630/21212, Loss: 162.3729
# Epoch 1/25, Batch 1640/21212, Loss: 220.6811
# Epoch 1/25, Batch 1650/21212, Loss: 250.8665
# Epoch 1/25, Batch 1660/21212, Loss: 218.3344
# Epoch 1/25, Batch 1670/21212, Loss: 196.6561
# Epoch 1/25, Batch 1680/21212, Loss: 211.5496
# Epoch 1/25, Batch 1690/21212, Loss: 212.3852
# Epoch 1/25, Batch 1700/21212, Loss: 385.8861
# Epoch 1/25, Batch 1710/21212, Loss: 451.7946
# Epoch 1/25, Batch 1720/21212, Loss: 532.4653
# Epoch 1/25, Batch 1730/21212, Loss: 440.5323
# Epoch 1/25, Batch 1740/21212, Loss: 501.9565
# Epoch 1/25, Batch 1750/21212, Loss: 507.1187
# Epoch 1/25, Batch 1760/21212, Loss: 468.0184
# Epoch 1/25, Batch 1770/21212, Loss: 428.9922
# Epoch 1/25, Batch 1780/21212, Loss: 436.4654
# Epoch 1/25, Batch 1790/21212, Loss: 451.5741
# Epoch 1/25, Batch 1800/21212, Loss: 335.8439
# Epoch 1/25, Batch 1810/21212, Loss: 344.8556
# Epoch 1/25, Batch 1820/21212, Loss: 163.7122
# Epoch 1/25, Batch 1830/21212, Loss: 156.3236
# Epoch 1/25, Batch 1840/21212, Loss: 259.8772
# Epoch 1/25, Batch 1850/21212, Loss: 271.4831
# Epoch 1/25, Batch 1860/21212, Loss: 251.5479
# Epoch 1/25, Batch 1870/21212, Loss: 290.6748
# Epoch 1/25, Batch 1880/21212, Loss: 186.3652
# Epoch 1/25, Batch 1890/21212, Loss: 304.9785
# Epoch 1/25, Batch 1900/21212, Loss: 307.3174
# Epoch 1/25, Batch 1910/21212, Loss: 364.4467
# Epoch 1/25, Batch 1920/21212, Loss: 492.9223
# Epoch 1/25, Batch 1930/21212, Loss: 348.8854
# Epoch 1/25, Batch 1940/21212, Loss: 326.3440
# Epoch 1/25, Batch 1950/21212, Loss: 487.9284
# Epoch 1/25, Batch 1960/21212, Loss: 436.7997
# Epoch 1/25, Batch 1970/21212, Loss: 328.0200
# Epoch 1/25, Batch 1980/21212, Loss: 324.7137
# Epoch 1/25, Batch 1990/21212, Loss: 475.2060
# Epoch 1/25, Batch 2000/21212, Loss: 223.5294
# Epoch 1/25, Batch 2010/21212, Loss: 170.7384
# Epoch 1/25, Batch 2020/21212, Loss: 198.4516
# Epoch 1/25, Batch 2030/21212, Loss: 137.1050
# Epoch 1/25, Batch 2040/21212, Loss: 200.9344
# Epoch 1/25, Batch 2050/21212, Loss: 238.8825
# Epoch 1/25, Batch 2060/21212, Loss: 170.6220
# Epoch 1/25, Batch 2070/21212, Loss: 202.2492
# Epoch 1/25, Batch 2080/21212, Loss: 159.1879
# Epoch 1/25, Batch 2090/21212, Loss: 317.7706
# Epoch 1/25, Batch 2100/21212, Loss: 350.5790
# Epoch 1/25, Batch 2110/21212, Loss: 462.0899
# Epoch 1/25, Batch 2120/21212, Loss: 483.0958
# Epoch 1/25, Batch 2130/21212, Loss: 469.8422
# Epoch 1/25, Batch 2140/21212, Loss: 393.0960
# Epoch 1/25, Batch 2150/21212, Loss: 311.7091
# Epoch 1/25, Batch 2160/21212, Loss: 504.5462
# Epoch 1/25, Batch 2170/21212, Loss: 485.0744
# Epoch 1/25, Batch 2180/21212, Loss: 359.3478
# Epoch 1/25, Batch 2190/21212, Loss: 314.9750
# Epoch 1/25, Batch 2200/21212, Loss: 259.3320
# Epoch 1/25, Batch 2210/21212, Loss: 211.2527
# Epoch 1/25, Batch 2220/21212, Loss: 143.8212
# Epoch 1/25, Batch 2230/21212, Loss: 139.4640
# Epoch 1/25, Batch 2240/21212, Loss: 158.2308
# Epoch 1/25, Batch 2250/21212, Loss: 139.4084
# Epoch 1/25, Batch 2260/21212, Loss: 160.9150
# Epoch 1/25, Batch 2270/21212, Loss: 154.3477
# Epoch 1/25, Batch 2280/21212, Loss: 134.1483
# Epoch 1/25, Batch 2290/21212, Loss: 275.6194
# Epoch 1/25, Batch 2300/21212, Loss: 361.2577
# Epoch 1/25, Batch 2310/21212, Loss: 435.6172
# Epoch 1/25, Batch 2320/21212, Loss: 293.3492
# Epoch 1/25, Batch 2330/21212, Loss: 508.9650
# Epoch 1/25, Batch 2340/21212, Loss: 348.1057
# Epoch 1/25, Batch 2350/21212, Loss: 364.8003
# Epoch 1/25, Batch 2360/21212, Loss: 373.6525
# Epoch 1/25, Batch 2370/21212, Loss: 344.6042
# Epoch 1/25, Batch 2380/21212, Loss: 525.5688
# Epoch 1/25, Batch 2390/21212, Loss: 454.4751
# Epoch 1/25, Batch 2400/21212, Loss: 365.6364
# Epoch 1/25, Batch 2410/21212, Loss: 625.0301
# Epoch 1/25, Batch 2420/21212, Loss: 413.5166
# Epoch 1/25, Batch 2430/21212, Loss: 345.4691
# Epoch 1/25, Batch 2440/21212, Loss: 261.3114
# Epoch 1/25, Batch 2450/21212, Loss: 274.5085
# Epoch 1/25, Batch 2460/21212, Loss: 264.9532
# Epoch 1/25, Batch 2470/21212, Loss: 242.1816
# Epoch 1/25, Batch 2480/21212, Loss: 221.0526
# Epoch 1/25, Batch 2490/21212, Loss: 335.7003
# Epoch 1/25, Batch 2500/21212, Loss: 316.2230
# Epoch 1/25, Batch 2510/21212, Loss: 392.8488
# Epoch 1/25, Batch 2520/21212, Loss: 355.8679
# Epoch 1/25, Batch 2530/21212, Loss: 437.8607
# Epoch 1/25, Batch 2540/21212, Loss: 477.4473
# Epoch 1/25, Batch 2550/21212, Loss: 468.2016
# Epoch 1/25, Batch 2560/21212, Loss: 357.5249
# Epoch 1/25, Batch 2570/21212, Loss: 453.3302
# Epoch 1/25, Batch 2580/21212, Loss: 285.7742
# Epoch 1/25, Batch 2590/21212, Loss: 409.9684
# Epoch 1/25, Batch 2600/21212, Loss: 259.0510
# Epoch 1/25, Batch 2610/21212, Loss: 192.6974
# Epoch 1/25, Batch 2620/21212, Loss: 160.3713
# Epoch 1/25, Batch 2630/21212, Loss: 222.2653
# Epoch 1/25, Batch 2640/21212, Loss: 186.5485
# Epoch 1/25, Batch 2650/21212, Loss: 251.3620
# Epoch 1/25, Batch 2660/21212, Loss: 244.1901
# Epoch 1/25, Batch 2670/21212, Loss: 255.6752
# Epoch 1/25, Batch 2680/21212, Loss: 272.1657
# Epoch 1/25, Batch 2690/21212, Loss: 290.3154
# Epoch 1/25, Batch 2700/21212, Loss: 404.6506
# Epoch 1/25, Batch 2710/21212, Loss: 301.8971
# Epoch 1/25, Batch 2720/21212, Loss: 324.7274
# Epoch 1/25, Batch 2730/21212, Loss: 246.4471
# Epoch 1/25, Batch 2740/21212, Loss: 309.8996
# Epoch 1/25, Batch 2750/21212, Loss: 328.6113
# Epoch 1/25, Batch 2760/21212, Loss: 348.1222
# Epoch 1/25, Batch 2770/21212, Loss: 376.8001
# Epoch 1/25, Batch 2780/21212, Loss: 411.6167
# Epoch 1/25, Batch 2790/21212, Loss: 308.7223
# Epoch 1/25, Batch 2800/21212, Loss: 230.4921
# Epoch 1/25, Batch 2810/21212, Loss: 124.6651
# Epoch 1/25, Batch 2820/21212, Loss: 134.8232
# Epoch 1/25, Batch 2830/21212, Loss: 173.6427
# Epoch 1/25, Batch 2840/21212, Loss: 605.3089
# Epoch 1/25, Batch 2850/21212, Loss: 480.3561
# Epoch 1/25, Batch 2860/21212, Loss: 363.7032
# Epoch 1/25, Batch 2870/21212, Loss: 274.3426
# Epoch 1/25, Batch 2880/21212, Loss: 306.7770
# Epoch 1/25, Batch 2890/21212, Loss: 354.0603
# Epoch 1/25, Batch 2900/21212, Loss: 274.6367
# Epoch 1/25, Batch 2910/21212, Loss: 395.1559
# Epoch 1/25, Batch 2920/21212, Loss: 512.5861
# Epoch 1/25, Batch 2930/21212, Loss: 466.8935
# Epoch 1/25, Batch 2940/21212, Loss: 485.3445
# Epoch 1/25, Batch 2950/21212, Loss: 383.3501
# Epoch 1/25, Batch 2960/21212, Loss: 470.7185
# Epoch 1/25, Batch 2970/21212, Loss: 279.3782
# Epoch 1/25, Batch 2980/21212, Loss: 355.9154
# Epoch 1/25, Batch 2990/21212, Loss: 364.9756
# Epoch 1/25, Batch 3000/21212, Loss: 286.7773
# Epoch 1/25, Batch 3010/21212, Loss: 154.5332
# Epoch 1/25, Batch 3020/21212, Loss: 180.4599
# Epoch 1/25, Batch 3030/21212, Loss: 175.6122
# Epoch 1/25, Batch 3040/21212, Loss: 197.9324
# Epoch 1/25, Batch 3050/21212, Loss: 197.1777
# Epoch 1/25, Batch 3060/21212, Loss: 234.4840
# Epoch 1/25, Batch 3070/21212, Loss: 367.8067
# Epoch 1/25, Batch 3080/21212, Loss: 287.8273
# Epoch 1/25, Batch 3090/21212, Loss: 448.1368
# Epoch 1/25, Batch 3100/21212, Loss: 360.5797
# Epoch 1/25, Batch 3110/21212, Loss: 366.6817
# Epoch 1/25, Batch 3120/21212, Loss: 340.6581
# Epoch 1/25, Batch 3130/21212, Loss: 371.3505
# Epoch 1/25, Batch 3140/21212, Loss: 513.4600
# Epoch 1/25, Batch 3150/21212, Loss: 350.4704
# Epoch 1/25, Batch 3160/21212, Loss: 364.7572
# Epoch 1/25, Batch 3170/21212, Loss: 501.8707
# Epoch 1/25, Batch 3180/21212, Loss: 498.2273
# Epoch 1/25, Batch 3190/21212, Loss: 294.2076
# Epoch 1/25, Batch 3200/21212, Loss: 559.6006
# Epoch 1/25, Batch 3210/21212, Loss: 385.5048
# Epoch 1/25, Batch 3220/21212, Loss: 283.0172
# Epoch 1/25, Batch 3230/21212, Loss: 401.7734
# Epoch 1/25, Batch 3240/21212, Loss: 2440.1646
# Epoch 1/25, Batch 3250/21212, Loss: 1327.3472
# Epoch 1/25, Batch 3260/21212, Loss: 1000.7825
# Epoch 1/25, Batch 3270/21212, Loss: 728.9557
# Epoch 1/25, Batch 3280/21212, Loss: 548.6328
# Epoch 1/25, Batch 3290/21212, Loss: 474.1909
# Epoch 1/25, Batch 3300/21212, Loss: 509.3222
# Epoch 1/25, Batch 3310/21212, Loss: 427.8002
# Epoch 1/25, Batch 3320/21212, Loss: 456.2413
# Epoch 1/25, Batch 3330/21212, Loss: 373.8766
# Epoch 1/25, Batch 3340/21212, Loss: 475.1011
# Epoch 1/25, Batch 3350/21212, Loss: 366.3629
# Epoch 1/25, Batch 3360/21212, Loss: 308.1258
# Epoch 1/25, Batch 3370/21212, Loss: 240.8181
# Epoch 1/25, Batch 3380/21212, Loss: 227.2057
# Epoch 1/25, Batch 3390/21212, Loss: 492.1336
# Epoch 1/25, Batch 3400/21212, Loss: 784.8398
# Epoch 1/25, Batch 3410/21212, Loss: 951.6096
# Epoch 1/25, Batch 3420/21212, Loss: 954.1455
# Epoch 1/25, Batch 3430/21212, Loss: 748.9647
# Epoch 1/25, Batch 3440/21212, Loss: 488.8173
# Epoch 1/25, Batch 3450/21212, Loss: 317.6190
# Epoch 1/25, Batch 3460/21212, Loss: 513.9282
# Epoch 1/25, Batch 3470/21212, Loss: 587.0936
# Epoch 1/25, Batch 3480/21212, Loss: 469.4949
# Epoch 1/25, Batch 3490/21212, Loss: 606.8145
# Epoch 1/25, Batch 3500/21212, Loss: 477.7071
# Epoch 1/25, Batch 3510/21212, Loss: 454.6758
# Epoch 1/25, Batch 3520/21212, Loss: 348.9020
# Epoch 1/25, Batch 3530/21212, Loss: 504.2280
# Epoch 1/25, Batch 3540/21212, Loss: 325.9892
# Epoch 1/25, Batch 3550/21212, Loss: 313.9927
# Epoch 1/25, Batch 3560/21212, Loss: 326.7980
# Epoch 1/25, Batch 3570/21212, Loss: 285.0638
# Epoch 1/25, Batch 3580/21212, Loss: 285.8865
# Epoch 1/25, Batch 3590/21212, Loss: 292.8148
# Epoch 1/25, Batch 3600/21212, Loss: 285.0752
# Epoch 1/25, Batch 3610/21212, Loss: 254.4589
# Epoch 1/25, Batch 3620/21212, Loss: 178.2019
# Epoch 1/25, Batch 3630/21212, Loss: 172.8109
# Epoch 1/25, Batch 3640/21212, Loss: 197.3363
# Epoch 1/25, Batch 3650/21212, Loss: 279.1003
# Epoch 1/25, Batch 3660/21212, Loss: 418.8219
# Epoch 1/25, Batch 3670/21212, Loss: 413.4634
# Epoch 1/25, Batch 3680/21212, Loss: 418.3626
# Epoch 1/25, Batch 3690/21212, Loss: 391.2949
# Epoch 1/25, Batch 3700/21212, Loss: 455.6500
# Epoch 1/25, Batch 3710/21212, Loss: 384.6518
# Epoch 1/25, Batch 3720/21212, Loss: 455.0699
# Epoch 1/25, Batch 3730/21212, Loss: 367.4803
# Epoch 1/25, Batch 3740/21212, Loss: 436.2220
# Epoch 1/25, Batch 3750/21212, Loss: 279.1270
# Epoch 1/25, Batch 3760/21212, Loss: 268.4167
# Epoch 1/25, Batch 3770/21212, Loss: 285.0888
# Epoch 1/25, Batch 3780/21212, Loss: 2569.8530
# Epoch 1/25, Batch 3790/21212, Loss: 1955.7682
# Epoch 1/25, Batch 3800/21212, Loss: 1829.9103
# Epoch 1/25, Batch 3810/21212, Loss: 1804.8077
# Epoch 1/25, Batch 3820/21212, Loss: 1563.3906
# Epoch 1/25, Batch 3830/21212, Loss: 1279.1133
# Epoch 1/25, Batch 3840/21212, Loss: 858.8105
# Epoch 1/25, Batch 3850/21212, Loss: 718.2520
# Epoch 1/25, Batch 3860/21212, Loss: 636.6890
# Epoch 1/25, Batch 3870/21212, Loss: 594.4714
# Epoch 1/25, Batch 3880/21212, Loss: 418.5955
# Epoch 1/25, Batch 3890/21212, Loss: 408.8502
# Epoch 1/25, Batch 3900/21212, Loss: 624.0831
# Epoch 1/25, Batch 3910/21212, Loss: 519.8915
# Epoch 1/25, Batch 3920/21212, Loss: 410.2596
# Epoch 1/25, Batch 3930/21212, Loss: 413.2087
# Epoch 1/25, Batch 3940/21212, Loss: 453.6754
# Epoch 1/25, Batch 3950/21212, Loss: 313.3036
# Epoch 1/25, Batch 3960/21212, Loss: 278.2302
# Epoch 1/25, Batch 3970/21212, Loss: 224.4812
# Epoch 1/25, Batch 3980/21212, Loss: 257.6178
# Epoch 1/25, Batch 3990/21212, Loss: 393.9832
# Epoch 1/25, Batch 4000/21212, Loss: 467.9590
# Epoch 1/25, Batch 4010/21212, Loss: 438.7781
# Epoch 1/25, Batch 4020/21212, Loss: 373.6303
# Epoch 1/25, Batch 4030/21212, Loss: 336.8708
# Epoch 1/25, Batch 4040/21212, Loss: 202.0773
# Epoch 1/25, Batch 4050/21212, Loss: 293.8799
# Epoch 1/25, Batch 4060/21212, Loss: 335.5178
# Epoch 1/25, Batch 4070/21212, Loss: 417.6964
# Epoch 1/25, Batch 4080/21212, Loss: 408.3447
# Epoch 1/25, Batch 4090/21212, Loss: 413.5746
# Epoch 1/25, Batch 4100/21212, Loss: 427.2646
# Epoch 1/25, Batch 4110/21212, Loss: 459.7941
# Epoch 1/25, Batch 4120/21212, Loss: 391.2493
# Epoch 1/25, Batch 4130/21212, Loss: 433.4229
# Epoch 1/25, Batch 4140/21212, Loss: 492.0677
# Epoch 1/25, Batch 4150/21212, Loss: 350.7791
# Epoch 1/25, Batch 4160/21212, Loss: 250.9048
# Epoch 1/25, Batch 4170/21212, Loss: 350.3274
# Epoch 1/25, Batch 4180/21212, Loss: 439.0459
# Epoch 1/25, Batch 4190/21212, Loss: 432.2938
# Epoch 1/25, Batch 4200/21212, Loss: 340.6210
# Epoch 1/25, Batch 4210/21212, Loss: 328.2658
# Epoch 1/25, Batch 4220/21212, Loss: 266.4024
# Epoch 1/25, Batch 4230/21212, Loss: 217.6305
# Epoch 1/25, Batch 4240/21212, Loss: 222.1875
# Epoch 1/25, Batch 4250/21212, Loss: 524.6651
# Epoch 1/25, Batch 4260/21212, Loss: 389.2321
# Epoch 1/25, Batch 4270/21212, Loss: 377.9369
# Epoch 1/25, Batch 4280/21212, Loss: 460.6222
# Epoch 1/25, Batch 4290/21212, Loss: 589.7648
# Epoch 1/25, Batch 4300/21212, Loss: 450.5638
# Epoch 1/25, Batch 4310/21212, Loss: 441.4506
# Epoch 1/25, Batch 4320/21212, Loss: 401.8166
# Epoch 1/25, Batch 4330/21212, Loss: 535.0058
# Epoch 1/25, Batch 4340/21212, Loss: 347.8656
# Epoch 1/25, Batch 4350/21212, Loss: 387.2602
# Epoch 1/25, Batch 4360/21212, Loss: 1656.2753
# Epoch 1/25, Batch 4370/21212, Loss: 954.3526
# Epoch 1/25, Batch 4380/21212, Loss: 775.7228
# Epoch 1/25, Batch 4390/21212, Loss: 779.2675
# Epoch 1/25, Batch 4400/21212, Loss: 895.8807
# Epoch 1/25, Batch 4410/21212, Loss: 934.5412
# Epoch 1/25, Batch 4420/21212, Loss: 390.9359
# Epoch 1/25, Batch 4430/21212, Loss: 340.8330
# Epoch 1/25, Batch 4440/21212, Loss: 357.1688
# Epoch 1/25, Batch 4450/21212, Loss: 421.2767
# Epoch 1/25, Batch 4460/21212, Loss: 471.8861
# Epoch 1/25, Batch 4470/21212, Loss: 382.8154
# Epoch 1/25, Batch 4480/21212, Loss: 476.2046
# Epoch 1/25, Batch 4490/21212, Loss: 372.1683
# Epoch 1/25, Batch 4500/21212, Loss: 538.2236
# Epoch 1/25, Batch 4510/21212, Loss: 391.4482
# Epoch 1/25, Batch 4520/21212, Loss: 598.7354
# Epoch 1/25, Batch 4530/21212, Loss: 462.4568
# Epoch 1/25, Batch 4540/21212, Loss: 219.7575
# Epoch 1/25, Batch 4550/21212, Loss: 176.0290
# Epoch 1/25, Batch 4560/21212, Loss: 840.2785
# Epoch 1/25, Batch 4570/21212, Loss: 866.3199
# Epoch 1/25, Batch 4580/21212, Loss: 1206.5598
# Epoch 1/25, Batch 4590/21212, Loss: 1147.3645
# Epoch 1/25, Batch 4600/21212, Loss: 1186.9006
# Epoch 1/25, Batch 4610/21212, Loss: 1127.1309
# Epoch 1/25, Batch 4620/21212, Loss: 921.6234
# Epoch 1/25, Batch 4630/21212, Loss: 702.8477
# Epoch 1/25, Batch 4640/21212, Loss: 616.2512
# Epoch 1/25, Batch 4650/21212, Loss: 431.7743
# Epoch 1/25, Batch 4660/21212, Loss: 506.8884
# Epoch 1/25, Batch 4670/21212, Loss: 662.7901
# Epoch 1/25, Batch 4680/21212, Loss: 479.9291
# Epoch 1/25, Batch 4690/21212, Loss: 500.9743
# Epoch 1/25, Batch 4700/21212, Loss: 494.6965
# Epoch 1/25, Batch 4710/21212, Loss: 461.5187
# Epoch 1/25, Batch 4720/21212, Loss: 546.6400
# Epoch 1/25, Batch 4730/21212, Loss: 366.1595
# Epoch 1/25, Batch 4740/21212, Loss: 275.3195
# Epoch 1/25, Batch 4750/21212, Loss: 315.3257
# Epoch 1/25, Batch 4760/21212, Loss: 401.2995
# Epoch 1/25, Batch 4770/21212, Loss: 496.6027
# Epoch 1/25, Batch 4780/21212, Loss: 439.0620
# Epoch 1/25, Batch 4790/21212, Loss: 323.4682
# Epoch 1/25, Batch 4800/21212, Loss: 553.7274
# Epoch 1/25, Batch 4810/21212, Loss: 542.5441
# Epoch 1/25, Batch 4820/21212, Loss: 429.3158
# Epoch 1/25, Batch 4830/21212, Loss: 504.3446
# Epoch 1/25, Batch 4840/21212, Loss: 532.7552
# Epoch 1/25, Batch 4850/21212, Loss: 387.3232
# Epoch 1/25, Batch 4860/21212, Loss: 452.0117
# Epoch 1/25, Batch 4870/21212, Loss: 381.1801
# Epoch 1/25, Batch 4880/21212, Loss: 430.1117
# Epoch 1/25, Batch 4890/21212, Loss: 516.1025
# Epoch 1/25, Batch 4900/21212, Loss: 490.9055
# Epoch 1/25, Batch 4910/21212, Loss: 394.6562
# Epoch 1/25, Batch 4920/21212, Loss: 433.6071
# Epoch 1/25, Batch 4930/21212, Loss: 429.9294
# Epoch 1/25, Batch 4940/21212, Loss: 186.0725
# Epoch 1/25, Batch 4950/21212, Loss: 263.0885
# Epoch 1/25, Batch 4960/21212, Loss: 606.5181
# Epoch 1/25, Batch 4970/21212, Loss: 700.2520
# Epoch 1/25, Batch 4980/21212, Loss: 718.0413
# Epoch 1/25, Batch 4990/21212, Loss: 923.1629
# Epoch 1/25, Batch 5000/21212, Loss: 858.6545
# Epoch 1/25, Batch 5010/21212, Loss: 741.8389
# Epoch 1/25, Batch 5020/21212, Loss: 555.6552
# Epoch 1/25, Batch 5030/21212, Loss: 385.0000
# Epoch 1/25, Batch 5040/21212, Loss: 611.5541
# Epoch 1/25, Batch 5050/21212, Loss: 457.5498
# Epoch 1/25, Batch 5060/21212, Loss: 593.3924
# Epoch 1/25, Batch 5070/21212, Loss: 483.2538
# Epoch 1/25, Batch 5080/21212, Loss: 515.6785
# Epoch 1/25, Batch 5090/21212, Loss: 523.7192
# Epoch 1/25, Batch 5100/21212, Loss: 595.0579
# Epoch 1/25, Batch 5110/21212, Loss: 482.7499
# Epoch 1/25, Batch 5120/21212, Loss: 485.6214
# Epoch 1/25, Batch 5130/21212, Loss: 355.3913
# Epoch 1/25, Batch 5140/21212, Loss: 192.6644
# Epoch 1/25, Batch 5150/21212, Loss: 228.4462
# Epoch 1/25, Batch 5160/21212, Loss: 279.1609
# Epoch 1/25, Batch 5170/21212, Loss: 163.1216
# Epoch 1/25, Batch 5180/21212, Loss: 371.9292
# Epoch 1/25, Batch 5190/21212, Loss: 487.3164
# Epoch 1/25, Batch 5200/21212, Loss: 479.9155
# Epoch 1/25, Batch 5210/21212, Loss: 428.6060
# Epoch 1/25, Batch 5220/21212, Loss: 370.4165
# Epoch 1/25, Batch 5230/21212, Loss: 233.1262
# Epoch 1/25, Batch 5240/21212, Loss: 445.7044
# Epoch 1/25, Batch 5250/21212, Loss: 543.1776
# Epoch 1/25, Batch 5260/21212, Loss: 414.6800
# Epoch 1/25, Batch 5270/21212, Loss: 666.4991
# Epoch 1/25, Batch 5280/21212, Loss: 395.2859
# Epoch 1/25, Batch 5290/21212, Loss: 396.7710
# Epoch 1/25, Batch 5300/21212, Loss: 358.3828
# Epoch 1/25, Batch 5310/21212, Loss: 306.7793
# Epoch 1/25, Batch 5320/21212, Loss: 257.2992
# Epoch 1/25, Batch 5330/21212, Loss: 423.9341
# Epoch 1/25, Batch 5340/21212, Loss: 231.8279
# Epoch 1/25, Batch 5350/21212, Loss: 312.4979
# Epoch 1/25, Batch 5360/21212, Loss: 271.9848
# Epoch 1/25, Batch 5370/21212, Loss: 260.3993
# Epoch 1/25, Batch 5380/21212, Loss: 105.7019
# Epoch 1/25, Batch 5390/21212, Loss: 189.7935
# Epoch 1/25, Batch 5400/21212, Loss: 156.5505
# Epoch 1/25, Batch 5410/21212, Loss: 261.7189
# Epoch 1/25, Batch 5420/21212, Loss: 394.2859
# Epoch 1/25, Batch 5430/21212, Loss: 281.1679
# Epoch 1/25, Batch 5440/21212, Loss: 334.5465
# Epoch 1/25, Batch 5450/21212, Loss: 354.7761
# Epoch 1/25, Batch 5460/21212, Loss: 458.3745
# Epoch 1/25, Batch 5470/21212, Loss: 378.7057
# Epoch 1/25, Batch 5480/21212, Loss: 502.8043
# Epoch 1/25, Batch 5490/21212, Loss: 435.5175
# Epoch 1/25, Batch 5500/21212, Loss: 481.2319
# Epoch 1/25, Batch 5510/21212, Loss: 358.8244
# Epoch 1/25, Batch 5520/21212, Loss: 426.4122
# Epoch 1/25, Batch 5530/21212, Loss: 423.3128
# Epoch 1/25, Batch 5540/21212, Loss: 284.3052
# Epoch 1/25, Batch 5550/21212, Loss: 868.4830
# Epoch 1/25, Batch 5560/21212, Loss: 895.3867
# Epoch 1/25, Batch 5570/21212, Loss: 823.3542
# Epoch 1/25, Batch 5580/21212, Loss: 831.9573
# Epoch 1/25, Batch 5590/21212, Loss: 936.0612
# Epoch 1/25, Batch 5600/21212, Loss: 813.8486
# Epoch 1/25, Batch 5610/21212, Loss: 656.3174
# Epoch 1/25, Batch 5620/21212, Loss: 548.1086
# Epoch 1/25, Batch 5630/21212, Loss: 475.6865
# Epoch 1/25, Batch 5640/21212, Loss: 412.6279
# Epoch 1/25, Batch 5650/21212, Loss: 386.3824
# Epoch 1/25, Batch 5660/21212, Loss: 494.1125
# Epoch 1/25, Batch 5670/21212, Loss: 501.8263
# Epoch 1/25, Batch 5680/21212, Loss: 429.2538
# Epoch 1/25, Batch 5690/21212, Loss: 577.1694
# Epoch 1/25, Batch 5700/21212, Loss: 487.4402
# Epoch 1/25, Batch 5710/21212, Loss: 413.1685
# Epoch 1/25, Batch 5720/21212, Loss: 368.7442
# Epoch 1/25, Batch 5730/21212, Loss: 332.2556
# Epoch 1/25, Batch 5740/21212, Loss: 201.2486
# Epoch 1/25, Batch 5750/21212, Loss: 375.4630
# Epoch 1/25, Batch 5760/21212, Loss: 422.3331
# Epoch 1/25, Batch 5770/21212, Loss: 508.5348
# Epoch 1/25, Batch 5780/21212, Loss: 456.8609
# Epoch 1/25, Batch 5790/21212, Loss: 349.9064
# Epoch 1/25, Batch 5800/21212, Loss: 607.1649
# Epoch 1/25, Batch 5810/21212, Loss: 522.9916
# Epoch 1/25, Batch 5820/21212, Loss: 546.8721
# Epoch 1/25, Batch 5830/21212, Loss: 468.9161
# Epoch 1/25, Batch 5840/21212, Loss: 405.2893
# Epoch 1/25, Batch 5850/21212, Loss: 333.6719
# Epoch 1/25, Batch 5860/21212, Loss: 540.8580
# Epoch 1/25, Batch 5870/21212, Loss: 454.4812
# Epoch 1/25, Batch 5880/21212, Loss: 527.8672
# Epoch 1/25, Batch 5890/21212, Loss: 439.7597
# Epoch 1/25, Batch 5900/21212, Loss: 342.7610
# Epoch 1/25, Batch 5910/21212, Loss: 350.1041
# Epoch 1/25, Batch 5920/21212, Loss: 216.6699
# Epoch 1/25, Batch 5930/21212, Loss: 241.6907
# Epoch 1/25, Batch 5940/21212, Loss: 321.8462
# Epoch 1/25, Batch 5950/21212, Loss: 459.4139
# Epoch 1/25, Batch 5960/21212, Loss: 465.2540
# Epoch 1/25, Batch 5970/21212, Loss: 579.8323
# Epoch 1/25, Batch 5980/21212, Loss: 650.3192
# Epoch 1/25, Batch 5990/21212, Loss: 608.0384
# Epoch 1/25, Batch 6000/21212, Loss: 541.2744
# Epoch 1/25, Batch 6010/21212, Loss: 412.9967
# Epoch 1/25, Batch 6020/21212, Loss: 504.8520
# Epoch 1/25, Batch 6030/21212, Loss: 644.7796
# Epoch 1/25, Batch 6040/21212, Loss: 491.2971
# Epoch 1/25, Batch 6050/21212, Loss: 544.2539
# Epoch 1/25, Batch 6060/21212, Loss: 423.7355
# Epoch 1/25, Batch 6070/21212, Loss: 491.1036
# Epoch 1/25, Batch 6080/21212, Loss: 434.7896
# Epoch 1/25, Batch 6090/21212, Loss: 355.7185
# Epoch 1/25, Batch 6100/21212, Loss: 333.6620
# Epoch 1/25, Batch 6110/21212, Loss: 345.9746
# Epoch 1/25, Batch 6120/21212, Loss: 429.5009
# Epoch 1/25, Batch 6130/21212, Loss: 221.2884
# Epoch 1/25, Batch 6140/21212, Loss: 250.3501
# Epoch 1/25, Batch 6150/21212, Loss: 222.2386
# Epoch 1/25, Batch 6160/21212, Loss: 327.8688
# Epoch 1/25, Batch 6170/21212, Loss: 268.0930
# Epoch 1/25, Batch 6180/21212, Loss: 377.8680
# Epoch 1/25, Batch 6190/21212, Loss: 463.4776
# Epoch 1/25, Batch 6200/21212, Loss: 408.0637
# Epoch 1/25, Batch 6210/21212, Loss: 348.5561
# Epoch 1/25, Batch 6220/21212, Loss: 306.7703
# Epoch 1/25, Batch 6230/21212, Loss: 450.4467
# Epoch 1/25, Batch 6240/21212, Loss: 411.6509
# Epoch 1/25, Batch 6250/21212, Loss: 409.3987
# Epoch 1/25, Batch 6260/21212, Loss: 489.7269
# Epoch 1/25, Batch 6270/21212, Loss: 540.0165
# Epoch 1/25, Batch 6280/21212, Loss: 533.1757
# Epoch 1/25, Batch 6290/21212, Loss: 376.4727
# Epoch 1/25, Batch 6300/21212, Loss: 358.3245
# Epoch 1/25, Batch 6310/21212, Loss: 340.2358
# Epoch 1/25, Batch 6320/21212, Loss: 364.7795
# Epoch 1/25, Batch 6330/21212, Loss: 279.0446
# Epoch 1/25, Batch 6340/21212, Loss: 477.5651
# Epoch 1/25, Batch 6350/21212, Loss: 767.6057
# Epoch 1/25, Batch 6360/21212, Loss: 666.3787
# Epoch 1/25, Batch 6370/21212, Loss: 663.5945
# Epoch 1/25, Batch 6380/21212, Loss: 823.3825
# Epoch 1/25, Batch 6390/21212, Loss: 658.4599
# Epoch 1/25, Batch 6400/21212, Loss: 476.6228
# Epoch 1/25, Batch 6410/21212, Loss: 409.2555
# Epoch 1/25, Batch 6420/21212, Loss: 386.3315
# Epoch 1/25, Batch 6430/21212, Loss: 610.4396
# Epoch 1/25, Batch 6440/21212, Loss: 560.6111
# Epoch 1/25, Batch 6450/21212, Loss: 336.1114
# Epoch 1/25, Batch 6460/21212, Loss: 469.0004
# Epoch 1/25, Batch 6470/21212, Loss: 418.1366
# Epoch 1/25, Batch 6480/21212, Loss: 386.5878
# Epoch 1/25, Batch 6490/21212, Loss: 503.8969
# Epoch 1/25, Batch 6500/21212, Loss: 451.6665
# Epoch 1/25, Batch 6510/21212, Loss: 449.1114
# Epoch 1/25, Batch 6520/21212, Loss: 218.2780
# Epoch 1/25, Batch 6530/21212, Loss: 263.7998
# Epoch 1/25, Batch 6540/21212, Loss: 249.3095
# Epoch 1/25, Batch 6550/21212, Loss: 262.2446
# Epoch 1/25, Batch 6560/21212, Loss: 342.5868
# Epoch 1/25, Batch 6570/21212, Loss: 264.2517
# Epoch 1/25, Batch 6580/21212, Loss: 469.3424
# Epoch 1/25, Batch 6590/21212, Loss: 290.1272
# Epoch 1/25, Batch 6600/21212, Loss: 385.9701
# Epoch 1/25, Batch 6610/21212, Loss: 332.8070
# Epoch 1/25, Batch 6620/21212, Loss: 502.5819
# Epoch 1/25, Batch 6630/21212, Loss: 354.4906
# Epoch 1/25, Batch 6640/21212, Loss: 379.0446
# Epoch 1/25, Batch 6650/21212, Loss: 360.8326
# Epoch 1/25, Batch 6660/21212, Loss: 368.1859
# Epoch 1/25, Batch 6670/21212, Loss: 460.3478
# Epoch 1/25, Batch 6680/21212, Loss: 445.0370
# Epoch 1/25, Batch 6690/21212, Loss: 351.9684
# Epoch 1/25, Batch 6700/21212, Loss: 441.0022
# Epoch 1/25, Batch 6710/21212, Loss: 350.8805
# Epoch 1/25, Batch 6720/21212, Loss: 519.0627
# Epoch 1/25, Batch 6730/21212, Loss: 286.3459
# Epoch 1/25, Batch 6740/21212, Loss: 246.2335
# Epoch 1/25, Batch 6750/21212, Loss: 128.2960
# Epoch 1/25, Batch 6760/21212, Loss: 129.6672
# Epoch 1/25, Batch 6770/21212, Loss: 147.2481
# Epoch 1/25, Batch 6780/21212, Loss: 122.5993
# Epoch 1/25, Batch 6790/21212, Loss: 156.0387
# Epoch 1/25, Batch 6800/21212, Loss: 148.5159
# Epoch 1/25, Batch 6810/21212, Loss: 341.6896
# Epoch 1/25, Batch 6820/21212, Loss: 330.7097
# Epoch 1/25, Batch 6830/21212, Loss: 510.4516
# Epoch 1/25, Batch 6840/21212, Loss: 377.8396
# Epoch 1/25, Batch 6850/21212, Loss: 339.3070
# Epoch 1/25, Batch 6860/21212, Loss: 396.0768
# Epoch 1/25, Batch 6870/21212, Loss: 425.3866
# Epoch 1/25, Batch 6880/21212, Loss: 401.0058
# Epoch 1/25, Batch 6890/21212, Loss: 449.0286
# Epoch 1/25, Batch 6900/21212, Loss: 418.9222
# Epoch 1/25, Batch 6910/21212, Loss: 442.6809
# Epoch 1/25, Batch 6920/21212, Loss: 306.0443
# Epoch 1/25, Batch 6930/21212, Loss: 527.4105
# Epoch 1/25, Batch 6940/21212, Loss: 560.2990
# Epoch 1/25, Batch 6950/21212, Loss: 470.6654
# Epoch 1/25, Batch 6960/21212, Loss: 472.7579
# Epoch 1/25, Batch 6970/21212, Loss: 546.4129
# Epoch 1/25, Batch 6980/21212, Loss: 470.7556
# Epoch 1/25, Batch 6990/21212, Loss: 391.0364
# Epoch 1/25, Batch 7000/21212, Loss: 400.5515
# Epoch 1/25, Batch 7010/21212, Loss: 551.6977
# Epoch 1/25, Batch 7020/21212, Loss: 600.9964
# Epoch 1/25, Batch 7030/21212, Loss: 643.1535
# Epoch 1/25, Batch 7040/21212, Loss: 514.0922
# Epoch 1/25, Batch 7050/21212, Loss: 625.1773
# Epoch 1/25, Batch 7060/21212, Loss: 433.0070
# Epoch 1/25, Batch 7070/21212, Loss: 590.4855
# Epoch 1/25, Batch 7080/21212, Loss: 461.8488
# Epoch 1/25, Batch 7090/21212, Loss: 357.8961
# Epoch 1/25, Batch 7100/21212, Loss: 420.8466
# Epoch 1/25, Batch 7110/21212, Loss: 478.9998
# Epoch 1/25, Batch 7120/21212, Loss: 282.6385
# Epoch 1/25, Batch 7130/21212, Loss: 234.6189
# Epoch 1/25, Batch 7140/21212, Loss: 252.8008
# Epoch 1/25, Batch 7150/21212, Loss: 203.5660
# Epoch 1/25, Batch 7160/21212, Loss: 208.0868
# Epoch 1/25, Batch 7170/21212, Loss: 305.8694
# Epoch 1/25, Batch 7180/21212, Loss: 267.4632
# Epoch 1/25, Batch 7190/21212, Loss: 144.7391
# Epoch 1/25, Batch 7200/21212, Loss: 247.6016
# Epoch 1/25, Batch 7210/21212, Loss: 351.3865
# Epoch 1/25, Batch 7220/21212, Loss: 352.4983
# Epoch 1/25, Batch 7230/21212, Loss: 433.6194
# Epoch 1/25, Batch 7240/21212, Loss: 312.0911
# Epoch 1/25, Batch 7250/21212, Loss: 474.1902
# Epoch 1/25, Batch 7260/21212, Loss: 620.1667
# Epoch 1/25, Batch 7270/21212, Loss: 474.5830
# Epoch 1/25, Batch 7280/21212, Loss: 454.6764
# Epoch 1/25, Batch 7290/21212, Loss: 352.0189
# Epoch 1/25, Batch 7300/21212, Loss: 476.3985
# Epoch 1/25, Batch 7310/21212, Loss: 363.2812
# Epoch 1/25, Batch 7320/21212, Loss: 280.6812
# Epoch 1/25, Batch 7330/21212, Loss: 321.2665
# Epoch 1/25, Batch 7340/21212, Loss: 232.6140
# Epoch 1/25, Batch 7350/21212, Loss: 216.9656
# Epoch 1/25, Batch 7360/21212, Loss: 290.1054
# Epoch 1/25, Batch 7370/21212, Loss: 290.2399
# Epoch 1/25, Batch 7380/21212, Loss: 258.2944
# Epoch 1/25, Batch 7390/21212, Loss: 352.9701
# Epoch 1/25, Batch 7400/21212, Loss: 448.4666
# Epoch 1/25, Batch 7410/21212, Loss: 686.3505
# Epoch 1/25, Batch 7420/21212, Loss: 489.8558
# Epoch 1/25, Batch 7430/21212, Loss: 595.9108
# Epoch 1/25, Batch 7440/21212, Loss: 503.2199
# Epoch 1/25, Batch 7450/21212, Loss: 560.1799
# Epoch 1/25, Batch 7460/21212, Loss: 566.1986
# Epoch 1/25, Batch 7470/21212, Loss: 535.0887
# Epoch 1/25, Batch 7480/21212, Loss: 582.5383
# Epoch 1/25, Batch 7490/21212, Loss: 934.9903
# Epoch 1/25, Batch 7500/21212, Loss: 515.6896
# Epoch 1/25, Batch 7510/21212, Loss: 390.8614
# Epoch 1/25, Batch 7520/21212, Loss: 316.1262
# Epoch 1/25, Batch 7530/21212, Loss: 245.1284
# Epoch 1/25, Batch 7540/21212, Loss: 138.1383
# Epoch 1/25, Batch 7550/21212, Loss: 182.4650
# Epoch 1/25, Batch 7560/21212, Loss: 173.2776
# Epoch 1/25, Batch 7570/21212, Loss: 353.0060
# Epoch 1/25, Batch 7580/21212, Loss: 345.4378
# Epoch 1/25, Batch 7590/21212, Loss: 226.5059
# Epoch 1/25, Batch 7600/21212, Loss: 375.3538
# Epoch 1/25, Batch 7610/21212, Loss: 426.0992
# Epoch 1/25, Batch 7620/21212, Loss: 375.2948
# Epoch 1/25, Batch 7630/21212, Loss: 290.4581
# Epoch 1/25, Batch 7640/21212, Loss: 465.2332
# Epoch 1/25, Batch 7650/21212, Loss: 408.3431
# Epoch 1/25, Batch 7660/21212, Loss: 295.0293
# Epoch 1/25, Batch 7670/21212, Loss: 586.6371
# Epoch 1/25, Batch 7680/21212, Loss: 342.9978
# Epoch 1/25, Batch 7690/21212, Loss: 332.9939
# Epoch 1/25, Batch 7700/21212, Loss: 318.5522
# Epoch 1/25, Batch 7710/21212, Loss: 203.5496
# Epoch 1/25, Batch 7720/21212, Loss: 267.6512
# Epoch 1/25, Batch 7730/21212, Loss: 197.6351
# Epoch 1/25, Batch 7740/21212, Loss: 99.2355
# Epoch 1/25, Batch 7750/21212, Loss: 144.6368
# Epoch 1/25, Batch 7760/21212, Loss: 718.6440
# Epoch 1/25, Batch 7770/21212, Loss: 594.0287
# Epoch 1/25, Batch 7780/21212, Loss: 406.1912
# Epoch 1/25, Batch 7790/21212, Loss: 233.6896
# Epoch 1/25, Batch 7800/21212, Loss: 376.8130
# Epoch 1/25, Batch 7810/21212, Loss: 471.2302
# Epoch 1/25, Batch 7820/21212, Loss: 491.9862
# Epoch 1/25, Batch 7830/21212, Loss: 265.1676
# Epoch 1/25, Batch 7840/21212, Loss: 488.8634
# Epoch 1/25, Batch 7850/21212, Loss: 333.3507
# Epoch 1/25, Batch 7860/21212, Loss: 474.0832
# Epoch 1/25, Batch 7870/21212, Loss: 395.4430
# Epoch 1/25, Batch 7880/21212, Loss: 370.8170
# Epoch 1/25, Batch 7890/21212, Loss: 214.1661
# Epoch 1/25, Batch 7900/21212, Loss: 364.2854
# Epoch 1/25, Batch 7910/21212, Loss: 361.7154
# Epoch 1/25, Batch 7920/21212, Loss: 250.6900
# Epoch 1/25, Batch 7930/21212, Loss: 185.3682
# Epoch 1/25, Batch 7940/21212, Loss: 194.4362
# Epoch 1/25, Batch 7950/21212, Loss: 113.0054
# Epoch 1/25, Batch 7960/21212, Loss: 150.8654
# Epoch 1/25, Batch 7970/21212, Loss: 183.9205
# Epoch 1/25, Batch 7980/21212, Loss: 246.6151
# Epoch 1/25, Batch 7990/21212, Loss: 260.1280
# Epoch 1/25, Batch 8000/21212, Loss: 241.8595
# Epoch 1/25, Batch 8010/21212, Loss: 426.4425
# Epoch 1/25, Batch 8020/21212, Loss: 276.2595
# Epoch 1/25, Batch 8030/21212, Loss: 425.5276
# Epoch 1/25, Batch 8040/21212, Loss: 438.9835
# Epoch 1/25, Batch 8050/21212, Loss: 311.3545
# Epoch 1/25, Batch 8060/21212, Loss: 633.4550
# Epoch 1/25, Batch 8070/21212, Loss: 309.1034
# Epoch 1/25, Batch 8080/21212, Loss: 415.9912
# Epoch 1/25, Batch 8090/21212, Loss: 337.2277
# Epoch 1/25, Batch 8100/21212, Loss: 364.7413
# Epoch 1/25, Batch 8110/21212, Loss: 245.7154
# Epoch 1/25, Batch 8120/21212, Loss: 154.9556
# Epoch 1/25, Batch 8130/21212, Loss: 205.6068
# Epoch 1/25, Batch 8140/21212, Loss: 143.1108
# Epoch 1/25, Batch 8150/21212, Loss: 133.8457
# Epoch 1/25, Batch 8160/21212, Loss: 180.9610
# Epoch 1/25, Batch 8170/21212, Loss: 188.4500
# Epoch 1/25, Batch 8180/21212, Loss: 224.0675
# Epoch 1/25, Batch 8190/21212, Loss: 263.1956
# Epoch 1/25, Batch 8200/21212, Loss: 319.7490
# Epoch 1/25, Batch 8210/21212, Loss: 391.4137
# Epoch 1/25, Batch 8220/21212, Loss: 422.1151
# Epoch 1/25, Batch 8230/21212, Loss: 330.5442
# Epoch 1/25, Batch 8240/21212, Loss: 477.1803
# Epoch 1/25, Batch 8250/21212, Loss: 504.6934
# Epoch 1/25, Batch 8260/21212, Loss: 363.4471
# Epoch 1/25, Batch 8270/21212, Loss: 397.3651
# Epoch 1/25, Batch 8280/21212, Loss: 375.7204
# Epoch 1/25, Batch 8290/21212, Loss: 333.9649
# Epoch 1/25, Batch 8300/21212, Loss: 327.4135
# Epoch 1/25, Batch 8310/21212, Loss: 173.5867
# Epoch 1/25, Batch 8320/21212, Loss: 565.6011
# Epoch 1/25, Batch 8330/21212, Loss: 259.2331
# Epoch 1/25, Batch 8340/21212, Loss: 186.1465
# Epoch 1/25, Batch 8350/21212, Loss: 115.2145
# Epoch 1/25, Batch 8360/21212, Loss: 178.6500
# Epoch 1/25, Batch 8370/21212, Loss: 239.6129
# Epoch 1/25, Batch 8380/21212, Loss: 210.4385
# Epoch 1/25, Batch 8390/21212, Loss: 415.9064
# Epoch 1/25, Batch 8400/21212, Loss: 453.8989
# Epoch 1/25, Batch 8410/21212, Loss: 357.8397
# Epoch 1/25, Batch 8420/21212, Loss: 362.2871
# Epoch 1/25, Batch 8430/21212, Loss: 392.4430
# Epoch 1/25, Batch 8440/21212, Loss: 453.5719
# Epoch 1/25, Batch 8450/21212, Loss: 558.5883
# Epoch 1/25, Batch 8460/21212, Loss: 373.9912
# Epoch 1/25, Batch 8470/21212, Loss: 507.0238
# Epoch 1/25, Batch 8480/21212, Loss: 378.8893
# Epoch 1/25, Batch 8490/21212, Loss: 307.2007
# Epoch 1/25, Batch 8500/21212, Loss: 264.3841
# Epoch 1/25, Batch 8510/21212, Loss: 189.7256
# Epoch 1/25, Batch 8520/21212, Loss: 231.3399
# Epoch 1/25, Batch 8530/21212, Loss: 222.8189
# Epoch 1/25, Batch 8540/21212, Loss: 137.2856
# Epoch 1/25, Batch 8550/21212, Loss: 141.6010
# Epoch 1/25, Batch 8560/21212, Loss: 130.4694
# Epoch 1/25, Batch 8570/21212, Loss: 155.5619
# Epoch 1/25, Batch 8580/21212, Loss: 294.6479
# Epoch 1/25, Batch 8590/21212, Loss: 199.9647
# Epoch 1/25, Batch 8600/21212, Loss: 264.1791
# Epoch 1/25, Batch 8610/21212, Loss: 311.4845
# Epoch 1/25, Batch 8620/21212, Loss: 238.4114
# Epoch 1/25, Batch 8630/21212, Loss: 286.4101
# Epoch 1/25, Batch 8640/21212, Loss: 329.6689
# Epoch 1/25, Batch 8650/21212, Loss: 339.9428
# Epoch 1/25, Batch 8660/21212, Loss: 422.8250
# Epoch 1/25, Batch 8670/21212, Loss: 417.4845
# Epoch 1/25, Batch 8680/21212, Loss: 356.7756
# Epoch 1/25, Batch 8690/21212, Loss: 261.4642
# Epoch 1/25, Batch 8700/21212, Loss: 295.3595
# Epoch 1/25, Batch 8710/21212, Loss: 206.9734
# Epoch 1/25, Batch 8720/21212, Loss: 163.5225
# Epoch 1/25, Batch 8730/21212, Loss: 176.4473
# Epoch 1/25, Batch 8740/21212, Loss: 200.7325
# Epoch 1/25, Batch 8750/21212, Loss: 200.7725
# Epoch 1/25, Batch 8760/21212, Loss: 202.8477
# Epoch 1/25, Batch 8770/21212, Loss: 329.9437
# Epoch 1/25, Batch 8780/21212, Loss: 273.1750
# Epoch 1/25, Batch 8790/21212, Loss: 259.3764
# Epoch 1/25, Batch 8800/21212, Loss: 385.4906
# Epoch 1/25, Batch 8810/21212, Loss: 295.1873
# Epoch 1/25, Batch 8820/21212, Loss: 355.6174
# Epoch 1/25, Batch 8830/21212, Loss: 304.4831
# Epoch 1/25, Batch 8840/21212, Loss: 504.0739
# Epoch 1/25, Batch 8850/21212, Loss: 238.2425
# Epoch 1/25, Batch 8860/21212, Loss: 450.1125
# Epoch 1/25, Batch 8870/21212, Loss: 257.7849
# Epoch 1/25, Batch 8880/21212, Loss: 340.3012
# Epoch 1/25, Batch 8890/21212, Loss: 295.5782
# Epoch 1/25, Batch 8900/21212, Loss: 118.9585
# Epoch 1/25, Batch 8910/21212, Loss: 110.9816
# Epoch 1/25, Batch 8920/21212, Loss: 114.8539
# Epoch 1/25, Batch 8930/21212, Loss: 160.1309
# Epoch 1/25, Batch 8940/21212, Loss: 157.0611
# Epoch 1/25, Batch 8950/21212, Loss: 123.9200
# Epoch 1/25, Batch 8960/21212, Loss: 115.3551
# Epoch 1/25, Batch 8970/21212, Loss: 197.3361
# Epoch 1/25, Batch 8980/21212, Loss: 282.7855
# Epoch 1/25, Batch 8990/21212, Loss: 332.4423
# Epoch 1/25, Batch 9000/21212, Loss: 233.5398
# Epoch 1/25, Batch 9010/21212, Loss: 259.3680
# Epoch 1/25, Batch 9020/21212, Loss: 263.3140
# Epoch 1/25, Batch 9030/21212, Loss: 450.4940
# Epoch 1/25, Batch 9040/21212, Loss: 288.0907
# Epoch 1/25, Batch 9050/21212, Loss: 369.2995
# Epoch 1/25, Batch 9060/21212, Loss: 367.9914
# Epoch 1/25, Batch 9070/21212, Loss: 357.3890
# Epoch 1/25, Batch 9080/21212, Loss: 285.7493
# Epoch 1/25, Batch 9090/21212, Loss: 231.8746
# Epoch 1/25, Batch 9100/21212, Loss: 141.1378
# Epoch 1/25, Batch 9110/21212, Loss: 190.4172
# Epoch 1/25, Batch 9120/21212, Loss: 152.4791
# Epoch 1/25, Batch 9130/21212, Loss: 157.0701
# Epoch 1/25, Batch 9140/21212, Loss: 368.7620
# Epoch 1/25, Batch 9150/21212, Loss: 228.9933
# Epoch 1/25, Batch 9160/21212, Loss: 274.2205
# Epoch 1/25, Batch 9170/21212, Loss: 212.4632
# Epoch 1/25, Batch 9180/21212, Loss: 169.6676
# Epoch 1/25, Batch 9190/21212, Loss: 303.7411
# Epoch 1/25, Batch 9200/21212, Loss: 270.2654
# Epoch 1/25, Batch 9210/21212, Loss: 408.8616
# Epoch 1/25, Batch 9220/21212, Loss: 326.4580
# Epoch 1/25, Batch 9230/21212, Loss: 388.6095
# Epoch 1/25, Batch 9240/21212, Loss: 352.0817
# Epoch 1/25, Batch 9250/21212, Loss: 375.9039
# Epoch 1/25, Batch 9260/21212, Loss: 207.4322
# Epoch 1/25, Batch 9270/21212, Loss: 380.9353
# Epoch 1/25, Batch 9280/21212, Loss: 297.9326
# Epoch 1/25, Batch 9290/21212, Loss: 246.5954
# Epoch 1/25, Batch 9300/21212, Loss: 190.1959
# Epoch 1/25, Batch 9310/21212, Loss: 122.4208
# Epoch 1/25, Batch 9320/21212, Loss: 150.6567
# Epoch 1/25, Batch 9330/21212, Loss: 160.0832
# Epoch 1/25, Batch 9340/21212, Loss: 117.2449
# Epoch 1/25, Batch 9350/21212, Loss: 188.4289
# Epoch 1/25, Batch 9360/21212, Loss: 142.7354
# Epoch 1/25, Batch 9370/21212, Loss: 193.1131
# Epoch 1/25, Batch 9380/21212, Loss: 292.0514
# Epoch 1/25, Batch 9390/21212, Loss: 332.6914
# Epoch 1/25, Batch 9400/21212, Loss: 404.7362
# Epoch 1/25, Batch 9410/21212, Loss: 282.2332
# Epoch 1/25, Batch 9420/21212, Loss: 428.3033
# Epoch 1/25, Batch 9430/21212, Loss: 389.8363
# Epoch 1/25, Batch 9440/21212, Loss: 415.8698
# Epoch 1/25, Batch 9450/21212, Loss: 347.8341
# Epoch 1/25, Batch 9460/21212, Loss: 381.1672
# Epoch 1/25, Batch 9470/21212, Loss: 313.8246
# Epoch 1/25, Batch 9480/21212, Loss: 233.4414
# Epoch 1/25, Batch 9490/21212, Loss: 228.6085
# Epoch 1/25, Batch 9500/21212, Loss: 182.1774
# Epoch 1/25, Batch 9510/21212, Loss: 129.1202
# Epoch 1/25, Batch 9520/21212, Loss: 102.7262
# Epoch 1/25, Batch 9530/21212, Loss: 154.7615
# Epoch 1/25, Batch 9540/21212, Loss: 106.3304
# Epoch 1/25, Batch 9550/21212, Loss: 119.6759
# Epoch 1/25, Batch 9560/21212, Loss: 137.6671
# Epoch 1/25, Batch 9570/21212, Loss: 233.7230
# Epoch 1/25, Batch 9580/21212, Loss: 273.6919
# Epoch 1/25, Batch 9590/21212, Loss: 396.6876
# Epoch 1/25, Batch 9600/21212, Loss: 318.2747
# Epoch 1/25, Batch 9610/21212, Loss: 221.6770
# Epoch 1/25, Batch 9620/21212, Loss: 336.4294
# Epoch 1/25, Batch 9630/21212, Loss: 405.3414
# Epoch 1/25, Batch 9640/21212, Loss: 387.1451
# Epoch 1/25, Batch 9650/21212, Loss: 360.3668
# Epoch 1/25, Batch 9660/21212, Loss: 345.4723
# Epoch 1/25, Batch 9670/21212, Loss: 226.3656
# Epoch 1/25, Batch 9680/21212, Loss: 394.7777
# Epoch 1/25, Batch 9690/21212, Loss: 201.1383
# Epoch 1/25, Batch 9700/21212, Loss: 556.7397
# Epoch 1/25, Batch 9710/21212, Loss: 671.2264
# Epoch 1/25, Batch 9720/21212, Loss: 449.5956
# Epoch 1/25, Batch 9730/21212, Loss: 372.4193
# Epoch 1/25, Batch 9740/21212, Loss: 209.0129
# Epoch 1/25, Batch 9750/21212, Loss: 239.3943
# Epoch 1/25, Batch 9760/21212, Loss: 158.3533
# Epoch 1/25, Batch 9770/21212, Loss: 209.4608
# Epoch 1/25, Batch 9780/21212, Loss: 245.6265
# Epoch 1/25, Batch 9790/21212, Loss: 321.4130
# Epoch 1/25, Batch 9800/21212, Loss: 271.5625
# Epoch 1/25, Batch 9810/21212, Loss: 299.7496
# Epoch 1/25, Batch 9820/21212, Loss: 334.9872
# Epoch 1/25, Batch 9830/21212, Loss: 338.6710
# Epoch 1/25, Batch 9840/21212, Loss: 316.0856
# Epoch 1/25, Batch 9850/21212, Loss: 333.2239
# Epoch 1/25, Batch 9860/21212, Loss: 367.1388
# Epoch 1/25, Batch 9870/21212, Loss: 427.5713
# Epoch 1/25, Batch 9880/21212, Loss: 214.6672
# Epoch 1/25, Batch 9890/21212, Loss: 281.5628
# Epoch 1/25, Batch 9900/21212, Loss: 164.3997
# Epoch 1/25, Batch 9910/21212, Loss: 211.1360
# Epoch 1/25, Batch 9920/21212, Loss: 152.2100
# Epoch 1/25, Batch 9930/21212, Loss: 222.1847
# Epoch 1/25, Batch 9940/21212, Loss: 443.6743
# Epoch 1/25, Batch 9950/21212, Loss: 208.1780
# Epoch 1/25, Batch 9960/21212, Loss: 350.5223
# Epoch 1/25, Batch 9970/21212, Loss: 245.9429
# Epoch 1/25, Batch 9980/21212, Loss: 296.1065
# Epoch 1/25, Batch 9990/21212, Loss: 452.1643
# Epoch 1/25, Batch 10000/21212, Loss: 348.8067
# Epoch 1/25, Batch 10010/21212, Loss: 426.5521
# Epoch 1/25, Batch 10020/21212, Loss: 346.4449
# Epoch 1/25, Batch 10030/21212, Loss: 376.1824
# Epoch 1/25, Batch 10040/21212, Loss: 380.8741
# Epoch 1/25, Batch 10050/21212, Loss: 361.3016
# Epoch 1/25, Batch 10060/21212, Loss: 202.6945
# Epoch 1/25, Batch 10070/21212, Loss: 257.7270
# Epoch 1/25, Batch 10080/21212, Loss: 319.8186
# Epoch 1/25, Batch 10090/21212, Loss: 191.0494
# Epoch 1/25, Batch 10100/21212, Loss: 244.8140
# Epoch 1/25, Batch 10110/21212, Loss: 224.9307
# Epoch 1/25, Batch 10120/21212, Loss: 194.1020
# Epoch 1/25, Batch 10130/21212, Loss: 221.1569
# Epoch 1/25, Batch 10140/21212, Loss: 226.2139
# Epoch 1/25, Batch 10150/21212, Loss: 307.4548
# Epoch 1/25, Batch 10160/21212, Loss: 312.2377
# Epoch 1/25, Batch 10170/21212, Loss: 429.9981
# Epoch 1/25, Batch 10180/21212, Loss: 331.5938
# Epoch 1/25, Batch 10190/21212, Loss: 373.9774
# Epoch 1/25, Batch 10200/21212, Loss: 346.6171
# Epoch 1/25, Batch 10210/21212, Loss: 251.4903
# Epoch 1/25, Batch 10220/21212, Loss: 357.1038
# Epoch 1/25, Batch 10230/21212, Loss: 308.9846
# Epoch 1/25, Batch 10240/21212, Loss: 468.4283
# Epoch 1/25, Batch 10250/21212, Loss: 282.6739
# Epoch 1/25, Batch 10260/21212, Loss: 234.7285
# Epoch 1/25, Batch 10270/21212, Loss: 303.3712
# Epoch 1/25, Batch 10280/21212, Loss: 204.6799
# Epoch 1/25, Batch 10290/21212, Loss: 222.6803
# Epoch 1/25, Batch 10300/21212, Loss: 90.2456
# Epoch 1/25, Batch 10310/21212, Loss: 148.2828
# Epoch 1/25, Batch 10320/21212, Loss: 186.3196
# Epoch 1/25, Batch 10330/21212, Loss: 170.2951
# Epoch 1/25, Batch 10340/21212, Loss: 197.9019
# Epoch 1/25, Batch 10350/21212, Loss: 207.2014
# Epoch 1/25, Batch 10360/21212, Loss: 271.2198
# Epoch 1/25, Batch 10370/21212, Loss: 267.8744
# Epoch 1/25, Batch 10380/21212, Loss: 310.0930
# Epoch 1/25, Batch 10390/21212, Loss: 410.6764
# Epoch 1/25, Batch 10400/21212, Loss: 391.6961
# Epoch 1/25, Batch 10410/21212, Loss: 377.5833
# Epoch 1/25, Batch 10420/21212, Loss: 318.2504
# Epoch 1/25, Batch 10430/21212, Loss: 397.1422
# Epoch 1/25, Batch 10440/21212, Loss: 317.7651
# Epoch 1/25, Batch 10450/21212, Loss: 353.3173
# Epoch 1/25, Batch 10460/21212, Loss: 445.1095
# Epoch 1/25, Batch 10470/21212, Loss: 261.2227
# Epoch 1/25, Batch 10480/21212, Loss: 203.1216
# Epoch 1/25, Batch 10490/21212, Loss: 1106.1635
# Epoch 1/25, Batch 10500/21212, Loss: 284.4765
# Epoch 1/25, Batch 10510/21212, Loss: 334.9484
# Epoch 1/25, Batch 10520/21212, Loss: 249.5846
# Epoch 1/25, Batch 10530/21212, Loss: 194.8372
# Epoch 1/25, Batch 10540/21212, Loss: 206.5195
# Epoch 1/25, Batch 10550/21212, Loss: 207.7397
# Epoch 1/25, Batch 10560/21212, Loss: 264.4561
# Epoch 1/25, Batch 10570/21212, Loss: 300.2415
# Epoch 1/25, Batch 10580/21212, Loss: 231.0182
# Epoch 1/25, Batch 10590/21212, Loss: 366.6180
# Epoch 1/25, Batch 10600/21212, Loss: 354.5004
# Epoch 1/25, Batch 10610/21212, Loss: 458.8003
# Epoch 1/25, Batch 10620/21212, Loss: 448.2859
# Epoch 1/25, Batch 10630/21212, Loss: 467.8281
# Epoch 1/25, Batch 10640/21212, Loss: 354.9215
# Epoch 1/25, Batch 10650/21212, Loss: 366.1049
# ...
# Epoch 25/25, Batch 17840/21212, Loss: 256.8423
# Epoch 25/25, Batch 17850/21212, Loss: 437.6759
# Epoch 25/25, Batch 17860/21212, Loss: 466.2595
# Epoch 25/25, Batch 17870/21212, Loss: 366.6388
# Epoch 25/25, Batch 17880/21212, Loss: 519.1252
# Epoch 25/25, Batch 17890/21212, Loss: 426.7992
# Epoch 25/25, Batch 17900/21212, Loss: 415.4297
# Epoch 25/25, Batch 17910/21212, Loss: 402.7438
# Epoch 25/25, Batch 17920/21212, Loss: 424.8297
# Epoch 25/25, Batch 17930/21212, Loss: 409.0096
# Epoch 25/25, Batch 17940/21212, Loss: 410.1992
# Epoch 25/25, Batch 17950/21212, Loss: 482.9204
# Epoch 25/25, Batch 17960/21212, Loss: 445.8388
# Epoch 25/25, Batch 17970/21212, Loss: 346.2111
# Epoch 25/25, Batch 17980/21212, Loss: 255.9218
# Epoch 25/25, Batch 17990/21212, Loss: 295.4069
# Epoch 25/25, Batch 18000/21212, Loss: 251.1385
# Epoch 25/25, Batch 18010/21212, Loss: 302.3828
# Epoch 25/25, Batch 18020/21212, Loss: 324.0540
# Epoch 25/25, Batch 18030/21212, Loss: 300.7923
# Epoch 25/25, Batch 18040/21212, Loss: 355.9675
# Epoch 25/25, Batch 18050/21212, Loss: 475.1302
# Epoch 25/25, Batch 18060/21212, Loss: 403.3254
# Epoch 25/25, Batch 18070/21212, Loss: 288.8877
# Epoch 25/25, Batch 18080/21212, Loss: 391.8466
# Epoch 25/25, Batch 18090/21212, Loss: 816.3991
# Epoch 25/25, Batch 18100/21212, Loss: 294.7135
# Epoch 25/25, Batch 18110/21212, Loss: 833.2427
# Epoch 25/25, Batch 18120/21212, Loss: 372.6696
# Epoch 25/25, Batch 18130/21212, Loss: 443.9647
# Epoch 25/25, Batch 18140/21212, Loss: 332.5704
# Epoch 25/25, Batch 18150/21212, Loss: 535.1236
# Epoch 25/25, Batch 18160/21212, Loss: 346.1579
# Epoch 25/25, Batch 18170/21212, Loss: 206.6553
# Epoch 25/25, Batch 18180/21212, Loss: 200.1525
# Epoch 25/25, Batch 18190/21212, Loss: 234.1928
# Epoch 25/25, Batch 18200/21212, Loss: 274.9369
# Epoch 25/25, Batch 18210/21212, Loss: 331.5076
# Epoch 25/25, Batch 18220/21212, Loss: 243.4465
# Epoch 25/25, Batch 18230/21212, Loss: 348.8824
# Epoch 25/25, Batch 18240/21212, Loss: 245.1002
# Epoch 25/25, Batch 18250/21212, Loss: 295.5696
# Epoch 25/25, Batch 18260/21212, Loss: 426.6093
# Epoch 25/25, Batch 18270/21212, Loss: 380.6165
# Epoch 25/25, Batch 18280/21212, Loss: 404.4194
# Epoch 25/25, Batch 18290/21212, Loss: 306.1225
# Epoch 25/25, Batch 18300/21212, Loss: 296.7805
# Epoch 25/25, Batch 18310/21212, Loss: 633.2776
# Epoch 25/25, Batch 18320/21212, Loss: 378.6545
# Epoch 25/25, Batch 18330/21212, Loss: 414.6862
# Epoch 25/25, Batch 18340/21212, Loss: 593.3416
# Epoch 25/25, Batch 18350/21212, Loss: 408.3873
# Epoch 25/25, Batch 18360/21212, Loss: 312.6546
# Epoch 25/25, Batch 18370/21212, Loss: 257.6232
# Epoch 25/25, Batch 18380/21212, Loss: 246.9036
# Epoch 25/25, Batch 18390/21212, Loss: 191.2425
# Epoch 25/25, Batch 18400/21212, Loss: 281.0092
# Epoch 25/25, Batch 18410/21212, Loss: 173.5876
# Epoch 25/25, Batch 18420/21212, Loss: 241.2477
# Epoch 25/25, Batch 18430/21212, Loss: 321.6372
# Epoch 25/25, Batch 18440/21212, Loss: 302.3930
# Epoch 25/25, Batch 18450/21212, Loss: 274.8009
# Epoch 25/25, Batch 18460/21212, Loss: 430.8779
# Epoch 25/25, Batch 18470/21212, Loss: 238.4897
# Epoch 25/25, Batch 18480/21212, Loss: 393.0352
# Epoch 25/25, Batch 18490/21212, Loss: 267.8897
# Epoch 25/25, Batch 18500/21212, Loss: 325.3198
# Epoch 25/25, Batch 18510/21212, Loss: 453.4868
# Epoch 25/25, Batch 18520/21212, Loss: 470.2351
# Epoch 25/25, Batch 18530/21212, Loss: 384.6358
# Epoch 25/25, Batch 18540/21212, Loss: 425.6454
# Epoch 25/25, Batch 18550/21212, Loss: 544.8437
# Epoch 25/25, Batch 18560/21212, Loss: 332.1405
# Epoch 25/25, Batch 18570/21212, Loss: 251.9860
# Epoch 25/25, Batch 18580/21212, Loss: 214.0307
# Epoch 25/25, Batch 18590/21212, Loss: 238.9864
# Epoch 25/25, Batch 18600/21212, Loss: 276.1676
# Epoch 25/25, Batch 18610/21212, Loss: 211.3929
# Epoch 25/25, Batch 18620/21212, Loss: 303.6384
# Epoch 25/25, Batch 18630/21212, Loss: 327.9876
# Epoch 25/25, Batch 18640/21212, Loss: 328.2672
# Epoch 25/25, Batch 18650/21212, Loss: 321.2892
# Epoch 25/25, Batch 18660/21212, Loss: 447.1699
# Epoch 25/25, Batch 18670/21212, Loss: 363.6182
# Epoch 25/25, Batch 18680/21212, Loss: 385.1124
# Epoch 25/25, Batch 18690/21212, Loss: 350.8672
# Epoch 25/25, Batch 18700/21212, Loss: 375.0756
# Epoch 25/25, Batch 18710/21212, Loss: 258.8044
# Epoch 25/25, Batch 18720/21212, Loss: 602.8755
# Epoch 25/25, Batch 18730/21212, Loss: 432.9457
# Epoch 25/25, Batch 18740/21212, Loss: 359.2246
# Epoch 25/25, Batch 18750/21212, Loss: 521.1735
# Epoch 25/25, Batch 18760/21212, Loss: 362.3896
# Epoch 25/25, Batch 18770/21212, Loss: 266.6032
# Epoch 25/25, Batch 18780/21212, Loss: 268.2170
# Epoch 25/25, Batch 18790/21212, Loss: 290.4933
# Epoch 25/25, Batch 18800/21212, Loss: 344.2184
# Epoch 25/25, Batch 18810/21212, Loss: 166.1738
# Epoch 25/25, Batch 18820/21212, Loss: 348.6183
# Epoch 25/25, Batch 18830/21212, Loss: 243.8830
# Epoch 25/25, Batch 18840/21212, Loss: 411.6951
# Epoch 25/25, Batch 18850/21212, Loss: 373.5466
# Epoch 25/25, Batch 18860/21212, Loss: 509.5202
# Epoch 25/25, Batch 18870/21212, Loss: 366.1039
# Epoch 25/25, Batch 18880/21212, Loss: 406.0730
# Epoch 25/25, Batch 18890/21212, Loss: 380.9677
# Epoch 25/25, Batch 18900/21212, Loss: 386.1495
# Epoch 25/25, Batch 18910/21212, Loss: 397.4962
# Epoch 25/25, Batch 18920/21212, Loss: 468.4681
# Epoch 25/25, Batch 18930/21212, Loss: 401.7170
# Epoch 25/25, Batch 18940/21212, Loss: 268.3372
# Epoch 25/25, Batch 18950/21212, Loss: 305.8309
# Epoch 25/25, Batch 18960/21212, Loss: 377.5194
# Epoch 25/25, Batch 18970/21212, Loss: 228.2030
# Epoch 25/25, Batch 18980/21212, Loss: 270.6159
# Epoch 25/25, Batch 18990/21212, Loss: 424.6336
# Epoch 25/25, Batch 19000/21212, Loss: 298.6662
# Epoch 25/25, Batch 19010/21212, Loss: 275.7461
# Epoch 25/25, Batch 19020/21212, Loss: 334.4845
# Epoch 25/25, Batch 19030/21212, Loss: 453.5072
# Epoch 25/25, Batch 19040/21212, Loss: 452.8374
# Epoch 25/25, Batch 19050/21212, Loss: 372.2467
# Epoch 25/25, Batch 19060/21212, Loss: 416.1675
# Epoch 25/25, Batch 19070/21212, Loss: 374.2474
# Epoch 25/25, Batch 19080/21212, Loss: 318.8248
# Epoch 25/25, Batch 19090/21212, Loss: 466.4862
# Epoch 25/25, Batch 19100/21212, Loss: 425.5291
# Epoch 25/25, Batch 19110/21212, Loss: 473.0668
# Epoch 25/25, Batch 19120/21212, Loss: 477.8971
# Epoch 25/25, Batch 19130/21212, Loss: 411.8365
# Epoch 25/25, Batch 19140/21212, Loss: 330.2737
# Epoch 25/25, Batch 19150/21212, Loss: 366.6682
# Epoch 25/25, Batch 19160/21212, Loss: 292.3989
# Epoch 25/25, Batch 19170/21212, Loss: 225.5555
# Epoch 25/25, Batch 19180/21212, Loss: 247.7714
# Epoch 25/25, Batch 19190/21212, Loss: 327.2644
# Epoch 25/25, Batch 19200/21212, Loss: 240.2327
# Epoch 25/25, Batch 19210/21212, Loss: 232.1673
# Epoch 25/25, Batch 19220/21212, Loss: 309.1503
# Epoch 25/25, Batch 19230/21212, Loss: 313.2139
# Epoch 25/25, Batch 19240/21212, Loss: 407.2025
# Epoch 25/25, Batch 19250/21212, Loss: 246.5695
# Epoch 25/25, Batch 19260/21212, Loss: 316.6778
# Epoch 25/25, Batch 19270/21212, Loss: 311.6201
# Epoch 25/25, Batch 19280/21212, Loss: 275.6101
# Epoch 25/25, Batch 19290/21212, Loss: 360.5122
# Epoch 25/25, Batch 19300/21212, Loss: 364.9361
# Epoch 25/25, Batch 19310/21212, Loss: 315.7232
# Epoch 25/25, Batch 19320/21212, Loss: 402.4488
# Epoch 25/25, Batch 19330/21212, Loss: 368.4313
# Epoch 25/25, Batch 19340/21212, Loss: 301.3535
# Epoch 25/25, Batch 19350/21212, Loss: 357.4520
# Epoch 25/25, Batch 19360/21212, Loss: 293.4320
# Epoch 25/25, Batch 19370/21212, Loss: 256.8877
# Epoch 25/25, Batch 19380/21212, Loss: 177.4310
# Epoch 25/25, Batch 19390/21212, Loss: 146.2814
# Epoch 25/25, Batch 19400/21212, Loss: 156.9539
# Epoch 25/25, Batch 19410/21212, Loss: 221.6037
# Epoch 25/25, Batch 19420/21212, Loss: 337.8370
# Epoch 25/25, Batch 19430/21212, Loss: 378.3617
# Epoch 25/25, Batch 19440/21212, Loss: 355.3687
# Epoch 25/25, Batch 19450/21212, Loss: 270.0305
# Epoch 25/25, Batch 19460/21212, Loss: 289.3817
# Epoch 25/25, Batch 19470/21212, Loss: 427.6740
# Epoch 25/25, Batch 19480/21212, Loss: 294.3220
# Epoch 25/25, Batch 19490/21212, Loss: 389.3204
# Epoch 25/25, Batch 19500/21212, Loss: 294.2921
# Epoch 25/25, Batch 19510/21212, Loss: 443.3488
# Epoch 25/25, Batch 19520/21212, Loss: 435.1317
# Epoch 25/25, Batch 19530/21212, Loss: 307.3488
# Epoch 25/25, Batch 19540/21212, Loss: 280.7545
# Epoch 25/25, Batch 19550/21212, Loss: 277.7677
# Epoch 25/25, Batch 19560/21212, Loss: 275.4145
# Epoch 25/25, Batch 19570/21212, Loss: 228.6746
# Epoch 25/25, Batch 19580/21212, Loss: 252.2060
# Epoch 25/25, Batch 19590/21212, Loss: 255.2051
# Epoch 25/25, Batch 19600/21212, Loss: 378.2332
# Epoch 25/25, Batch 19610/21212, Loss: 354.3078
# Epoch 25/25, Batch 19620/21212, Loss: 390.0669
# Epoch 25/25, Batch 19630/21212, Loss: 401.3346
# Epoch 25/25, Batch 19640/21212, Loss: 356.0988
# Epoch 25/25, Batch 19650/21212, Loss: 399.0096
# Epoch 25/25, Batch 19660/21212, Loss: 427.2101
# Epoch 25/25, Batch 19670/21212, Loss: 502.4751
# Epoch 25/25, Batch 19680/21212, Loss: 426.0996
# Epoch 25/25, Batch 19690/21212, Loss: 306.0453
# Epoch 25/25, Batch 19700/21212, Loss: 448.4931
# Epoch 25/25, Batch 19710/21212, Loss: 440.4781
# Epoch 25/25, Batch 19720/21212, Loss: 374.3960
# Epoch 25/25, Batch 19730/21212, Loss: 395.2975
# Epoch 25/25, Batch 19740/21212, Loss: 359.1187
# Epoch 25/25, Batch 19750/21212, Loss: 371.0789
# Epoch 25/25, Batch 19760/21212, Loss: 314.9522
# Epoch 25/25, Batch 19770/21212, Loss: 230.9882
# Epoch 25/25, Batch 19780/21212, Loss: 269.1636
# Epoch 25/25, Batch 19790/21212, Loss: 401.9795
# Epoch 25/25, Batch 19800/21212, Loss: 252.7611
# Epoch 25/25, Batch 19810/21212, Loss: 415.8834
# Epoch 25/25, Batch 19820/21212, Loss: 263.4066
# Epoch 25/25, Batch 19830/21212, Loss: 747.4821
# Epoch 25/25, Batch 19840/21212, Loss: 337.0024
# Epoch 25/25, Batch 19850/21212, Loss: 313.9290
# Epoch 25/25, Batch 19860/21212, Loss: 472.0570
# Epoch 25/25, Batch 19870/21212, Loss: 435.5273
# Epoch 25/25, Batch 19880/21212, Loss: 382.9342
# Epoch 25/25, Batch 19890/21212, Loss: 356.5449
# Epoch 25/25, Batch 19900/21212, Loss: 359.0653
# Epoch 25/25, Batch 19910/21212, Loss: 344.9211
# Epoch 25/25, Batch 19920/21212, Loss: 407.1487
# Epoch 25/25, Batch 19930/21212, Loss: 301.1185
# Epoch 25/25, Batch 19940/21212, Loss: 333.3400
# Epoch 25/25, Batch 19950/21212, Loss: 420.2650
# Epoch 25/25, Batch 19960/21212, Loss: 244.4253
# Epoch 25/25, Batch 19970/21212, Loss: 360.7679
# Epoch 25/25, Batch 19980/21212, Loss: 255.1153
# Epoch 25/25, Batch 19990/21212, Loss: 244.5410
# Epoch 25/25, Batch 20000/21212, Loss: 413.9692
# Epoch 25/25, Batch 20010/21212, Loss: 377.0520
# Epoch 25/25, Batch 20020/21212, Loss: 308.2512
# Epoch 25/25, Batch 20030/21212, Loss: 380.7986
# Epoch 25/25, Batch 20040/21212, Loss: 296.1964
# Epoch 25/25, Batch 20050/21212, Loss: 339.2161
# Epoch 25/25, Batch 20060/21212, Loss: 346.1433
# Epoch 25/25, Batch 20070/21212, Loss: 245.3616
# Epoch 25/25, Batch 20080/21212, Loss: 396.8284
# Epoch 25/25, Batch 20090/21212, Loss: 384.2404
# Epoch 25/25, Batch 20100/21212, Loss: 342.5690
# Epoch 25/25, Batch 20110/21212, Loss: 387.4827
# Epoch 25/25, Batch 20120/21212, Loss: 236.7569
# Epoch 25/25, Batch 20130/21212, Loss: 360.5132
# Epoch 25/25, Batch 20140/21212, Loss: 350.5762
# Epoch 25/25, Batch 20150/21212, Loss: 309.9115
# Epoch 25/25, Batch 20160/21212, Loss: 333.9340
# Epoch 25/25, Batch 20170/21212, Loss: 216.0368
# Epoch 25/25, Batch 20180/21212, Loss: 302.5927
# Epoch 25/25, Batch 20190/21212, Loss: 293.2997
# Epoch 25/25, Batch 20200/21212, Loss: 317.4058
# Epoch 25/25, Batch 20210/21212, Loss: 443.8787
# Epoch 25/25, Batch 20220/21212, Loss: 430.3734
# Epoch 25/25, Batch 20230/21212, Loss: 381.1056
# Epoch 25/25, Batch 20240/21212, Loss: 434.3767
# Epoch 25/25, Batch 20250/21212, Loss: 546.1597
# Epoch 25/25, Batch 20260/21212, Loss: 415.7112
# Epoch 25/25, Batch 20270/21212, Loss: 381.1855
# Epoch 25/25, Batch 20280/21212, Loss: 422.5987
# Epoch 25/25, Batch 20290/21212, Loss: 304.7104
# Epoch 25/25, Batch 20300/21212, Loss: 272.9268
# Epoch 25/25, Batch 20310/21212, Loss: 462.2339
# Epoch 25/25, Batch 20320/21212, Loss: 532.9094
# Epoch 25/25, Batch 20330/21212, Loss: 384.3279
# Epoch 25/25, Batch 20340/21212, Loss: 339.4801
# Epoch 25/25, Batch 20350/21212, Loss: 306.1541
# Epoch 25/25, Batch 20360/21212, Loss: 327.0538
# Epoch 25/25, Batch 20370/21212, Loss: 262.6753
# Epoch 25/25, Batch 20380/21212, Loss: 266.3185
# Epoch 25/25, Batch 20390/21212, Loss: 300.6909
# Epoch 25/25, Batch 20400/21212, Loss: 328.1122
# Epoch 25/25, Batch 20410/21212, Loss: 360.2979
# Epoch 25/25, Batch 20420/21212, Loss: 343.1171
# Epoch 25/25, Batch 20430/21212, Loss: 333.4997
# Epoch 25/25, Batch 20440/21212, Loss: 312.0067
# Epoch 25/25, Batch 20450/21212, Loss: 412.6235
# Epoch 25/25, Batch 20460/21212, Loss: 349.4543
# Epoch 25/25, Batch 20470/21212, Loss: 399.6554
# Epoch 25/25, Batch 20480/21212, Loss: 387.7939
# Epoch 25/25, Batch 20490/21212, Loss: 372.5686
# Epoch 25/25, Batch 20500/21212, Loss: 304.1786
# Epoch 25/25, Batch 20510/21212, Loss: 426.7010
# Epoch 25/25, Batch 20520/21212, Loss: 298.8066
# Epoch 25/25, Batch 20530/21212, Loss: 405.0133
# Epoch 25/25, Batch 20540/21212, Loss: 390.2336
# Epoch 25/25, Batch 20550/21212, Loss: 354.9786
# Epoch 25/25, Batch 20560/21212, Loss: 277.3705
# Epoch 25/25, Batch 20570/21212, Loss: 382.7942
# Epoch 25/25, Batch 20580/21212, Loss: 233.3666
# Epoch 25/25, Batch 20590/21212, Loss: 269.5797
# Epoch 25/25, Batch 20600/21212, Loss: 326.9781
# Epoch 25/25, Batch 20610/21212, Loss: 356.1985
# Epoch 25/25, Batch 20620/21212, Loss: 553.5137
# Epoch 25/25, Batch 20630/21212, Loss: 537.8007
# Epoch 25/25, Batch 20640/21212, Loss: 431.3891
# Epoch 25/25, Batch 20650/21212, Loss: 352.3940
# Epoch 25/25, Batch 20660/21212, Loss: 318.6653
# Epoch 25/25, Batch 20670/21212, Loss: 443.6759
# Epoch 25/25, Batch 20680/21212, Loss: 481.9711
# Epoch 25/25, Batch 20690/21212, Loss: 426.5608
# Epoch 25/25, Batch 20700/21212, Loss: 352.1646
# Epoch 25/25, Batch 20710/21212, Loss: 580.8745
# Epoch 25/25, Batch 20720/21212, Loss: 531.8019
# Epoch 25/25, Batch 20730/21212, Loss: 463.7791
# Epoch 25/25, Batch 20740/21212, Loss: 234.2373
# Epoch 25/25, Batch 20750/21212, Loss: 259.5552
# Epoch 25/25, Batch 20760/21212, Loss: 270.4741
# Epoch 25/25, Batch 20770/21212, Loss: 331.5773
# Epoch 25/25, Batch 20780/21212, Loss: 415.8142
# Epoch 25/25, Batch 20790/21212, Loss: 308.5242
# Epoch 25/25, Batch 20800/21212, Loss: 410.7144
# Epoch 25/25, Batch 20810/21212, Loss: 513.7968
# Epoch 25/25, Batch 20820/21212, Loss: 345.6850
# Epoch 25/25, Batch 20830/21212, Loss: 461.4450
# Epoch 25/25, Batch 20840/21212, Loss: 535.1454
# Epoch 25/25, Batch 20850/21212, Loss: 333.5818
# Epoch 25/25, Batch 20860/21212, Loss: 371.4221
# Epoch 25/25, Batch 20870/21212, Loss: 396.9998
# Epoch 25/25, Batch 20880/21212, Loss: 302.7188
# Epoch 25/25, Batch 20890/21212, Loss: 508.9583
# Epoch 25/25, Batch 20900/21212, Loss: 461.1996
# Epoch 25/25, Batch 20910/21212, Loss: 510.3647
# Epoch 25/25, Batch 20920/21212, Loss: 460.7197
# Epoch 25/25, Batch 20930/21212, Loss: 513.3394
# Epoch 25/25, Batch 20940/21212, Loss: 308.3987
# Epoch 25/25, Batch 20950/21212, Loss: 265.3692
# Epoch 25/25, Batch 20960/21212, Loss: 301.1324
# Epoch 25/25, Batch 20970/21212, Loss: 438.8102
# Epoch 25/25, Batch 20980/21212, Loss: 267.1747
# Epoch 25/25, Batch 20990/21212, Loss: 264.4724
# Epoch 25/25, Batch 21000/21212, Loss: 302.5323
# Epoch 25/25, Batch 21010/21212, Loss: 336.5537
# Epoch 25/25, Batch 21020/21212, Loss: 497.5868
# Epoch 25/25, Batch 21030/21212, Loss: 438.6739
# Epoch 25/25, Batch 21040/21212, Loss: 372.3756
# Epoch 25/25, Batch 21050/21212, Loss: 460.7042
# Epoch 25/25, Batch 21060/21212, Loss: 294.7652
# Epoch 25/25, Batch 21070/21212, Loss: 878.6624
# Epoch 25/25, Batch 21080/21212, Loss: 406.9594
# Epoch 25/25, Batch 21090/21212, Loss: 415.3538
# Epoch 25/25, Batch 21100/21212, Loss: 367.7609
# Epoch 25/25, Batch 21110/21212, Loss: 350.4706
# Epoch 25/25, Batch 21120/21212, Loss: 299.2844
# Epoch 25/25, Batch 21130/21212, Loss: 261.6637
# Epoch 25/25, Batch 21140/21212, Loss: 379.0880
# Epoch 25/25, Batch 21150/21212, Loss: 447.7729
# Epoch 25/25, Batch 21160/21212, Loss: 246.0182
# Epoch 25/25, Batch 21170/21212, Loss: 361.6994
# Epoch 25/25, Batch 21180/21212, Loss: 328.5135
# Epoch 25/25, Batch 21190/21212, Loss: 263.6735
# Epoch 25/25, Batch 21200/21212, Loss: 356.1949
# Epoch 25/25, Batch 21210/21212, Loss: 509.7289
# Epoch 25/25, Average Loss: 335.1923
# Validation Loss: 538.0370
# Test Loss: 529.9283

# %%
# Validation loop
model.eval()
valid_loss = 0.0
valid_mape = 0.0
valid_mse = 0.0

with torch.no_grad():
    for data, targets in valid_loader:
        data = data.to(device)
        targets = targets.to(device)
        
        outputs = model(data)
        loss = quantile_loss(targets, outputs, quantile=0.5)
        valid_loss += loss.item()
        
        # Calculate MAPE
        mape = mean_absolute_percentage_error(targets.cpu().numpy(), outputs.cpu().numpy())
        valid_mape += mape
        
        # Calculate MSE
        mse = mean_squared_error(targets.cpu().numpy(), outputs.cpu().numpy())
        valid_mse += mse

print(f"Validation Loss: {valid_loss / len(valid_loader):.4f}")
print(f"Validation MAPE: {valid_mape / len(valid_loader):.4f}")
print(f"Validation MSE: {valid_mse / len(valid_loader):.4f}")

# Test loop
test_loss = 0.0
test_mape = 0.0
test_mse = 0.0

with torch.no_grad():
    for data, targets in test_loader:
        data = data.to(device)
        targets = targets.to(device)
        
        outputs = model(data)
        loss = quantile_loss(targets, outputs, quantile=0.5)
        test_loss += loss.item()
        
        # Calculate MAPE
        mape = mean_absolute_percentage_error(targets.cpu().numpy(), outputs.cpu().numpy())
        test_mape += mape
        
        # Calculate MSE
        mse = mean_squared_error(targets.cpu().numpy(), outputs.cpu().numpy())
        test_mse += mse

print(f"Test Loss: {test_loss / len(test_loader):.4f}")
print(f"Test MAPE: {test_mape / len(test_loader):.4f}")
print(f"Test MSE: {test_mse / len(test_loader):.4f}")
# Out:
# Validation Loss: 532.0240
# Validation MAPE: 52762973149808.4688
# Validation MSE: 3174036.3891
# Test Loss: 529.5674
# Test MAPE: 7.1660
# Test MSE: 3138549.0116

# %%
batchsize_list = [300, 150, 50, 20, 8]
time_frame_list = ['3min', '5min', '15min', '30min', '60min']
time_frame_seconds_list = [180, 300, 900, 1800, 3600]
n = 0

snn_power_mape_list = []
snn_volt_mape_list = []
snn_curr_mape_list = []

# Dictionary to store mv variables
mv_dict = {}

for j in range(len(batchsize_list)):
    batchsize = batchsize_list[j]
    time_frame = time_frame_list[j]
    time_frame_seconds = time_frame_seconds_list[j]

    X = pd.concat([df["power - 1h"], df["power - 2h"], df["power - 3h"], 
                   df["V1 - 1h"], df["V1 - 2h"], df["V1 - 3h"], 
                   df["I1L - 1h"], df["I1L - 2h"], df["I1L - 3h"], 
                   df["EC - 1h"], df["EC - 2h"], df["EC - 3h"], 
                   df["raw_VWC - 1h"], df["raw_VWC - 2h"], df["raw_VWC - 3h"], 
                   df["temp - 1h"], df["temp - 2h"], df["temp - 3h"], 
                   df["tsd"], df["hour"]], axis=1)
    y = pd.concat([df["Power (uW)"], df['Voltage (mV)'], df['Current (uA)']], axis=1)

    # Normalize Data
    X_normalized = ((X - X.min()) / (X.max() - X.min()))

    # Split train and test sets
    X_train, X_test = train_test_split(X_normalized, test_size=0.3, shuffle=False)
    y_train, y_test = train_test_split(y, test_size=0.3, shuffle=False)

    X_valid, X_test = train_test_split(X_test, test_size=0.5, shuffle=False)
    y_valid, y_test = train_test_split(y_test, test_size=0.5, shuffle=False)

    # Calculate actual energy generated in test set
    E_actual = 0
    for i in range(len(y_test) - 1):
        t = (y_test.index[i+1] - y_test.index[i]).total_seconds()
        if t < 180:
            E_actual += y_test['Power (uW)'][i] * t

    # Resample data
    X_valid = X_valid.resample(time_frame).mean().dropna()
    y_valid = y_valid.resample(time_frame).mean().dropna()

    X_test = X_test.resample(time_frame).mean().dropna()
    y_test = y_test.resample(time_frame).mean().dropna()

    # Define mv variable for the current time frame
    mv_dict[time_frame] = y_test

    # Reshape data
    X_train = X_train.values.reshape((X_train.shape[0], 1, X_train.shape[1]))
    X_valid = X_valid.values.reshape((X_valid.shape[0], 1, X_valid.shape[1]))
    X_test = X_test.values.reshape((X_test.shape[0], 1, X_test.shape[1]))

    # Convert to tensor
    X_train = torch.tensor(X_train)
    y_train = torch.tensor(y_train.values)
    X_valid = torch.tensor(X_valid)
    y_valid = torch.tensor(y_valid.values)
    X_test = torch.tensor(X_test)
    y_test = torch.tensor(y_test.values)

    # Make datasets
    train_dataset = TensorDataset(X_train, y_train)
    valid_dataset = TensorDataset(X_valid, y_valid)
    test_dataset = TensorDataset(X_test, y_test)

    # Create DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=batchsize, shuffle=False)
    valid_loader = DataLoader(valid_dataset, batch_size=batchsize, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batchsize, shuffle=False)

    num_steps = 50
    num_inputs = X_train.shape[2]

    # Create new instance of the SNN Class
    model = Net(num_inputs, num_steps).to(device)

    file = 'trained_models/snn_' + time_frame + '_quant50.pth'
    print(file)

    checkpoint = torch.load(file, map_location=torch.device('cpu'), weights_only=True)
    model.load_state_dict(checkpoint['state_dict'])

    model.eval()
    actuals = []
    predictions = []

    with torch.no_grad():
        for data, targets in test_loader:
            # Prepare data
            data = data.to(device).float()
            targets = targets.to(device).float()

            _, _, _, output = model(data)

            output = output.cpu().squeeze(1).detach()
            actuals.append(targets)
            predictions.append(output[-1])

    # Convert lists to tensors
    actuals = torch.cat(actuals, dim=0)
    predictions = torch.cat(predictions, dim=0)

    mv = mv_dict[time_frame]
    mv["power_pred_med_" + time_frame] = predictions[:, 0].numpy()
    mv["voltage_pred_med_" + time_frame] = predictions[:, 1].numpy()
    mv["current_pred_med_" + time_frame] = predictions[:, 2].numpy()

    print(f'Voltage overestimation rate for {time_frame}: %.3f%%' % (
        (mv['Voltage (mV)'].values <= mv["voltage_pred_med_" + time_frame]).mean() * 100))
    print(f"Test MAPE power ({time_frame}): %3f" % MAPE(mv['Power (uW)'].values.ravel(), mv["power_pred_med_" + time_frame]))
    print(f"Test MAPE voltage ({time_frame}): %3f" % MAPE(mv['Voltage (mV)'], mv["voltage_pred_med_" + time_frame]))
    print(f"Test MAPE current ({time_frame}): %3f" % MAPE(mv['Current (uA)'], mv["current_pred_med_" + time_frame]))

    E_pred = 0
    for i in range(len(mv) - 1):
        t = (mv.index[i+1] - mv.index[i]).total_seconds()
        if t <= time_frame_seconds + 50:
            E_pred += mv["power_pred_med_" + time_frame][i] * t

    print(f'Predicted vs. Actual Total Energy Percent Difference ({time_frame}): %.3f%%' % (
        (E_pred - E_actual) * 100 / E_actual))

    V_actual = mv['Voltage (mV)'].mean()
    V_pred = mv["voltage_pred_med_" + time_frame].mean()
    print(f'Predicted vs. Actual Total Voltage Percent Difference ({time_frame}): %.3f%%' % (
        (V_pred - V_actual) * 100 / V_actual))
